# %% [markdown]
# ## Database

# %%
import pymongo
import boto3
from urllib.parse import quote_plus
from botocore.client import Config
from pymongo.collection import Collection

# %%
mongoUser = "mongotestaccess"
mongoPassword = "mongotestsecret"
mongoHost = "localhost"
mongoPort = "27017"
mongoDB = "fairscape"
mongoUserCollection = "users"
mongoIdentifierCollection = "mds"
mongoROCrateCollection = "rocrate"
mongoAsyncCollection = "async"

minioAccessKey = "miniotestadmin"
minioSecretKey = "miniotestsecret"
minioEndpoint = "http://localhost:9000"
minioDefaultBucket = "fairscape"
minioDefaultPath = "fairscape"

# %%
connection_string = f"mongodb://{quote_plus(mongoUser)}:{quote_plus(mongoPassword)}@{mongoHost}:{mongoPort}"
mongoClient = pymongo.MongoClient(connection_string)

mongoDB = mongoClient[mongoDB]

userCollection = mongoDB[mongoUserCollection]
identifierCollection = mongoDB[mongoIdentifierCollection]
rocrateCollection = mongoDB[mongoROCrateCollection]
asyncCollection = mongoDB[mongoAsyncCollection]

# %%
s3 = boto3.client('s3',
        endpoint_url=minioEndpoint,
        aws_access_key_id=minioAccessKey,
        aws_secret_access_key=minioSecretKey,
        config=Config(signature_version='s3v4'),
        region_name='us-east-1'
    )

try:
    s3.create_bucket(Bucket=minioDefaultBucket)
except:
    pass

# %%
# set up support for compression headers
def _add_header(request, **kwargs):
    request.headers.add_header('x-minio-extract', 'true')

event_system = s3.meta.events
event_system.register_first('before-sign.s3.*', _add_header)

# %%
class FairscapeRequest():
    def __init__(self, minioClient, minioBucket, identifierCollection, userCollection, asyncCollection):
        self.minioClient=minioClient
        self.minioBucket=minioBucket
        self.minioDefaultPath="fairscape"
        self.identifierCollection=identifierCollection
        self.userCollection=userCollection
        self.asyncCollection=asyncCollection

    def getMetadata(self, guid: str):
        return self.identifierCollection.find_one({"@id": guid})

# %% [markdown]
# ## Setting up Mongo Indices

# %%
# create plain text search on description name author for identifier collection
identifierCollection.create_index(
    [( "description", "text" )]
)
# Out:
# 'description_text'

# %%
identifierCollection.create_index("@id", unique=True)
# Out:
# '@id_1'

# %%
# clear indices
identifierCollection.drop_indexes()

# %%
# text query example
query = { "$text": { "$search": "a time-traveling DeLorean" } }
cursor = identifierCollection.find(query)

list(cursor)
# Out:
# []

# %% [markdown]
# ### Clearing Mongo Minio for Tests

# %% [markdown]
# # Models

# %%
def clearMongo():
    userCollection.delete_many({})
    identifierCollection.delete_many({})
    asyncCollection.delete_many({})
    rocrateCollection.delete_many({})

# %%
def clearMinio():
    paginator = s3.get_paginator('list_objects')
    page_iterator = paginator.paginate(Bucket=minioDefaultBucket)
    
    for page in page_iterator:
        try:
            for obj in page['Contents']:
                s3.delete_object(Bucket=minioDefaultBucket, Key=obj["Key"])
        except KeyError:
            pass

# %%
clearMongo()

# %%
clearMinio()

# %% [markdown]
# ## User/Auth

# %%
from pydantic import (
    BaseModel,
    Field
)
from typing import (
    Optional,
    List,
    Literal
)
import datetime
import jwt

# %%
# permissions
class Permissions(BaseModel):
    owner: str
    group: Optional[str] = Field(default=None)

# %%
class UserCreateModel(BaseModel):
    email: str
    firstName: str
    lastName: str
    password: str



class UserWriteModel(UserCreateModel):
    metadataType: Literal['Person'] = Field(alias="@type", default="Person")
    session: Optional[str] = Field(default=None)
    groups: Optional[List[str]] = Field(default=[])
    datasets: Optional[List[str]] = Field(default=[])
    software: Optional[List[str]] = Field(default=[])
    computations: Optional[List[str]] = Field(default=[])
    rocrates: Optional[List[str]] = Field(default=[])

    def getPermissions(self)->Permissions:
        permissionsDict = {
            "owner": self.email,
        }
        
        if len(self.groups)>0:
            permissionsDict['group'] = self.groups[0]
        else:
            permissionsDict['group'] = None

            
        return Permissions.model_validate(permissionsDict)

# %%
def createUser(userCollection: Collection, userInstance: UserCreateModel)->pymongo.results.InsertOneResult:
    userWriteInstance = UserWriteModel.model_validate({**userInstance.model_dump()})
    
    insertResult = userCollection.insert_one(
        userWriteInstance.model_dump(by_alias=True)
    )

    return insertResult

# %%
def loginUser(userCollection: Collection, jwtSecret: str, userEmail: str, userPassword: str):
    """ Get a user record, create a session for the 
    """

    foundUser = userCollection.find_one({
        "email": userEmail,
        "password": userPassword
    })

    if foundUser is None:
        return None

    # create a token for the user
    userEmail = foundUser['email']
    fullname = ' '.join([foundUser['firstName'], foundUser['lastName']])
    now = datetime.datetime.now(datetime.timezone.utc)
    exp = datetime.datetime.now(datetime.timezone.utc) + datetime.timedelta(hours=24)

    nowTimestamp = datetime.datetime.timestamp(now)
    expTimestamp = datetime.datetime.timestamp(exp)

    tokenMessage = {
        'iss': 'https://fairscape.net/',
        'sub':  userEmail,
        'name': fullname,
        'email': userEmail,
        'iat': int(nowTimestamp),
        'exp': int(expTimestamp)
    }

    compactJWS = jwt.encode(tokenMessage, jwtSecret, algorithm="HS256")
    
    # set session in userCollection
    updateTokenResult = userCollection.update_one({
        "email": userEmail,
        "password": userPassword
        },
        {
        "$set": {"session": compactJWS}
        }
    )

    #TODO check that update is correct

    return compactJWS

# %%
def getUserBySession(userCollection: Collection, session: str):
    foundUser = userCollection.find_one({
        "session": session
    })

    if foundUser is None:
        return None
    else:
        return UserWriteModel.model_validate(foundUser)

# %% [markdown]
# #### User/Auth Tests

# %%
testUserInstance = UserCreateModel(
    email="mal8ch@virginia.edu",
    firstName="Max",
    lastName="Levinson",
    password="roaringtwenties"
)

testJWTSecret = "test-secret"

# %%
createUserResult = createUser(userCollection, testUserInstance)
createUserResult
# Out:
# InsertOneResult(ObjectId('681251b1a9f7d5c166ee03c7'), acknowledged=True)

# %%
# login user
loginUserResult = loginUser(userCollection, testJWTSecret, testUserInstance.email, testUserInstance.password)
loginUserResult
# Out:
# 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpc3MiOiJodHRwczovL2ZhaXJzY2FwZS5uZXQvIiwic3ViIjoibWFsOGNoQHZpcmdpbmlhLmVkdSIsIm5hbWUiOiJNYXggTGV2aW5zb24iLCJlbWFpbCI6Im1hbDhjaEB2aXJnaW5pYS5lZHUiLCJpYXQiOjE3NDYwMzEwMjYsImV4cCI6MTc0NjExNzQyNn0.ZBkgD5Y-595IfkFcmEFDCwYaR2bYkTecglQbNUD4PHM'

# %%
# get user by session
foundUser = getUserBySession(userCollection, loginUserResult)
foundUser
# Out:
# UserWriteModel(email='mal8ch@virginia.edu', firstName='Max', lastName='Levinson', password='roaringtwenties', metadataType='Person', session='eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpc3MiOiJodHRwczovL2ZhaXJzY2FwZS5uZXQvIiwic3ViIjoibWFsOGNoQHZpcmdpbmlhLmVkdSIsIm5hbWUiOiJNYXggTGV2aW5zb24iLCJlbWFpbCI6Im1hbDhjaEB2aXJnaW5pYS5lZHUiLCJpYXQiOjE3NDYwMzEwMjYsImV4cCI6MTc0NjExNzQyNn0.ZBkgD5Y-595IfkFcmEFDCwYaR2bYkTecglQbNUD4PHM', groups=[], datasets=[], software=[], computations=[], rocrates=[])

# %% [markdown]
# ## Groups

# %%
class Group(BaseModel):
    name: str
    metadataType: Literal['Group'] = Field(default=Literal['Group'])
    members: List[str] = Field(default=[])

class GroupWriteModel(Group):
    owner: str

# %%
class FairscapeGroupRequest(FairscapeRequest):

    def createGroup(
        self, 
        user: UserWriteInstance, 
        groupInstance: Group
    ):
        pass

    def getGroup(self):
        pass

    def

# %%
def createGroup():
    pass

def getGroup():
    pass

# %% [markdown]
# ## Dataset

# %%
import fastapi
from fairscape_models.dataset import Dataset
from enum import Enum
from typing import Union, Optional

# %%
class DatasetCreateModel(Dataset):
    guid: Optional[str] = Field(
        title="guid",
        alias="@id",
        default=None
    )
    metadataType: Optional[str] = Field(alias="@type")
    dateRegistered: Optional[datetime.datetime] = Field(default_factory=datetime.datetime.now)

class DistributionTypeEnum(str, Enum):
    MINIO = 'minio'
    URL = 'url'
    GLOBUS = 'globus'

class MinioDistribution(BaseModel):
    path: str

class URLDistribution(BaseModel):
    uri: str

class DatasetDistribution(BaseModel):
    distributionType: DistributionTypeEnum
    location: Union[MinioDistribution, URLDistribution]


class DatasetWriteModel(DatasetCreateModel):
    distribution: Optional[DatasetDistribution] = Field(default=None)
    published: bool = Field(default=True)
    permissions: Permissions

# %%
def setDatasetObjectKey(datasetFilename: str, userInstance: UserWriteModel, basePath: str = None):
    if basePath is None:
        contentName = pathlib.Path(datasetFile).name
        return f"{userInstance.email}/datasets/{contentName}"
    else:
        return f"{basePath}/{userInstance.email}/datasets/{contentName}"

# %%
def uploadObjectMinio(
    minioClient,
    minioBucket: str,
    minioKey: str,
    datasetFile: fastapi.UploadFile,
)-> DatasetDistribution:
    """ Upload a 
    """

    uploadResult = minioClient.upload_fileobj(
        Bucket=minioBucket,
        Key=minioKey,
        Fileobj=datasetFile
    )

    # create distribution for metadata
    distribution = DatasetDistribution.model_validate({
        "distributionType": DistributionTypeEnum.Minio,
            "location": {"path": minioKey}
        })

    return distribution

# %%
class FairscapeDatasetRequest(FairscapeRequest):
    
    def __init__(self, minioClient, minioBucket, identifierCollection, userCollection):
        super().__init__(minioClient, minioBucket, identifierCollection, userCollection)
         
    def getDatasetMetadata(
        self,
        datasetGUID: str
    ):
        foundMetadata = self.getMetadata(datasetGUID)
        if foundMetadata is None:
            raise Exception

        else:
            return DatasetWriteModel.model_validate({**foundMetadata})

    def getDatasetContent(
        self, 
        userInstance: UserWriteModel, 
        datasetGUID: str,
    ):
        datasetInstance = self.getDatasetMetadata(datasetGUID)

        # check that datasetInstance has minio distribtuion
        if datasetInstance.distribution.distributionType != DistributionTypeEnum.MINIO:
            raise Exception

        # get the distribution location from metadata
        objectKey = datasetInstance.distributionType.location.path

        response = self.minioClient.get_object(
            Bucket=self.minioBucket,
            Key=objectKey
        )
        return response
        
    def createDataset(
        self, 
        userInstance: UserWriteModel,
        inputDataset: Dataset,
        datasetContent: Optional[fastapi.UploadFile]=None
    ):
        # check if guid already exists
        foundMetadata = self.getMetadata(inputDataset.guid)

        if foundMetadata is not None:
            raise Exception('GUID Already assigned')
        
        # if no content is passed
        if datasetContent is None:
            
            # process dataset
            if 'http' in inputDataset.contentUrl:
                distribution = DatasetDistribution.model_validate({
                    "distributionType": "url",
                    "location": {"uri": inputDataset.contentUrl}
                    })
            if inputDataset.contentUrl is None:
               distribution = None 

        # upload dataset content to minio
        else:
            
            # determine object key
            uploadKey = setDatasetObjectKey(
                datasetContent.filename, 
                userInstance, 
                basePath= self.minioDefaultPath
            )
            
            # upload content and return a dataset distribution
            distribution = uploadObjectMinio(self.minioClient, self.minioBucket, uploadKey, datasetContent)

        # set remainder of metadata for storage
        permissionsSet = userInstance.getPermissions()
    
        outputDataset = DatasetWriteModel.model_validate({
            "permissions": permissionsSet, 
            "distribution": distribution, 
            **datasetModelInstance.model_dump(by_alias=True)})
    
        # insert identifier metadata into mongo
        insertResult= identifierCollection.insert_one(
            outputDataset.model_dump(by_alias=True)
        )
    
        
        # add identifier to users'dataset
        updateResult = userCollection.update_one(
            {"email": userInstance.email}, 
            {"$push": {"identifiers": inputDataset.guid}}
        )

# %% [markdown]
# ## Dataset Tests

# %% [markdown]
# #### Metadata Only

# %%
fairscapeDatasetRequest = FairscapeDatasetRequest(
    minioClient=s3,
    minioBucket="default",
    identifierCollection=identifierCollection,
    userCollection=userCollection
)

# %%
# create a instance of fairscape_models.Dataset
datasetModelInstance = Dataset.model_validate(
    {
        "@id": "ark:59852/test-guid",
        "name": "test dataset",
        "@type": "https://w3id.org/EVI#Dataset",
        "author": "John Doe",
        "datePublished": "04-08-2025",
        "version": "0.1.0",
        "file": "csv",
        "description": "An example dataset",
        "keywords": [],
        "format": "csv",
        "dataSchema": None,
        "generatedBy": [],
        "derivedFrom": [],
        "usedByComputation": [],
        "contentUrl": "https://example.org/"
    }
)

# %% [markdown]
# #### Metadata and Data

# %%
# create a dataset
createDatasetResult = fairscapeDatasetRequest.createDataset(
    userInstance=foundUser,
    inputDataset=datasetModelInstance
)
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[34], line 2
#       1 # create a dataset
# ----> 2 createDatasetResult = fairscapeDatasetRequest.createDataset(
#       3     userInstance=foundUser,
#       4     inputDataset=datasetModelInstance
#       5 )
#
# Cell In[26], line 47, in FairscapeDatasetRequest.createDataset(self, userInstance, inputDataset, datasetContent)
#      44 foundMetadata = self.getMetadata(inputDataset.guid)
#      46 if foundMetadata is not None:
# ---> 47     raise Exception('GUID Already assigned')
#      49 # if no content is passed
#      50 if datasetContent is None:
#      51
#      52     # process dataset
#
# Exception: GUID Already assigned

# %%
createDatasetResult

# %%
# get a dataset metadata record
getDatasetResult = fairscapeDatasetRequest.getDatasetMetadata(
    datasetGUID=datasetModelInstance.guid
)

# %%
getDatasetResult
# Out:
# DatasetWriteModel(guid='ark:59852/test-guid', name='test dataset', metadataType='https://w3id.org/EVI#Dataset', additionalType='Dataset', author='John Doe', datePublished='04-08-2025', version='0.1.0', description='An example dataset', keywords=[], associatedPublication=None, additionalDocumentation=None, fileFormat='csv', dataSchema=None, generatedBy=[], derivedFrom=[], usedByComputation=[], contentUrl='https://example.org/', dateRegistered=datetime.datetime(2025, 4, 24, 4, 53, 8, 914000), distribution=DatasetDistribution(distributionType=<DistributionTypeEnum.URL: 'url'>, location=URLDistribution(uri='https://example.org/')), published=True, permissions=Permissions(owner='mal8ch@virginia.edu', group=None), _id=ObjectId('6809fbf4493117aa0ac6505c'), metadataType='https://w3id.org/EVI#Dataset', file='csv', dataSchema=None)

# %%
# get dataset content
getDatasetContentResult = fairscapeDatasetRequest.getDatasetContent(
    datasetGUID=datasetModelInstance.guid,
    userInstance=foundUser
)
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[38], line 2
#       1 # get dataset content
# ----> 2 getDatasetContentResult = fairscapeDatasetRequest.getDatasetContent(
#       3     datasetGUID=datasetModelInstance.guid,
#       4     userInstance=foundUser
#       5 )
#
# Cell In[26], line 26, in FairscapeDatasetRequest.getDatasetContent(self, userInstance, datasetGUID)
#      24 # check that datasetInstance has minio distribtuion
#      25 if datasetInstance.distribution.distributionType != DistributionTypeEnum.MINIO:
# ---> 26     raise Exception
#      28 # get the distribution location from metadata
#      29 objectKey = datasetInstance.distributionType.location.path
#
# Exception:

# %% [markdown]
# ## Software

# %%
from fairscape_models.software import Software

class SoftwareWriteModel(Software):
    published: bool = Field(default=True)
    dateRegistered: Optional[datetime.datetime] = Field(default_factory=datetime.datetime.now)
    permissions: Permissions

# %%
class FairscapeSoftwareRequest(FairscapeRequest):

    def __init__(self, minioClient, minioBucket, identifierCollection, userCollection):
        super().__init__(minioClient, minioBucket, identifierCollection, userCollection)

    def createSoftware(self):
        pass

    def getSoftware(self):
        pass

    def deleteSoftware(self):
        pass

    def updateSoftware(self):
        pass

# %%
def createSoftware(
    identifierCollection: pymongo.collection.Collection,
    userCollection: pymongo.collection.Collection,
    softwareInstance: Software,
    userInstance: UserWriteModel
)->bool:

    # check if identifier exists
    foundMetadata = identifierCollection.find_one({"@id": softwareInstance.guid})
    if foundMetadata is not None:
        raise Exception
    
    # create write model
    permissionsInstance = userInstance.getPermissions()

    softwareWriteInstance = SoftwareWriteModel.model_validate(  
        {
        "permissions": permissionsInstance,
        "published": True,
        **softwareInstance.model_dump(by_alias=True)
        }
     )

    # update user collection
    updateUserResult = userCollection.update_one(
        {"email": userInstance.email}, 
        {"$push": {"software": softwareInstance.guid}}
    )

    # update identifier collection
    insertSoftwareResult = identifierCollection.insert_one(
        softwareWriteInstance.model_dump(by_alias=True)
    )

    return True

# %%
def getSoftware()->SoftwareWriteModel:
    pass

# %%
def updateSoftware():
    pass

# %% [markdown]
# ## Computation

# %%
from fairscape_models.computation import Computation

class ComputationWriteModel(Computation):
    published: bool = Field(default=True)
    dateRegistered: Optional[datetime.datetime] = Field(default_factory=datetime.datetime.now)
    permissions: Permissions

# %%
def createComputation():
    pass

# %%
def getComputation():
    pass

# %%
def updateComputation():
    pass

# %%
def deleteComputation():
    pass

# %% [markdown]
# ## Schema

# %%
from fairscape_models.schema import schema

# %% [markdown]
# ## ROCrate

# %% [markdown]
# #### Old Implementation

# %%
# old implementation
class ROCrateUploadJob(BaseModel):
    userCN: str
    transactionFolder: str
    zippedCratePath: str
    timeStarted: datetime.datetime | None = Field(default=None)
    timeFinished: datetime.datetime | None = Field(default=None)
    progress: float = Field(default=0)
    stage: Optional[str] = Field(default='started')
    status: Optional[str] = Field(default='in progress')
    completed: Optional[bool] = Field(default=False)
    success: Optional[bool] = Field(default=False)
    processedFiles: List[str] = Field(default=[])
    identifiersMinted: List[str] = Field(default=[])
    error: str | None = Field(default=None)

# %%
def ProcessMetadata(roCrateMetadata, userCN: str, zipname: str):
    """ Function for processing metadata
    """ 
    crateArk = parseArk(roCrateMetadata["@id"])

    # Add distribution information if not present
    if 'distribution' not in roCrateMetadata:
        crate_name = Path(zipname).stem  # Get filename without extension
        object_path = f"{transactionFolder}/{crate_name}"

        roCrateMetadata['distribution'] = {
            "archivedROCrateBucket": fairscapeConfig.minio.rocrate_bucket,
            "archivedObjectPath": pathlib.Path(fairscapeConfig.minio.rocrate_bucket_path) / userCN / filePath / zipname
        }
        # set download link to https download link
        roCrateMetadata['contentURL'] = f"{fairscapeConfig.url}/rocrate/download/{rocrateGUID}" 

    roCrateMetadata['uploadDate'] = datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S")

    if crateArk is None:
        # TODO assign new identifiers
        pass
    else:
        roCrateMetadata["@id"] = crateArk

    # TODO reassign identifiers if there is conflict
    for crateElement in roCrateMetadata["@graph"]:
        elementArk = parseArk(crateElement["@id"])
        if elementArk is None:
            pass
        else:
            crateElement["@id"] = elementArk

# %%
def extractMetadata(transactionFolder, zippedMetadataKey):
    try:
        metadataResponse = s3.get_object(
            Bucket=fairscapeConfig.minio.default_bucket,
            Key=str(zippedMetadataKey),
        )

    # handle no such key error
    except s3.exceptions.NoSuchKey as err:
        backgroundTaskLogger.error(
            f"transaction: {str(transactionFolder)}" +
            "\tmessage: failed to read ro-crate-metadata.json from zipped ROCrate" + f"\terror: {str(minioException)}"
        )

        asyncCollection.update_one(
            {"transactionFolder": str(transactionFolder)},
            {"$set": 
                {
                    "completed": True,
                    "success": False,
                    "error": f"failed to read ro-crate-metadata.json from path {str(zippedMetadataKey)}",
                    "status": "Failed"
                }
            }
        )

    try:
        metadataContent = metadataResponse['Body'].read()
        metadataJSON = json.loads(metadataContent)

    # TODO more specific exceptions
    except:
        backgroundTaskLogger.error(
            f"transaction: {str(transactionFolder)}" +
            "\tmessage: failed to parse ro-crate-metadata.json from zipped ROCrate" + f"\terror: {str(minioException)}"
        )
        
        asyncCollection.update_one(
            {"transactionFolder": str(transactionFolder)},
            {"$set": 
                {
                    "completed": True,
                    "success": False,
                    "error": f"failed to parse ro-crate json",
                    "status": "Failed"
                }
            }
        )

        raise Exception

    asyncCollection.update_one(
        {"transactionFolder": str(transactionFolder)},
        {"$set": 
            {
                "stage": "extracting ro crate"
            }
        }
    )

    return metadataJSON

# %%
def AsyncRegisterROCrate(userCN: str, transactionFolder: str, filePath: str):
    """
    Background task for processing Zipped ROCrates.
    :param str userCN: Current User's CN uploading the ROCrate
    :param str transactionFolder: UUID folder representing the unique path in minio
    :param str filePath: The filename of the zipped crate contents
    """

    # connect to ldap and get user
    ldapConnection = fairscapeConfig.ldap.connectAdmin()
    currentUserLDAP = getUserByCN(ldapConnection, userCN)
    ldapConnection.unbind()


    # extract metadata from the zipped ROCrate 
    # construct the upload path
    uploadPath = pathlib.PurePosixPath(filePath) 
    
    zippedMetadataKey = uploadPath / uploadPath.stem / 'ro-crate-metadata.json'

    crateMetadata = extractMetadata(
        transactionFolder,
        zippedMetadataKey
    )

    # ------------------------------------
    #         Process Metadata 
    # -----------------------------------
    
    asyncCollection.update_one(
        {"transactionFolder": str(transactionFolder)},
        {"$set": 
            {
                "stage": "processing metadata"
            }
        }
    )

    metadata = ROCrateV1_2.model_validate(crateMetadata)


    #TODO: handle pydantic validation errors
    #except pydantic.ValidationError as err:
    #TODO: update transaction with metadata validation failure
        #validationErrors = err.errors() 
    
    # TODO reassign identifiers if there is conflict

    # TODO add default project for a user

    # TODO if no ROCrate ARK is assigned 
    # if crateMetadata.get("@id") is None:
    #    pass
    
    # clean identifiers
    metadata.cleanIdentifiers()
    crateElem = metadata.getCrateMetadata()
    crateGUID = crateElem.guid

    # Add distribution information if not present
    if crateMetadata.get('distribution') is None:
        zipUploadPath = uploadPath 
        crateMetadata['distribution'] = {
            "archivedROCrateBucket": fairscapeConfig.minio.rocrate_bucket,
            "archivedObjectPath": str(zipUploadPath)
        }

        # TODO set content URL
        # set download link to https download link
        crateMetadata['contentUrl'] = f"{fairscapeConfig.url}/rocrate/download/{crateGUID}" 

    crateMetadata['uploadDate'] = datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S")


    for crateElement in crateMetadata["@graph"]:
        #if elementArk is None:
        #    pass
        elementArk = parseArk(crateElement["@id"])
        crateElement['@id'] = elementArk
        crateElement['isPartOf'] = {"@id": crateGUID}


    # upload extracted files to datasets 
    # filter out all datasets
    crateDatasets = filter(
        lambda crateElem: crateElem.get("@type") == "EVI:Dataset" and  crateElem.get("contentUrl") is not None,
        crateMetadata['@graph']
        )

    for datasetElem in crateDatasets:

        # file to read from within the zipfile 
        contentURL = datasetElem['contentUrl']
        sourcePath = pathlib.Path(contentURL.lstrip('file:///'))


        # compute relative crate path
        # this will give elements a path in minio preserving the structure of the rocrate
        # files will have relative path similar to
        #  {ro_crate_name} / *** / {filename}
        # starting from the deepest element breaking at the level of the rocrate
        folderNames= str(sourcePath).split('/')
        folderNames.reverse()

        relativePath = pathlib.Path(folderNames[0])

        for nested in folderNames[1::]:
            relativePath = nested / relativePath
            if nested == uploadPath.stem:
                break

        zippedFilePath = uploadPath / relativePath


        #backgroundTaskLogger.info(                
        #    f"transaction: {str(transactionFolder)}" +
        #    f"\tuploadPath: {str(uploadPath)}" +
        #    f"\ttmpFilePath: {str(tmpFilePath)}" +
        #    "\tmessage: uploading dataset" 
        #    )

        # add distribution to metadata to enable download enpoints
        datasetElem['distribution'] = {
            'distributionType': 'minio',
            'location': {
                'path': str(zippedFilePath)
            }
        }

        # TODO check that dataset enpoint works and is accurate
        # set download link relative to fairscape
        datasetElem['contentUrl']=f"{fairscapeConfig.url}/dataset/download/{datasetElem['@id']}"


    # --------------------------- 
    #    PUBLISH METADATA
    # --------------------------

    asyncCollection.update_one(
        {"transactionFolder": transactionFolder},
        {"$set": 
            {
                "stage": "publishing metadata"
            }
        }
    )

    # Check if @id already exsists
    #rocrateFound = rocrateCollection.find_one(
    #        {"@id": crateMetadata['@id']}
    #        )

    #if rocrateFound:
    #    raise ROCrateException(
    #        f"ROCrate with @id == {crateMetadata['@id']} found", None)
    

    # set default permissions for uploaded crate
    crateMetadata['permissions'] = {
            "owner": currentUserLDAP.dn,
            "group": currentUserLDAP.memberOf[0]
            }

    # set default permissions for all datasets
    for crateElem in crateMetadata['@graph']:
        # set permissions on all rocrate identifiers
        crateElem['permissions'] = {
            "owner": currentUserLDAP.dn,
            "group": currentUserLDAP.memberOf[0]
            }

    # for every element in the rocrate model dump json
    insertMetadata = [ elem for elem in crateMetadata.get("@graph", [])]
    # insert rocrate json into identifier collection
    insertMetadata.append(crateMetadata)

    insertedIdentifiers = [ elem.get("@id") for elem in insertMetadata]

    # TODO check for already existing identifiers and mark as conflicts
    #     - should reassign identifiers at metadata processing stage

    # insert all identifiers into the identifier collection
    insertResult = identifierCollection.insert_many(insertMetadata)

    if len(insertResult.inserted_ids) != len(insertMetadata):
        # raise an exception
        backgroundTaskLogger.error(
            f"transaction: {str(transactionFolder)}" +
            "\tmessage: error uploading provenance identifiers" 
        )
        raise Exception(f"Error Minting Provenance Identifiers")

    else:
        # log success
        backgroundTaskLogger.info(
            f"transaction: {str(transactionFolder)}" +
            "\tmessage: minted provenance identifiers" +
            f"\tcrateGUID: {crateGUID}" +
            f"\tnumberOfIdentifiers: {len(insertResult.inserted_ids)}"
        )

    # insert rocrate result 
    insertResult = rocrateCollection.insert_one(crateMetadata)

    if insertResult.inserted_id is None:
        backgroundTaskLogger.error(
            f"transaction: {str(transactionFolder)}" +
            "\tmessage: error uploading rocrate identifier"  +
            f"\tcrateGUID: {crateGUID}"
        )
        raise Exception(f"Error Minting Provenance Identifiers")

    else:
        backgroundTaskLogger.info(
            f"transaction: {str(transactionFolder)}" +
            "\tmessage: minted rocrate identifiers" +
            f"\tcrateGUID: {crateGUID}" 
        )

    # update the job as success 
    # upsert because some jobs can't find their metadata
    asyncCollection.update_one(
        {"transactionFolder": str(transactionFolder)},
        {"$set": 
            {
                "userCN": userCN,
                "transactionFolder": str(transactionFolder),
                "zippedCratePath": filePath,
                "completed": True,
                "success": True,
                "status": "finished",
                "stage": "completed all tasks successfully"
            }
        },
        upsert=True
    )

    # ---------------------
    # Delete Transaction
    # ---------------------
    return True

# %% [markdown]
# #### Refactor

# %%
import re
import pathlib
import uuid
import json

from fairscape_models.rocrate import ROCrateV1_2
from fairscape_models.dataset import Dataset

# %%
class ROCrateUploadRequest(BaseModel):
    guid: str
    permissions: Permissions
    uploadPath: str
    timeStarted: Optional[datetime.datetime] = Field(default_factory=datetime.datetime.now)
    timeFinished: Optional[datetime.datetime] = Field(default=None)
    completed: Optional[bool] = Field(default=False)
    error: Optional[str] = Field(default=None)
    identifiersMinted: List[str] = Field(default=[])

# %%
def userPath(inputEmail):
    searchResults = re.search("(^[a-zA-Z0-9_.+-]+)@", inputEmail) 

    if searchResults is None:
        raise Exception
    else:
        return searchResults.group(1)

# %%
userPath('mal8ch@virginia.edu')
# Out:
# 'mal8ch'

# %%
def getROCrateMetadata(s3Client, bucketName, uploadInstance):
    zippedCratePath = pathlib.Path(uploadInstance.uploadPath)
    zippedCrateMetadataPath = zippedCratePath / zippedCratePath.stem / 'ro-crate-metadata.json'
    
    # get the values for the zipped metadata
    try:
        s3Response = s3Client.get_object(
            Bucket=bucketName,
            Key=str(zippedCrateMetadataPath)
        )

        # get the metadata out of the s3 response
        content= s3Response['Body'].read()
        roCrateJSON = json.loads(content)
        return roCrateJSON
    
    except s3Client.exceptions.NoSuchKey as err:
        # TODO handle error
        print("No Key Found")
        print(err)

# %%
class FairscapeROCrateUploadRequest(FairscapeRequest):
    pass

    def uploadROCrate(self, userInstance: UserWriteModel, rocrate):
        # TODO replace pathlib with file
        
        # set upload path
        rocrateFilename = rocrateZip.name

        # get email path
        userEmailPath = userPath(foundUser.email)
        
        uploadPath = f"{self.minioDefaultPath}/{userEmailPath}/rocrates/{rocrateFilename}"

        # upload zip to minio
        # TODO switch with fastapi.UploadFile
        with rocrateZip.open('rb') as zippedFileObj:
            uploadOperationResult = self.minioClient.upload_fileobj(
                Bucket = self.minioBucket,
                Key = str(uploadPath),
                Fileobj = zippedFileObj,
                ExtraArgs = {'ContentType': 'application/zip'}
            )

        transactionGUID = uuid.uuid4()
        
        uploadRequestInstance = ROCrateUploadRequest.model_validate({
            "guid": str(transactionGUID),
            "permissions": userInstance.getPermissions(),
            "uploadPath": str(uploadPath)
        })
        # create record in the async collection
        uploadRequestMetadata = uploadRequestInstance.model_dump()
        insertResult = self.asyncCollection.insert_one(uploadRequestMetadata)

        return uploadRequestInstance
    
    def processROcrate(self, transactionGUID: str):
        # get the current rocrate upload job
        uploadMetadata = asyncCollection.find_one({"guid": upload.guid})

        if uploadMetadata is None:
            raise Exception

        uploadInstance = ROCrateUploadRequest.model_validate(uploadMetadata)
        
        # find the user from the 
        userMetadata = self.userCollection.find_one(
            {"email": uploadInstance.permissions.owner }
        )

        foundUser = UserWriteModel.model_validate(userMetadata)

        roCrateMetadata = getROCrateMetadata(self.minioClient, self.minioBucket, uploadInstance)
        
        # parse the metadata into the rocrate
        try:
            roCrateModel = ROCrateV1_2.model_validate(roCrateJSON)
        
        except ValidationError as validationErr:
            # TODO return an error
            print("ValidationError")
            return None

        # get rocrate GUID
        crateMetadata = roCrateModel.getCrateMetadata()

        # get list of the objects from minio
        objectList = getROCrateContentsMinio(s3, minioDefaultBucket, zippedCratePath)

        # write dataset records
        datasetGUIDS = writeDatasets(
            self.identifierCollection, 
            foundUser, 
            roCrateModel, 
            objectList
        )

        # write metadata elements
        nonDatasetGUIDS = writeMetadataElements(
            self.identifierCollection,
            foundUser,
            roCrateModel
        )

        # update process as success
        updateResult = asyncCollection.update_one(
            {"guid": uploadInstance.guid},
            {"$set": {
                "completed": True,
                "identifiersMinted": datasetGUIDS + nonDatasetGUIDS,
                "timeFinished": datetime.datetime.now()
            }}
        )

        #TODO: check update result
            
        return datasetGUIDS + nonDatasetGUIDS

# %%
fairscapeCrateUpload = FairscapeROCrateUploadRequest(
    minioClient=s3,
    minioBucket=minioDefaultBucket,
    identifierCollection=identifierCollection,
    userCollection=userCollection,
    asyncCollection=asyncCollection
)

# %%
fairscapeCrateUpload.processROcrate(upload.guid)
# Out:
# ['ark:59852/dataset-paclitaxel-manifest',
#  'ark:59852/B2AI_5_Paclitaxel_H12_R8_z01_blue',
#  'ark:59852/B2AI_5_Paclitaxel_H12_R8_z01_red',
#  'ark:59852/B2AI_5_Paclitaxel_H12_R8_z01_yellow',
#  'ark:59852/B2AI_5_Paclitaxel_H12_R8_z01_green',
#  'ark:59852/B2AI_4_Paclitaxel_H12_R8_z02_blue',
#  'ark:59852/B2AI_4_Paclitaxel_H12_R8_z02_red',
#  'ark:59852/B2AI_4_Paclitaxel_H12_R8_z02_yellow',
#  'ark:59852/B2AI_4_Paclitaxel_H12_R8_z02_green',
#  'ark:59852/B2AI_3_Paclitaxel_H12_R8_z02_blue',
#  'ark:59852/B2AI_3_Paclitaxel_H12_R8_z02_red',
#  'ark:59852/B2AI_3_Paclitaxel_H12_R8_z02_yellow',
#  'ark:59852/B2AI_3_Paclitaxel_H12_R8_z02_green',
#  'ark:59852/B2AI_2_Paclitaxel_H12_R8_z00_blue',
#  'ark:59852/B2AI_2_Paclitaxel_H12_R8_z00_red',
#  'ark:59852/B2AI_2_Paclitaxel_H12_R8_z00_yellow',
#  'ark:59852/B2AI_2_Paclitaxel_H12_R8_z00_green',
#  'ark:59852/B2AI_5_Paclitaxel_H12_R7_z02_blue',
#  'ark:59852/B2AI_5_Paclitaxel_H12_R7_z02_red',
#  'ark:59852/B2AI_5_Paclitaxel_H12_R7_z02_yellow',
#  'ark:59852/B2AI_5_Paclitaxel_H12_R7_z02_green',
#  'ark:59852/B2AI_4_Paclitaxel_H12_R7_z01_blue',
#  'ark:59852/B2AI_4_Paclitaxel_H12_R7_z01_red',
#  'ark:59852/B2AI_4_Paclitaxel_H12_R7_z01_yellow',
#  'ark:59852/B2AI_4_Paclitaxel_H12_R7_z01_green',
#  'ark:59852/B2AI_3_Paclitaxel_H12_R7_z00_blue',
#  'ark:59852/B2AI_3_Paclitaxel_H12_R7_z00_red',
#  'ark:59852/B2AI_3_Paclitaxel_H12_R7_z00_yellow',
#  'ark:59852/B2AI_3_Paclitaxel_H12_R7_z00_green',
#  'ark:59852/B2AI_2_Paclitaxel_H12_R7_z01_blue',
#  'ark:59852/B2AI_2_Paclitaxel_H12_R7_z01_red',
#  'ark:59852/B2AI_2_Paclitaxel_H12_R7_z01_yellow',
#  'ark:59852/B2AI_2_Paclitaxel_H12_R7_z01_green',
#  'ark:59852/B2AI_1_Paclitaxel_H12_R7_z01_blue',
#  'ark:59852/B2AI_1_Paclitaxel_H12_R7_z01_red',
#  'ark:59852/B2AI_1_Paclitaxel_H12_R7_z01_yellow',
#  'ark:59852/B2AI_1_Paclitaxel_H12_R7_z01_green',
#  'ark:59852/B2AI_5_Paclitaxel_H12_R6_z01_blue',
#  'ark:59852/B2AI_5_Paclitaxel_H12_R6_z01_red',
#  'ark:59852/B2AI_5_Paclitaxel_H12_R6_z01_yellow',
#  'ark:59852/B2AI_5_Paclitaxel_H12_R6_z01_green',
#  'ark:59852/B2AI_4_Paclitaxel_H12_R6_z02_blue',
#  'ark:59852/B2AI_4_Paclitaxel_H12_R6_z02_red',
#  'ark:59852/B2AI_4_Paclitaxel_H12_R6_z02_yellow',
#  'ark:59852/B2AI_4_Paclitaxel_H12_R6_z02_green',
#  'ark:59852/B2AI_2_Paclitaxel_H12_R6_z01_blue',
#  'ark:59852/B2AI_2_Paclitaxel_H12_R6_z01_red',
#  'ark:59852/B2AI_2_Paclitaxel_H12_R6_z01_yellow',
#  'ark:59852/B2AI_2_Paclitaxel_H12_R6_z01_green',
#  'ark:59852/B2AI_5_Paclitaxel_H12_R5_z01_blue',
#  'ark:59852/B2AI_5_Paclitaxel_H12_R5_z01_red',
#  'ark:59852/B2AI_5_Paclitaxel_H12_R5_z01_yellow',
#  'ark:59852/B2AI_5_Paclitaxel_H12_R5_z01_green',
#  'ark:59852/B2AI_4_Paclitaxel_H12_R5_z02_blue',
#  'ark:59852/B2AI_4_Paclitaxel_H12_R5_z02_red',
#  'ark:59852/B2AI_4_Paclitaxel_H12_R5_z02_yellow',
#  'ark:59852/B2AI_4_Paclitaxel_H12_R5_z02_green',
#  'ark:59852/B2AI_2_Paclitaxel_H12_R5_z02_blue',
#  'ark:59852/B2AI_2_Paclitaxel_H12_R5_z02_red',
#  'ark:59852/B2AI_2_Paclitaxel_H12_R5_z02_yellow',
#  'ark:59852/B2AI_2_Paclitaxel_H12_R5_z02_green',
#  'ark:59852/B2AI_1_Paclitaxel_H12_R5_z01_blue',
#  'ark:59852/B2AI_1_Paclitaxel_H12_R5_z01_red',
#  'ark:59852/B2AI_1_Paclitaxel_H12_R5_z01_yellow',
#  'ark:59852/B2AI_1_Paclitaxel_H12_R5_z01_green',
#  'ark:59852/B2AI_5_Paclitaxel_H12_R4_z00_blue',
#  'ark:59852/B2AI_5_Paclitaxel_H12_R4_z00_red',
#  'ark:59852/B2AI_5_Paclitaxel_H12_R4_z00_yellow',
#  'ark:59852/B2AI_5_Paclitaxel_H12_R4_z00_green',
#  'ark:59852/B2AI_4_Paclitaxel_H12_R4_z02_blue',
#  'ark:59852/B2AI_4_Paclitaxel_H12_R4_z02_red',
#  'ark:59852/B2AI_4_Paclitaxel_H12_R4_z02_yellow',
#  'ark:59852/B2AI_4_Paclitaxel_H12_R4_z02_green',
#  'ark:59852/B2AI_1_Paclitaxel_H12_R4_z01_blue',
#  'ark:59852/B2AI_1_Paclitaxel_H12_R4_z01_red',
#  'ark:59852/B2AI_1_Paclitaxel_H12_R4_z01_yellow',
#  'ark:59852/B2AI_1_Paclitaxel_H12_R4_z01_green',
#  'ark:59852/B2AI_4_Paclitaxel_H12_R3_z01_blue',
#  'ark:59852/B2AI_4_Paclitaxel_H12_R3_z01_red',
#  'ark:59852/B2AI_4_Paclitaxel_H12_R3_z01_yellow',
#  'ark:59852/B2AI_4_Paclitaxel_H12_R3_z01_green',
#  'ark:59852/B2AI_3_Paclitaxel_H12_R3_z01_blue',
#  'ark:59852/B2AI_3_Paclitaxel_H12_R3_z01_red',
#  'ark:59852/B2AI_3_Paclitaxel_H12_R3_z01_yellow',
#  'ark:59852/B2AI_3_Paclitaxel_H12_R3_z01_green',
#  'ark:59852/B2AI_2_Paclitaxel_H12_R3_z01_blue',
#  'ark:59852/B2AI_2_Paclitaxel_H12_R3_z01_red',
#  'ark:59852/B2AI_2_Paclitaxel_H12_R3_z01_yellow',
#  'ark:59852/B2AI_2_Paclitaxel_H12_R3_z01_green',
#  'ark:59852/B2AI_1_Paclitaxel_H12_R3_z02_blue',
#  'ark:59852/B2AI_1_Paclitaxel_H12_R3_z02_red',
#  'ark:59852/B2AI_1_Paclitaxel_H12_R3_z02_yellow',
#  'ark:59852/B2AI_1_Paclitaxel_H12_R3_z02_green',
#  'ark:59852/B2AI_2_Paclitaxel_H12_R2_z00_blue',
#  'ark:59852/B2AI_2_Paclitaxel_H12_R2_z00_red',
#  'ark:59852/B2AI_2_Paclitaxel_H12_R2_z00_yellow',
#  'ark:59852/B2AI_2_Paclitaxel_H12_R2_z00_green',
#  'ark:59852/B2AI_1_Paclitaxel_H12_R2_z01_blue',
#  'ark:59852/B2AI_1_Paclitaxel_H12_R2_z01_red',
#  'ark:59852/B2AI_1_Paclitaxel_H12_R2_z01_yellow',
#  'ark:59852/B2AI_1_Paclitaxel_H12_R2_z01_green',
#  'ark:59852/B2AI_5_Paclitaxel_H12_R13_z01_blue',
#  'ark:59852/B2AI_5_Paclitaxel_H12_R13_z01_red',
#  'ark:59852/B2AI_5_Paclitaxel_H12_R13_z01_yellow',
#  'ark:59852/B2AI_5_Paclitaxel_H12_R13_z01_green',
#  'ark:59852/B2AI_2_Paclitaxel_H12_R13_z01_blue',
#  'ark:59852/B2AI_2_Paclitaxel_H12_R13_z01_red',
#  'ark:59852/B2AI_2_Paclitaxel_H12_R13_z01_yellow',
#  'ark:59852/B2AI_2_Paclitaxel_H12_R13_z01_green',
#  'ark:59852/B2AI_5_Paclitaxel_H12_R12_z01_blue',
#  'ark:59852/B2AI_5_Paclitaxel_H12_R12_z01_red',
#  'ark:59852/B2AI_5_Paclitaxel_H12_R12_z01_yellow',
#  'ark:59852/B2AI_5_Paclitaxel_H12_R12_z01_green',
#  'ark:59852/B2AI_2_Paclitaxel_H12_R12_z01_blue',
#  'ark:59852/B2AI_2_Paclitaxel_H12_R12_z01_red',
#  'ark:59852/B2AI_2_Paclitaxel_H12_R12_z01_yellow',
#  'ark:59852/B2AI_2_Paclitaxel_H12_R12_z01_green',
#  'ark:59852/B2AI_5_Paclitaxel_H12_R11_z01_blue',
#  'ark:59852/B2AI_5_Paclitaxel_H12_R11_z01_red',
#  'ark:59852/B2AI_5_Paclitaxel_H12_R11_z01_yellow',
#  'ark:59852/B2AI_5_Paclitaxel_H12_R11_z01_green',
#  'ark:59852/B2AI_3_Paclitaxel_H12_R11_z00_blue',
#  'ark:59852/B2AI_3_Paclitaxel_H12_R11_z00_red',
#  'ark:59852/B2AI_3_Paclitaxel_H12_R11_z00_yellow',
#  'ark:59852/B2AI_3_Paclitaxel_H12_R11_z00_green',
#  'ark:59852/B2AI_2_Paclitaxel_H12_R11_z02_blue',
#  'ark:59852/B2AI_2_Paclitaxel_H12_R11_z02_red',
#  'ark:59852/B2AI_2_Paclitaxel_H12_R11_z02_yellow',
#  'ark:59852/B2AI_2_Paclitaxel_H12_R11_z02_green',
#  'ark:59852/B2AI_5_Paclitaxel_H12_R1_z01_blue',
#  'ark:59852/B2AI_5_Paclitaxel_H12_R1_z01_red',
#  'ark:59852/B2AI_5_Paclitaxel_H12_R1_z01_yellow',
#  'ark:59852/B2AI_5_Paclitaxel_H12_R1_z01_green',
#  'ark:59852/B2AI_3_Paclitaxel_H12_R1_z00_blue',
#  'ark:59852/B2AI_3_Paclitaxel_H12_R1_z00_red',
#  'ark:59852/B2AI_3_Paclitaxel_H12_R1_z00_yellow',
#  'ark:59852/B2AI_3_Paclitaxel_H12_R1_z00_green',
#  'ark:59852/B2AI_2_Paclitaxel_H12_R1_z00_blue',
#  'ark:59852/B2AI_2_Paclitaxel_H12_R1_z00_red',
#  'ark:59852/B2AI_2_Paclitaxel_H12_R1_z00_yellow',
#  'ark:59852/B2AI_2_Paclitaxel_H12_R1_z00_green',
#  'ark:59852/B2AI_1_Paclitaxel_H12_R1_z01_blue',
#  'ark:59852/B2AI_1_Paclitaxel_H12_R1_z01_red',
#  'ark:59852/B2AI_1_Paclitaxel_H12_R1_z01_yellow',
#  'ark:59852/B2AI_1_Paclitaxel_H12_R1_z01_green',
#  'ark:59852/B2AI_3_Paclitaxel_G12_R8_z02_blue',
#  'ark:59852/B2AI_3_Paclitaxel_G12_R8_z02_red',
#  'ark:59852/B2AI_3_Paclitaxel_G12_R8_z02_yellow',
#  'ark:59852/B2AI_3_Paclitaxel_G12_R8_z02_green',
#  'ark:59852/B2AI_3_Paclitaxel_G12_R6_z01_blue',
#  'ark:59852/B2AI_3_Paclitaxel_G12_R6_z01_red',
#  'ark:59852/B2AI_3_Paclitaxel_G12_R6_z01_yellow',
#  'ark:59852/B2AI_3_Paclitaxel_G12_R6_z01_green',
#  'ark:59852/B2AI_3_Paclitaxel_G12_R5_z02_blue',
#  'ark:59852/B2AI_3_Paclitaxel_G12_R5_z02_red',
#  'ark:59852/B2AI_3_Paclitaxel_G12_R5_z02_yellow',
#  'ark:59852/B2AI_3_Paclitaxel_G12_R5_z02_green',
#  'ark:59852/B2AI_3_Paclitaxel_G12_R4_z02_blue',
#  'ark:59852/B2AI_3_Paclitaxel_G12_R4_z02_red',
#  'ark:59852/B2AI_3_Paclitaxel_G12_R4_z02_yellow',
#  'ark:59852/B2AI_3_Paclitaxel_G12_R4_z02_green',
#  'ark:59852/B2AI_3_Paclitaxel_G12_R17_z01_blue',
#  'ark:59852/B2AI_3_Paclitaxel_G12_R17_z01_red',
#  'ark:59852/B2AI_3_Paclitaxel_G12_R17_z01_yellow',
#  'ark:59852/B2AI_3_Paclitaxel_G12_R17_z01_green',
#  'ark:59852/B2AI_3_Paclitaxel_G12_R13_z01_blue',
#  'ark:59852/B2AI_3_Paclitaxel_G12_R13_z01_red',
#  'ark:59852/B2AI_3_Paclitaxel_G12_R13_z01_yellow',
#  'ark:59852/B2AI_3_Paclitaxel_G12_R13_z01_green',
#  'ark:59852/B2AI_3_Paclitaxel_G12_R12_z00_blue',
#  'ark:59852/B2AI_3_Paclitaxel_G12_R12_z00_red',
#  'ark:59852/B2AI_3_Paclitaxel_G12_R12_z00_yellow',
#  'ark:59852/B2AI_3_Paclitaxel_G12_R12_z00_green',
#  'ark:59852/B2AI_3_Paclitaxel_G12_R11_z00_blue',
#  'ark:59852/B2AI_3_Paclitaxel_G12_R11_z00_red',
#  'ark:59852/B2AI_3_Paclitaxel_G12_R11_z00_yellow',
#  'ark:59852/B2AI_3_Paclitaxel_G12_R11_z00_green',
#  'ark:59852/B2AI_3_Paclitaxel_G12_R1_z00_blue',
#  'ark:59852/B2AI_3_Paclitaxel_G12_R1_z00_red',
#  'ark:59852/B2AI_3_Paclitaxel_G12_R1_z00_yellow',
#  'ark:59852/B2AI_3_Paclitaxel_G12_R1_z00_green',
#  'ark:59852/B2AI_1_Paclitaxel_F7_R8_z01_blue',
#  'ark:59852/B2AI_1_Paclitaxel_F7_R8_z01_red',
#  'ark:59852/B2AI_1_Paclitaxel_F7_R8_z01_yellow',
#  'ark:59852/B2AI_1_Paclitaxel_F7_R8_z01_green',
#  'ark:59852/B2AI_1_Paclitaxel_F7_R7_z00_blue',
#  'ark:59852/B2AI_1_Paclitaxel_F7_R7_z00_red',
#  'ark:59852/B2AI_1_Paclitaxel_F7_R7_z00_yellow',
#  'ark:59852/B2AI_1_Paclitaxel_F7_R7_z00_green',
#  'ark:59852/B2AI_1_Paclitaxel_F7_R6_z00_blue',
#  'ark:59852/B2AI_1_Paclitaxel_F7_R6_z00_red',
#  'ark:59852/B2AI_1_Paclitaxel_F7_R6_z00_yellow',
#  'ark:59852/B2AI_1_Paclitaxel_F7_R6_z00_green',
#  'ark:59852/B2AI_1_Paclitaxel_F7_R5_z01_blue',
#  'ark:59852/B2AI_1_Paclitaxel_F7_R5_z01_red',
#  'ark:59852/B2AI_1_Paclitaxel_F7_R5_z01_yellow',
#  'ark:59852/B2AI_1_Paclitaxel_F7_R5_z01_green',
#  'ark:59852/B2AI_1_Paclitaxel_F7_R4_z01_blue',
#  'ark:59852/B2AI_1_Paclitaxel_F7_R4_z01_red',
#  'ark:59852/B2AI_1_Paclitaxel_F7_R4_z01_yellow',
#  'ark:59852/B2AI_1_Paclitaxel_F7_R4_z01_green',
#  'ark:59852/B2AI_1_Paclitaxel_F7_R3_z01_blue',
#  'ark:59852/B2AI_1_Paclitaxel_F7_R3_z01_red',
#  'ark:59852/B2AI_1_Paclitaxel_F7_R3_z01_yellow',
#  'ark:59852/B2AI_1_Paclitaxel_F7_R3_z01_green',
#  'ark:59852/B2AI_1_Paclitaxel_F7_R2_z01_blue',
#  'ark:59852/B2AI_1_Paclitaxel_F7_R2_z01_red',
#  'ark:59852/B2AI_1_Paclitaxel_F7_R2_z01_yellow',
#  'ark:59852/B2AI_1_Paclitaxel_F7_R2_z01_green',
#  'ark:59852/B2AI_1_Paclitaxel_F7_R1_z00_blue',
#  'ark:59852/B2AI_1_Paclitaxel_F7_R1_z00_red',
#  'ark:59852/B2AI_1_Paclitaxel_F7_R1_z00_yellow',
#  'ark:59852/B2AI_1_Paclitaxel_F7_R1_z00_green',
#  'ark:59852/B2AI_5_Paclitaxel_G12_R8_z02_blue',
#  'ark:59852/B2AI_5_Paclitaxel_G12_R8_z02_red',
#  'ark:59852/B2AI_5_Paclitaxel_G12_R8_z02_yellow',
#  'ark:59852/B2AI_5_Paclitaxel_G12_R8_z02_green',
#  'ark:59852/B2AI_5_Paclitaxel_G12_R6_z00_blue',
#  'ark:59852/B2AI_5_Paclitaxel_G12_R6_z00_red',
#  'ark:59852/B2AI_5_Paclitaxel_G12_R6_z00_yellow',
#  'ark:59852/B2AI_5_Paclitaxel_G12_R6_z00_green',
#  'ark:59852/B2AI_5_Paclitaxel_G12_R5_z01_blue',
#  'ark:59852/B2AI_5_Paclitaxel_G12_R5_z01_red',
#  'ark:59852/B2AI_5_Paclitaxel_G12_R5_z01_yellow',
#  'ark:59852/B2AI_5_Paclitaxel_G12_R5_z01_green',
#  'ark:59852/B2AI_5_Paclitaxel_G12_R3_z01_blue',
#  'ark:59852/B2AI_5_Paclitaxel_G12_R3_z01_red',
#  'ark:59852/B2AI_5_Paclitaxel_G12_R3_z01_yellow',
#  'ark:59852/B2AI_5_Paclitaxel_G12_R3_z01_green',
#  'ark:59852/B2AI_5_Paclitaxel_G12_R28_z01_blue',
#  'ark:59852/B2AI_5_Paclitaxel_G12_R28_z01_red',
#  'ark:59852/B2AI_5_Paclitaxel_G12_R28_z01_yellow',
#  'ark:59852/B2AI_5_Paclitaxel_G12_R28_z01_green',
#  'ark:59852/B2AI_5_Paclitaxel_G12_R27_z01_blue',
#  'ark:59852/B2AI_5_Paclitaxel_G12_R27_z01_red',
#  'ark:59852/B2AI_5_Paclitaxel_G12_R27_z01_yellow',
#  'ark:59852/B2AI_5_Paclitaxel_G12_R27_z01_green',
#  'ark:59852/B2AI_5_Paclitaxel_G12_R26_z01_blue',
#  'ark:59852/B2AI_5_Paclitaxel_G12_R26_z01_red',
#  'ark:59852/B2AI_5_Paclitaxel_G12_R26_z01_yellow',
#  'ark:59852/B2AI_5_Paclitaxel_G12_R26_z01_green',
#  'ark:59852/B2AI_5_Paclitaxel_G12_R2_z01_blue',
#  'ark:59852/B2AI_5_Paclitaxel_G12_R2_z01_red',
#  'ark:59852/B2AI_5_Paclitaxel_G12_R2_z01_yellow',
#  'ark:59852/B2AI_5_Paclitaxel_G12_R2_z01_green',
#  'ark:59852/B2AI_5_Paclitaxel_G12_R17_z01_blue',
#  'ark:59852/B2AI_5_Paclitaxel_G12_R17_z01_red',
#  'ark:59852/B2AI_5_Paclitaxel_G12_R17_z01_yellow',
#  'ark:59852/B2AI_5_Paclitaxel_G12_R17_z01_green',
#  'ark:59852/B2AI_5_Paclitaxel_G12_R13_z00_blue',
#  'ark:59852/B2AI_5_Paclitaxel_G12_R13_z00_red',
#  'ark:59852/B2AI_5_Paclitaxel_G12_R13_z00_yellow',
#  'ark:59852/B2AI_5_Paclitaxel_G12_R13_z00_green',
#  'ark:59852/B2AI_5_Paclitaxel_G12_R12_z01_blue',
#  'ark:59852/B2AI_5_Paclitaxel_G12_R12_z01_red',
#  'ark:59852/B2AI_5_Paclitaxel_G12_R12_z01_yellow',
#  'ark:59852/B2AI_5_Paclitaxel_G12_R12_z01_green',
#  'ark:59852/B2AI_5_Paclitaxel_G12_R11_z00_blue',
#  'ark:59852/B2AI_5_Paclitaxel_G12_R11_z00_red',
#  'ark:59852/B2AI_5_Paclitaxel_G12_R11_z00_yellow',
#  'ark:59852/B2AI_5_Paclitaxel_G12_R11_z00_green',
#  'ark:59852/B2AI_5_Paclitaxel_G12_R1_z01_blue',
#  'ark:59852/B2AI_5_Paclitaxel_G12_R1_z01_red',
#  'ark:59852/B2AI_5_Paclitaxel_G12_R1_z01_yellow',
#  'ark:59852/B2AI_5_Paclitaxel_G12_R1_z01_green',
#  'ark:59852/B2AI_2_Paclitaxel_G12_R8_z02_blue',
#  'ark:59852/B2AI_2_Paclitaxel_G12_R8_z02_red',
#  'ark:59852/B2AI_2_Paclitaxel_G12_R8_z02_yellow',
#  'ark:59852/B2AI_2_Paclitaxel_G12_R8_z02_green',
#  'ark:59852/B2AI_2_Paclitaxel_G12_R7_z02_blue',
#  'ark:59852/B2AI_2_Paclitaxel_G12_R7_z02_red',
#  'ark:59852/B2AI_2_Paclitaxel_G12_R7_z02_yellow',
#  'ark:59852/B2AI_2_Paclitaxel_G12_R7_z02_green',
#  'ark:59852/B2AI_2_Paclitaxel_G12_R6_z02_blue',
#  'ark:59852/B2AI_2_Paclitaxel_G12_R6_z02_red',
#  'ark:59852/B2AI_2_Paclitaxel_G12_R6_z02_yellow',
#  'ark:59852/B2AI_2_Paclitaxel_G12_R6_z02_green',
#  'ark:59852/B2AI_2_Paclitaxel_G12_R5_z02_blue',
#  'ark:59852/B2AI_2_Paclitaxel_G12_R5_z02_red',
#  'ark:59852/B2AI_2_Paclitaxel_G12_R5_z02_yellow',
#  'ark:59852/B2AI_2_Paclitaxel_G12_R5_z02_green',
#  'ark:59852/B2AI_2_Paclitaxel_G12_R4_z02_blue',
#  'ark:59852/B2AI_2_Paclitaxel_G12_R4_z02_red',
#  'ark:59852/B2AI_2_Paclitaxel_G12_R4_z02_yellow',
#  'ark:59852/B2AI_2_Paclitaxel_G12_R4_z02_green',
#  'ark:59852/B2AI_2_Paclitaxel_G12_R2_z02_blue',
#  'ark:59852/B2AI_2_Paclitaxel_G12_R2_z02_red',
#  'ark:59852/B2AI_2_Paclitaxel_G12_R2_z02_yellow',
#  'ark:59852/B2AI_2_Paclitaxel_G12_R2_z02_green',
#  'ark:59852/B2AI_2_Paclitaxel_G12_R17_z00_blue',
#  'ark:59852/B2AI_2_Paclitaxel_G12_R17_z00_red',
#  'ark:59852/B2AI_2_Paclitaxel_G12_R17_z00_yellow',
#  'ark:59852/B2AI_2_Paclitaxel_G12_R17_z00_green',
#  'ark:59852/B2AI_2_Paclitaxel_G12_R13_z01_blue',
#  'ark:59852/B2AI_2_Paclitaxel_G12_R13_z01_red',
#  'ark:59852/B2AI_2_Paclitaxel_G12_R13_z01_yellow',
#  'ark:59852/B2AI_2_Paclitaxel_G12_R13_z01_green',
#  'ark:59852/B2AI_2_Paclitaxel_G12_R12_z01_blue',
#  'ark:59852/B2AI_2_Paclitaxel_G12_R12_z01_red',
#  'ark:59852/B2AI_2_Paclitaxel_G12_R12_z01_yellow',
#  'ark:59852/B2AI_2_Paclitaxel_G12_R12_z01_green',
#  'ark:59852/B2AI_2_Paclitaxel_G12_R1_z02_blue',
#  'ark:59852/B2AI_2_Paclitaxel_G12_R1_z02_red',
#  'ark:59852/B2AI_2_Paclitaxel_G12_R1_z02_yellow',
#  'ark:59852/B2AI_2_Paclitaxel_G12_R1_z02_green',
#  'ark:59852/B2AI_3_Paclitaxel_F12_R8_z00_blue',
#  'ark:59852/B2AI_3_Paclitaxel_F12_R8_z00_red',
#  'ark:59852/B2AI_3_Paclitaxel_F12_R8_z00_yellow',
#  'ark:59852/B2AI_3_Paclitaxel_F12_R8_z00_green',
#  'ark:59852/B2AI_3_Paclitaxel_F12_R7_z00_blue',
#  'ark:59852/B2AI_3_Paclitaxel_F12_R7_z00_red',
#  'ark:59852/B2AI_3_Paclitaxel_F12_R7_z00_yellow',
#  'ark:59852/B2AI_3_Paclitaxel_F12_R7_z00_green',
#  'ark:59852/B2AI_3_Paclitaxel_F12_R6_z01_blue',
#  'ark:59852/B2AI_3_Paclitaxel_F12_R6_z01_red',
#  'ark:59852/B2AI_3_Paclitaxel_F12_R6_z01_yellow',
#  'ark:59852/B2AI_3_Paclitaxel_F12_R6_z01_green',
#  'ark:59852/B2AI_3_Paclitaxel_F12_R5_z02_blue',
#  'ark:59852/B2AI_3_Paclitaxel_F12_R5_z02_red',
#  'ark:59852/B2AI_3_Paclitaxel_F12_R5_z02_yellow',
#  'ark:59852/B2AI_3_Paclitaxel_F12_R5_z02_green',
#  'ark:59852/B2AI_3_Paclitaxel_F12_R3_z02_blue',
#  'ark:59852/B2AI_3_Paclitaxel_F12_R3_z02_red',
#  'ark:59852/B2AI_3_Paclitaxel_F12_R3_z02_yellow',
#  'ark:59852/B2AI_3_Paclitaxel_F12_R3_z02_green',
#  'ark:59852/B2AI_3_Paclitaxel_F12_R2_z01_blue',
#  'ark:59852/B2AI_3_Paclitaxel_F12_R2_z01_red',
#  'ark:59852/B2AI_3_Paclitaxel_F12_R2_z01_yellow',
#  'ark:59852/B2AI_3_Paclitaxel_F12_R2_z01_green',
#  'ark:59852/B2AI_3_Paclitaxel_F12_R14_z01_blue',
#  'ark:59852/B2AI_3_Paclitaxel_F12_R14_z01_red',
#  'ark:59852/B2AI_3_Paclitaxel_F12_R14_z01_yellow',
#  'ark:59852/B2AI_3_Paclitaxel_F12_R14_z01_green',
#  'ark:59852/B2AI_3_Paclitaxel_F12_R13_z01_blue',
#  'ark:59852/B2AI_3_Paclitaxel_F12_R13_z01_red',
#  'ark:59852/B2AI_3_Paclitaxel_F12_R13_z01_yellow',
#  'ark:59852/B2AI_3_Paclitaxel_F12_R13_z01_green',
#  'ark:59852/B2AI_3_Paclitaxel_F12_R12_z01_blue',
#  'ark:59852/B2AI_3_Paclitaxel_F12_R12_z01_red',
#  'ark:59852/B2AI_3_Paclitaxel_F12_R12_z01_yellow',
#  'ark:59852/B2AI_3_Paclitaxel_F12_R12_z01_green',
#  'ark:59852/B2AI_3_Paclitaxel_F12_R11_z00_blue',
#  'ark:59852/B2AI_3_Paclitaxel_F12_R11_z00_red',
#  'ark:59852/B2AI_3_Paclitaxel_F12_R11_z00_yellow',
#  'ark:59852/B2AI_3_Paclitaxel_F12_R11_z00_green',
#  'ark:59852/B2AI_1_Paclitaxel_C12_R7_z00_blue',
#  'ark:59852/B2AI_1_Paclitaxel_C12_R7_z00_red',
#  'ark:59852/B2AI_1_Paclitaxel_C12_R7_z00_yellow',
#  'ark:59852/B2AI_1_Paclitaxel_C12_R7_z00_green',
#  'ark:59852/B2AI_1_Paclitaxel_C12_R2_z01_blue',
#  'ark:59852/B2AI_1_Paclitaxel_C12_R2_z01_red',
#  'ark:59852/B2AI_1_Paclitaxel_C12_R2_z01_yellow',
#  'ark:59852/B2AI_1_Paclitaxel_C12_R2_z01_green',
#  'ark:59852/B2AI_1_Paclitaxel_C12_R14_z01_blue',
#  'ark:59852/B2AI_1_Paclitaxel_C12_R14_z01_red',
#  'ark:59852/B2AI_1_Paclitaxel_C12_R14_z01_yellow',
#  'ark:59852/B2AI_1_Paclitaxel_C12_R14_z01_green',
#  'ark:59852/B2AI_1_Paclitaxel_C12_R13_z02_blue',
#  'ark:59852/B2AI_1_Paclitaxel_C12_R13_z02_red',
#  'ark:59852/B2AI_1_Paclitaxel_C12_R13_z02_yellow',
#  'ark:59852/B2AI_1_Paclitaxel_C12_R13_z02_green',
#  'ark:59852/B2AI_1_Paclitaxel_C12_R10_z02_blue',
#  'ark:59852/B2AI_1_Paclitaxel_C12_R10_z02_red',
#  'ark:59852/B2AI_1_Paclitaxel_C12_R10_z02_yellow',
#  'ark:59852/B2AI_1_Paclitaxel_C12_R10_z02_green',
#  'ark:59852/B2AI_1_Paclitaxel_C12_R1_z01_blue',
#  'ark:59852/B2AI_1_Paclitaxel_C12_R1_z01_red',
#  'ark:59852/B2AI_1_Paclitaxel_C12_R1_z01_yellow',
#  'ark:59852/B2AI_1_Paclitaxel_C12_R1_z01_green',
#  'ark:59852/B2AI_1_Paclitaxel_H7_R8_z01_blue',
#  'ark:59852/B2AI_1_Paclitaxel_H7_R8_z01_red',
#  'ark:59852/B2AI_1_Paclitaxel_H7_R8_z01_yellow',
#  'ark:59852/B2AI_1_Paclitaxel_H7_R8_z01_green',
#  'ark:59852/B2AI_1_Paclitaxel_H7_R7_z01_blue',
#  'ark:59852/B2AI_1_Paclitaxel_H7_R7_z01_red',
#  'ark:59852/B2AI_1_Paclitaxel_H7_R7_z01_yellow',
#  'ark:59852/B2AI_1_Paclitaxel_H7_R7_z01_green',
#  'ark:59852/B2AI_1_Paclitaxel_H7_R6_z01_blue',
#  'ark:59852/B2AI_1_Paclitaxel_H7_R6_z01_red',
#  'ark:59852/B2AI_1_Paclitaxel_H7_R6_z01_yellow',
#  'ark:59852/B2AI_1_Paclitaxel_H7_R6_z01_green',
#  'ark:59852/B2AI_1_Paclitaxel_H7_R5_z01_blue',
#  'ark:59852/B2AI_1_Paclitaxel_H7_R5_z01_red',
#  'ark:59852/B2AI_1_Paclitaxel_H7_R5_z01_yellow',
#  'ark:59852/B2AI_1_Paclitaxel_H7_R5_z01_green',
#  'ark:59852/B2AI_1_Paclitaxel_H7_R4_z01_blue',
#  'ark:59852/B2AI_1_Paclitaxel_H7_R4_z01_red',
#  'ark:59852/B2AI_1_Paclitaxel_H7_R4_z01_yellow',
#  'ark:59852/B2AI_1_Paclitaxel_H7_R4_z01_green',
#  'ark:59852/B2AI_1_Paclitaxel_H7_R3_z00_blue',
#  'ark:59852/B2AI_1_Paclitaxel_H7_R3_z00_red',
#  'ark:59852/B2AI_1_Paclitaxel_H7_R3_z00_yellow',
#  'ark:59852/B2AI_1_Paclitaxel_H7_R3_z00_green',
#  'ark:59852/B2AI_1_Paclitaxel_H7_R1_z00_blue',
#  'ark:59852/B2AI_1_Paclitaxel_H7_R1_z00_red',
#  'ark:59852/B2AI_1_Paclitaxel_H7_R1_z00_yellow',
#  'ark:59852/B2AI_1_Paclitaxel_H7_R1_z00_green',
#  'ark:59852/B2AI_4_Paclitaxel_G12_R8_z01_blue',
#  'ark:59852/B2AI_4_Paclitaxel_G12_R8_z01_red',
#  'ark:59852/B2AI_4_Paclitaxel_G12_R8_z01_yellow',
#  'ark:59852/B2AI_4_Paclitaxel_G12_R8_z01_green',
#  'ark:59852/B2AI_4_Paclitaxel_G12_R7_z02_blue',
#  'ark:59852/B2AI_4_Paclitaxel_G12_R7_z02_red',
#  'ark:59852/B2AI_4_Paclitaxel_G12_R7_z02_yellow',
#  'ark:59852/B2AI_4_Paclitaxel_G12_R7_z02_green',
#  'ark:59852/B2AI_4_Paclitaxel_G12_R6_z02_blue',
#  'ark:59852/B2AI_4_Paclitaxel_G12_R6_z02_red',
#  'ark:59852/B2AI_4_Paclitaxel_G12_R6_z02_yellow',
#  'ark:59852/B2AI_4_Paclitaxel_G12_R6_z02_green',
#  'ark:59852/B2AI_4_Paclitaxel_G12_R4_z01_blue',
#  'ark:59852/B2AI_4_Paclitaxel_G12_R4_z01_red',
#  'ark:59852/B2AI_4_Paclitaxel_G12_R4_z01_yellow',
#  'ark:59852/B2AI_4_Paclitaxel_G12_R4_z01_green',
#  'ark:59852/B2AI_4_Paclitaxel_G12_R3_z01_blue',
#  'ark:59852/B2AI_4_Paclitaxel_G12_R3_z01_red',
#  'ark:59852/B2AI_4_Paclitaxel_G12_R3_z01_yellow',
#  'ark:59852/B2AI_4_Paclitaxel_G12_R3_z01_green',
#  'ark:59852/B2AI_4_Paclitaxel_G12_R2_z00_blue',
#  'ark:59852/B2AI_4_Paclitaxel_G12_R2_z00_red',
#  'ark:59852/B2AI_4_Paclitaxel_G12_R2_z00_yellow',
#  'ark:59852/B2AI_4_Paclitaxel_G12_R2_z00_green',
#  'ark:59852/B2AI_4_Paclitaxel_G12_R1_z01_blue',
#  'ark:59852/B2AI_4_Paclitaxel_G12_R1_z01_red',
#  'ark:59852/B2AI_4_Paclitaxel_G12_R1_z01_yellow',
#  'ark:59852/B2AI_4_Paclitaxel_G12_R1_z01_green',
#  'ark:59852/B2AI_3_Paclitaxel_E12_R8_z01_blue',
#  'ark:59852/B2AI_3_Paclitaxel_E12_R8_z01_red',
#  'ark:59852/B2AI_3_Paclitaxel_E12_R8_z01_yellow',
#  'ark:59852/B2AI_3_Paclitaxel_E12_R8_z01_green',
#  'ark:59852/B2AI_3_Paclitaxel_E12_R7_z02_blue',
#  'ark:59852/B2AI_3_Paclitaxel_E12_R7_z02_red',
#  'ark:59852/B2AI_3_Paclitaxel_E12_R7_z02_yellow',
#  'ark:59852/B2AI_3_Paclitaxel_E12_R7_z02_green',
#  'ark:59852/B2AI_3_Paclitaxel_E12_R6_z02_blue',
#  'ark:59852/B2AI_3_Paclitaxel_E12_R6_z02_red',
#  'ark:59852/B2AI_3_Paclitaxel_E12_R6_z02_yellow',
#  'ark:59852/B2AI_3_Paclitaxel_E12_R6_z02_green',
#  'ark:59852/B2AI_3_Paclitaxel_E12_R5_z02_blue',
#  'ark:59852/B2AI_3_Paclitaxel_E12_R5_z02_red',
#  'ark:59852/B2AI_3_Paclitaxel_E12_R5_z02_yellow',
#  'ark:59852/B2AI_3_Paclitaxel_E12_R5_z02_green',
#  'ark:59852/B2AI_3_Paclitaxel_E12_R4_z02_blue',
#  'ark:59852/B2AI_3_Paclitaxel_E12_R4_z02_red',
#  'ark:59852/B2AI_3_Paclitaxel_E12_R4_z02_yellow',
#  'ark:59852/B2AI_3_Paclitaxel_E12_R4_z02_green',
#  'ark:59852/B2AI_3_Paclitaxel_E12_R3_z01_blue',
#  'ark:59852/B2AI_3_Paclitaxel_E12_R3_z01_red',
#  'ark:59852/B2AI_3_Paclitaxel_E12_R3_z01_yellow',
#  'ark:59852/B2AI_3_Paclitaxel_E12_R3_z01_green',
#  'ark:59852/B2AI_3_Paclitaxel_E12_R2_z02_blue',
#  'ark:59852/B2AI_3_Paclitaxel_E12_R2_z02_red',
#  'ark:59852/B2AI_3_Paclitaxel_E12_R2_z02_yellow',
#  'ark:59852/B2AI_3_Paclitaxel_E12_R2_z02_green',
#  'ark:59852/B2AI_3_Paclitaxel_E12_R14_z01_blue',
#  'ark:59852/B2AI_3_Paclitaxel_E12_R14_z01_red',
#  'ark:59852/B2AI_3_Paclitaxel_E12_R14_z01_yellow',
#  'ark:59852/B2AI_3_Paclitaxel_E12_R14_z01_green',
#  'ark:59852/B2AI_3_Paclitaxel_E12_R13_z01_blue',
#  'ark:59852/B2AI_3_Paclitaxel_E12_R13_z01_red',
#  'ark:59852/B2AI_3_Paclitaxel_E12_R13_z01_yellow',
#  'ark:59852/B2AI_3_Paclitaxel_E12_R13_z01_green',
#  'ark:59852/B2AI_3_Paclitaxel_E12_R12_z01_blue',
#  'ark:59852/B2AI_3_Paclitaxel_E12_R12_z01_red',
#  'ark:59852/B2AI_3_Paclitaxel_E12_R12_z01_yellow',
#  'ark:59852/B2AI_3_Paclitaxel_E12_R12_z01_green',
#  'ark:59852/B2AI_3_Paclitaxel_E12_R11_z01_blue',
#  'ark:59852/B2AI_3_Paclitaxel_E12_R11_z01_red',
#  'ark:59852/B2AI_3_Paclitaxel_E12_R11_z01_yellow',
#  'ark:59852/B2AI_3_Paclitaxel_E12_R11_z01_green',
#  'ark:59852/B2AI_4_Paclitaxel_F12_R8_z01_blue',
#  'ark:59852/B2AI_4_Paclitaxel_F12_R8_z01_red',
#  'ark:59852/B2AI_4_Paclitaxel_F12_R8_z01_yellow',
#  'ark:59852/B2AI_4_Paclitaxel_F12_R8_z01_green',
#  'ark:59852/B2AI_4_Paclitaxel_F12_R7_z01_blue',
#  'ark:59852/B2AI_4_Paclitaxel_F12_R7_z01_red',
#  'ark:59852/B2AI_4_Paclitaxel_F12_R7_z01_yellow',
#  'ark:59852/B2AI_4_Paclitaxel_F12_R7_z01_green',
#  'ark:59852/B2AI_4_Paclitaxel_F12_R5_z00_blue',
#  'ark:59852/B2AI_4_Paclitaxel_F12_R5_z00_red',
#  'ark:59852/B2AI_4_Paclitaxel_F12_R5_z00_yellow',
#  'ark:59852/B2AI_4_Paclitaxel_F12_R5_z00_green',
#  'ark:59852/B2AI_4_Paclitaxel_F12_R3_z02_blue',
#  'ark:59852/B2AI_4_Paclitaxel_F12_R3_z02_red',
#  'ark:59852/B2AI_4_Paclitaxel_F12_R3_z02_yellow',
#  'ark:59852/B2AI_4_Paclitaxel_F12_R3_z02_green',
#  'ark:59852/B2AI_4_Paclitaxel_F12_R14_z01_blue',
#  'ark:59852/B2AI_4_Paclitaxel_F12_R14_z01_red',
#  'ark:59852/B2AI_4_Paclitaxel_F12_R14_z01_yellow',
#  'ark:59852/B2AI_4_Paclitaxel_F12_R14_z01_green',
#  'ark:59852/B2AI_4_Paclitaxel_F12_R12_z02_blue',
#  'ark:59852/B2AI_4_Paclitaxel_F12_R12_z02_red',
#  'ark:59852/B2AI_4_Paclitaxel_F12_R12_z02_yellow',
#  'ark:59852/B2AI_4_Paclitaxel_F12_R12_z02_green',
#  'ark:59852/B2AI_4_Paclitaxel_F12_R1_z02_blue',
#  'ark:59852/B2AI_4_Paclitaxel_F12_R1_z02_red',
#  'ark:59852/B2AI_4_Paclitaxel_F12_R1_z02_yellow',
#  'ark:59852/B2AI_4_Paclitaxel_F12_R1_z02_green',
#  'ark:59852/B2AI_3_Paclitaxel_D12_R8_z01_blue',
#  'ark:59852/B2AI_3_Paclitaxel_D12_R8_z01_red',
#  'ark:59852/B2AI_3_Paclitaxel_D12_R8_z01_yellow',
#  'ark:59852/B2AI_3_Paclitaxel_D12_R8_z01_green',
#  'ark:59852/B2AI_3_Paclitaxel_D12_R7_z01_blue',
#  'ark:59852/B2AI_3_Paclitaxel_D12_R7_z01_red',
#  'ark:59852/B2AI_3_Paclitaxel_D12_R7_z01_yellow',
#  'ark:59852/B2AI_3_Paclitaxel_D12_R7_z01_green',
#  'ark:59852/B2AI_3_Paclitaxel_D12_R6_z02_blue',
#  'ark:59852/B2AI_3_Paclitaxel_D12_R6_z02_red',
#  'ark:59852/B2AI_3_Paclitaxel_D12_R6_z02_yellow',
#  'ark:59852/B2AI_3_Paclitaxel_D12_R6_z02_green',
#  'ark:59852/B2AI_3_Paclitaxel_D12_R5_z02_blue',
#  'ark:59852/B2AI_3_Paclitaxel_D12_R5_z02_red',
#  'ark:59852/B2AI_3_Paclitaxel_D12_R5_z02_yellow',
#  'ark:59852/B2AI_3_Paclitaxel_D12_R5_z02_green',
#  'ark:59852/B2AI_3_Paclitaxel_D12_R4_z01_blue',
#  'ark:59852/B2AI_3_Paclitaxel_D12_R4_z01_red',
#  'ark:59852/B2AI_3_Paclitaxel_D12_R4_z01_yellow',
#  'ark:59852/B2AI_3_Paclitaxel_D12_R4_z01_green',
#  'ark:59852/B2AI_3_Paclitaxel_D12_R3_z02_blue',
#  'ark:59852/B2AI_3_Paclitaxel_D12_R3_z02_red',
#  'ark:59852/B2AI_3_Paclitaxel_D12_R3_z02_yellow',
#  'ark:59852/B2AI_3_Paclitaxel_D12_R3_z02_green',
#  'ark:59852/B2AI_3_Paclitaxel_D12_R14_z00_blue',
#  'ark:59852/B2AI_3_Paclitaxel_D12_R14_z00_red',
#  'ark:59852/B2AI_3_Paclitaxel_D12_R14_z00_yellow',
#  'ark:59852/B2AI_3_Paclitaxel_D12_R14_z00_green',
#  'ark:59852/B2AI_3_Paclitaxel_D12_R13_z01_blue',
#  'ark:59852/B2AI_3_Paclitaxel_D12_R13_z01_red',
#  'ark:59852/B2AI_3_Paclitaxel_D12_R13_z01_yellow',
#  'ark:59852/B2AI_3_Paclitaxel_D12_R13_z01_green',
#  'ark:59852/B2AI_3_Paclitaxel_D12_R12_z00_blue',
#  'ark:59852/B2AI_3_Paclitaxel_D12_R12_z00_red',
#  'ark:59852/B2AI_3_Paclitaxel_D12_R12_z00_yellow',
#  'ark:59852/B2AI_3_Paclitaxel_D12_R12_z00_green',
#  'ark:59852/B2AI_3_Paclitaxel_D12_R11_z01_blue',
#  'ark:59852/B2AI_3_Paclitaxel_D12_R11_z01_red',
#  'ark:59852/B2AI_3_Paclitaxel_D12_R11_z01_yellow',
#  'ark:59852/B2AI_3_Paclitaxel_D12_R11_z01_green',
#  'ark:59852/B2AI_2_Paclitaxel_F12_R8_z02_blue',
#  'ark:59852/B2AI_2_Paclitaxel_F12_R8_z02_red',
#  'ark:59852/B2AI_2_Paclitaxel_F12_R8_z02_yellow',
#  'ark:59852/B2AI_2_Paclitaxel_F12_R8_z02_green',
#  'ark:59852/B2AI_2_Paclitaxel_F12_R7_z02_blue',
#  'ark:59852/B2AI_2_Paclitaxel_F12_R7_z02_red',
#  'ark:59852/B2AI_2_Paclitaxel_F12_R7_z02_yellow',
#  'ark:59852/B2AI_2_Paclitaxel_F12_R7_z02_green',
#  'ark:59852/B2AI_2_Paclitaxel_F12_R6_z02_blue',
#  'ark:59852/B2AI_2_Paclitaxel_F12_R6_z02_red',
#  'ark:59852/B2AI_2_Paclitaxel_F12_R6_z02_yellow',
#  'ark:59852/B2AI_2_Paclitaxel_F12_R6_z02_green',
#  'ark:59852/B2AI_2_Paclitaxel_F12_R5_z02_blue',
#  'ark:59852/B2AI_2_Paclitaxel_F12_R5_z02_red',
#  'ark:59852/B2AI_2_Paclitaxel_F12_R5_z02_yellow',
#  'ark:59852/B2AI_2_Paclitaxel_F12_R5_z02_green',
#  'ark:59852/B2AI_2_Paclitaxel_F12_R4_z02_blue',
#  'ark:59852/B2AI_2_Paclitaxel_F12_R4_z02_red',
#  'ark:59852/B2AI_2_Paclitaxel_F12_R4_z02_yellow',
#  'ark:59852/B2AI_2_Paclitaxel_F12_R4_z02_green',
#  'ark:59852/B2AI_2_Paclitaxel_F12_R3_z02_blue',
#  'ark:59852/B2AI_2_Paclitaxel_F12_R3_z02_red',
#  'ark:59852/B2AI_2_Paclitaxel_F12_R3_z02_yellow',
#  'ark:59852/B2AI_2_Paclitaxel_F12_R3_z02_green',
#  'ark:59852/B2AI_2_Paclitaxel_F12_R14_z01_blue',
#  'ark:59852/B2AI_2_Paclitaxel_F12_R14_z01_red',
#  'ark:59852/B2AI_2_Paclitaxel_F12_R14_z01_yellow',
#  'ark:59852/B2AI_2_Paclitaxel_F12_R14_z01_green',
#  'ark:59852/B2AI_2_Paclitaxel_F12_R13_z00_blue',
#  'ark:59852/B2AI_2_Paclitaxel_F12_R13_z00_red',
#  'ark:59852/B2AI_2_Paclitaxel_F12_R13_z00_yellow',
#  'ark:59852/B2AI_2_Paclitaxel_F12_R13_z00_green',
#  'ark:59852/B2AI_2_Paclitaxel_F12_R12_z01_blue',
#  'ark:59852/B2AI_2_Paclitaxel_F12_R12_z01_red',
#  'ark:59852/B2AI_2_Paclitaxel_F12_R12_z01_yellow',
#  'ark:59852/B2AI_2_Paclitaxel_F12_R12_z01_green',
#  'ark:59852/B2AI_3_Paclitaxel_C12_R8_z01_blue',
#  'ark:59852/B2AI_3_Paclitaxel_C12_R8_z01_red',
#  'ark:59852/B2AI_3_Paclitaxel_C12_R8_z01_yellow',
#  'ark:59852/B2AI_3_Paclitaxel_C12_R8_z01_green',
#  'ark:59852/B2AI_3_Paclitaxel_C12_R7_z02_blue',
#  'ark:59852/B2AI_3_Paclitaxel_C12_R7_z02_red',
#  'ark:59852/B2AI_3_Paclitaxel_C12_R7_z02_yellow',
#  'ark:59852/B2AI_3_Paclitaxel_C12_R7_z02_green',
#  'ark:59852/B2AI_3_Paclitaxel_C12_R6_z02_blue',
#  'ark:59852/B2AI_3_Paclitaxel_C12_R6_z02_red',
#  'ark:59852/B2AI_3_Paclitaxel_C12_R6_z02_yellow',
#  'ark:59852/B2AI_3_Paclitaxel_C12_R6_z02_green',
#  'ark:59852/B2AI_3_Paclitaxel_C12_R5_z02_blue',
#  'ark:59852/B2AI_3_Paclitaxel_C12_R5_z02_red',
#  'ark:59852/B2AI_3_Paclitaxel_C12_R5_z02_yellow',
#  'ark:59852/B2AI_3_Paclitaxel_C12_R5_z02_green',
#  'ark:59852/B2AI_3_Paclitaxel_C12_R4_z02_blue',
#  'ark:59852/B2AI_3_Paclitaxel_C12_R4_z02_red',
#  'ark:59852/B2AI_3_Paclitaxel_C12_R4_z02_yellow',
#  'ark:59852/B2AI_3_Paclitaxel_C12_R4_z02_green',
#  'ark:59852/B2AI_3_Paclitaxel_C12_R14_z01_blue',
#  'ark:59852/B2AI_3_Paclitaxel_C12_R14_z01_red',
#  'ark:59852/B2AI_3_Paclitaxel_C12_R14_z01_yellow',
#  'ark:59852/B2AI_3_Paclitaxel_C12_R14_z01_green',
#  'ark:59852/B2AI_1_Paclitaxel_G8_R8_z01_blue',
#  'ark:59852/B2AI_1_Paclitaxel_G8_R8_z01_red',
#  'ark:59852/B2AI_1_Paclitaxel_G8_R8_z01_yellow',
#  'ark:59852/B2AI_1_Paclitaxel_G8_R8_z01_green',
#  'ark:59852/B2AI_1_Paclitaxel_G8_R7_z01_blue',
#  'ark:59852/B2AI_1_Paclitaxel_G8_R7_z01_red',
#  'ark:59852/B2AI_1_Paclitaxel_G8_R7_z01_yellow',
#  'ark:59852/B2AI_1_Paclitaxel_G8_R7_z01_green',
#  'ark:59852/B2AI_1_Paclitaxel_G8_R5_z01_blue',
#  'ark:59852/B2AI_1_Paclitaxel_G8_R5_z01_red',
#  'ark:59852/B2AI_1_Paclitaxel_G8_R5_z01_yellow',
#  'ark:59852/B2AI_1_Paclitaxel_G8_R5_z01_green',
#  'ark:59852/B2AI_1_Paclitaxel_G8_R4_z02_blue',
#  'ark:59852/B2AI_1_Paclitaxel_G8_R4_z02_red',
#  'ark:59852/B2AI_1_Paclitaxel_G8_R4_z02_yellow',
#  'ark:59852/B2AI_1_Paclitaxel_G8_R4_z02_green',
#  'ark:59852/B2AI_1_Paclitaxel_G8_R3_z01_blue',
#  'ark:59852/B2AI_1_Paclitaxel_G8_R3_z01_red',
#  'ark:59852/B2AI_1_Paclitaxel_G8_R3_z01_yellow',
#  'ark:59852/B2AI_1_Paclitaxel_G8_R3_z01_green',
#  'ark:59852/B2AI_1_Paclitaxel_G8_R2_z01_blue',
#  'ark:59852/B2AI_1_Paclitaxel_G8_R2_z01_red',
#  'ark:59852/B2AI_1_Paclitaxel_G8_R2_z01_yellow',
#  'ark:59852/B2AI_1_Paclitaxel_G8_R2_z01_green',
#  'ark:59852/B2AI_1_Paclitaxel_G8_R1_z01_blue',
#  'ark:59852/B2AI_1_Paclitaxel_G8_R1_z01_red',
#  'ark:59852/B2AI_1_Paclitaxel_G8_R1_z01_yellow',
#  'ark:59852/B2AI_1_Paclitaxel_G8_R1_z01_green',
#  'ark:59852/B2AI_4_Paclitaxel_E12_R8_z01_blue',
#  'ark:59852/B2AI_4_Paclitaxel_E12_R8_z01_red',
#  'ark:59852/B2AI_4_Paclitaxel_E12_R8_z01_yellow',
#  'ark:59852/B2AI_4_Paclitaxel_E12_R8_z01_green',
#  'ark:59852/B2AI_4_Paclitaxel_E12_R7_z00_blue',
#  'ark:59852/B2AI_4_Paclitaxel_E12_R7_z00_red',
#  'ark:59852/B2AI_4_Paclitaxel_E12_R7_z00_yellow',
#  'ark:59852/B2AI_4_Paclitaxel_E12_R7_z00_green',
#  'ark:59852/B2AI_4_Paclitaxel_E12_R6_z02_blue',
#  'ark:59852/B2AI_4_Paclitaxel_E12_R6_z02_red',
#  'ark:59852/B2AI_4_Paclitaxel_E12_R6_z02_yellow',
#  'ark:59852/B2AI_4_Paclitaxel_E12_R6_z02_green',
#  'ark:59852/B2AI_4_Paclitaxel_E12_R5_z01_blue',
#  'ark:59852/B2AI_4_Paclitaxel_E12_R5_z01_red',
#  'ark:59852/B2AI_4_Paclitaxel_E12_R5_z01_yellow',
#  'ark:59852/B2AI_4_Paclitaxel_E12_R5_z01_green',
#  'ark:59852/B2AI_4_Paclitaxel_E12_R4_z01_blue',
#  'ark:59852/B2AI_4_Paclitaxel_E12_R4_z01_red',
#  'ark:59852/B2AI_4_Paclitaxel_E12_R4_z01_yellow',
#  'ark:59852/B2AI_4_Paclitaxel_E12_R4_z01_green',
#  'ark:59852/B2AI_4_Paclitaxel_E12_R3_z01_blue',
#  'ark:59852/B2AI_4_Paclitaxel_E12_R3_z01_red',
#  'ark:59852/B2AI_4_Paclitaxel_E12_R3_z01_yellow',
#  'ark:59852/B2AI_4_Paclitaxel_E12_R3_z01_green',
#  'ark:59852/B2AI_4_Paclitaxel_E12_R2_z02_blue',
#  'ark:59852/B2AI_4_Paclitaxel_E12_R2_z02_red',
#  'ark:59852/B2AI_4_Paclitaxel_E12_R2_z02_yellow',
#  'ark:59852/B2AI_4_Paclitaxel_E12_R2_z02_green',
#  'ark:59852/B2AI_4_Paclitaxel_E12_R12_z02_blue',
#  'ark:59852/B2AI_4_Paclitaxel_E12_R12_z02_red',
#  'ark:59852/B2AI_4_Paclitaxel_E12_R12_z02_yellow',
#  'ark:59852/B2AI_4_Paclitaxel_E12_R12_z02_green',
#  'ark:59852/B2AI_4_Paclitaxel_E12_R11_z02_blue',
#  'ark:59852/B2AI_4_Paclitaxel_E12_R11_z02_red',
#  'ark:59852/B2AI_4_Paclitaxel_E12_R11_z02_yellow',
#  'ark:59852/B2AI_4_Paclitaxel_E12_R11_z02_green',
#  'ark:59852/B2AI_4_Paclitaxel_E12_R1_z01_blue',
#  'ark:59852/B2AI_4_Paclitaxel_E12_R1_z01_red',
#  'ark:59852/B2AI_4_Paclitaxel_E12_R1_z01_yellow',
#  'ark:59852/B2AI_4_Paclitaxel_E12_R1_z01_green',
#  'ark:59852/B2AI_2_Paclitaxel_E12_R8_z02_blue',
#  'ark:59852/B2AI_2_Paclitaxel_E12_R8_z02_red',
#  'ark:59852/B2AI_2_Paclitaxel_E12_R8_z02_yellow',
#  'ark:59852/B2AI_2_Paclitaxel_E12_R8_z02_green',
#  'ark:59852/B2AI_2_Paclitaxel_E12_R7_z02_blue',
#  'ark:59852/B2AI_2_Paclitaxel_E12_R7_z02_red',
#  'ark:59852/B2AI_2_Paclitaxel_E12_R7_z02_yellow',
#  'ark:59852/B2AI_2_Paclitaxel_E12_R7_z02_green',
#  'ark:59852/B2AI_2_Paclitaxel_E12_R6_z02_blue',
#  'ark:59852/B2AI_2_Paclitaxel_E12_R6_z02_red',
#  'ark:59852/B2AI_2_Paclitaxel_E12_R6_z02_yellow',
#  'ark:59852/B2AI_2_Paclitaxel_E12_R6_z02_green',
#  'ark:59852/B2AI_2_Paclitaxel_E12_R5_z02_blue',
#  'ark:59852/B2AI_2_Paclitaxel_E12_R5_z02_red',
#  'ark:59852/B2AI_2_Paclitaxel_E12_R5_z02_yellow',
#  'ark:59852/B2AI_2_Paclitaxel_E12_R5_z02_green',
#  'ark:59852/B2AI_2_Paclitaxel_E12_R4_z02_blue',
#  'ark:59852/B2AI_2_Paclitaxel_E12_R4_z02_red',
#  'ark:59852/B2AI_2_Paclitaxel_E12_R4_z02_yellow',
#  'ark:59852/B2AI_2_Paclitaxel_E12_R4_z02_green',
#  'ark:59852/B2AI_2_Paclitaxel_E12_R2_z02_blue',
#  'ark:59852/B2AI_2_Paclitaxel_E12_R2_z02_red',
#  'ark:59852/B2AI_2_Paclitaxel_E12_R2_z02_yellow',
#  'ark:59852/B2AI_2_Paclitaxel_E12_R2_z02_green',
#  'ark:59852/B2AI_2_Paclitaxel_E12_R14_z01_blue',
#  'ark:59852/B2AI_2_Paclitaxel_E12_R14_z01_red',
#  'ark:59852/B2AI_2_Paclitaxel_E12_R14_z01_yellow',
#  'ark:59852/B2AI_2_Paclitaxel_E12_R14_z01_green',
#  'ark:59852/B2AI_2_Paclitaxel_E12_R13_z01_blue',
#  'ark:59852/B2AI_2_Paclitaxel_E12_R13_z01_red',
#  'ark:59852/B2AI_2_Paclitaxel_E12_R13_z01_yellow',
#  'ark:59852/B2AI_2_Paclitaxel_E12_R13_z01_green',
#  'ark:59852/B2AI_2_Paclitaxel_E12_R12_z02_blue',
#  'ark:59852/B2AI_2_Paclitaxel_E12_R12_z02_red',
#  'ark:59852/B2AI_2_Paclitaxel_E12_R12_z02_yellow',
#  'ark:59852/B2AI_2_Paclitaxel_E12_R12_z02_green',
#  'ark:59852/B2AI_2_Paclitaxel_E12_R11_z01_blue',
#  'ark:59852/B2AI_2_Paclitaxel_E12_R11_z01_red',
#  'ark:59852/B2AI_2_Paclitaxel_E12_R11_z01_yellow',
#  'ark:59852/B2AI_2_Paclitaxel_E12_R11_z01_green',
#  'ark:59852/B2AI_2_Paclitaxel_E12_R1_z01_blue',
#  'ark:59852/B2AI_2_Paclitaxel_E12_R1_z01_red',
#  'ark:59852/B2AI_2_Paclitaxel_E12_R1_z01_yellow',
#  'ark:59852/B2AI_2_Paclitaxel_E12_R1_z01_green',
#  'ark:59852/B2AI_5_Paclitaxel_F12_R6_z01_blue',
#  'ark:59852/B2AI_5_Paclitaxel_F12_R6_z01_red',
#  'ark:59852/B2AI_5_Paclitaxel_F12_R6_z01_yellow',
#  'ark:59852/B2AI_5_Paclitaxel_F12_R6_z01_green',
#  'ark:59852/B2AI_5_Paclitaxel_F12_R5_z01_blue',
#  'ark:59852/B2AI_5_Paclitaxel_F12_R5_z01_red',
#  'ark:59852/B2AI_5_Paclitaxel_F12_R5_z01_yellow',
#  'ark:59852/B2AI_5_Paclitaxel_F12_R5_z01_green',
#  'ark:59852/B2AI_5_Paclitaxel_F12_R3_z00_blue',
#  'ark:59852/B2AI_5_Paclitaxel_F12_R3_z00_red',
#  'ark:59852/B2AI_5_Paclitaxel_F12_R3_z00_yellow',
#  'ark:59852/B2AI_5_Paclitaxel_F12_R3_z00_green',
#  'ark:59852/B2AI_5_Paclitaxel_F12_R2_z01_blue',
#  'ark:59852/B2AI_5_Paclitaxel_F12_R2_z01_red',
#  'ark:59852/B2AI_5_Paclitaxel_F12_R2_z01_yellow',
#  'ark:59852/B2AI_5_Paclitaxel_F12_R2_z01_green',
#  'ark:59852/B2AI_5_Paclitaxel_F12_R16_z01_blue',
#  'ark:59852/B2AI_5_Paclitaxel_F12_R16_z01_red',
#  'ark:59852/B2AI_5_Paclitaxel_F12_R16_z01_yellow',
#  'ark:59852/B2AI_5_Paclitaxel_F12_R16_z01_green',
#  'ark:59852/B2AI_5_Paclitaxel_F12_R15_z01_blue',
#  'ark:59852/B2AI_5_Paclitaxel_F12_R15_z01_red',
#  'ark:59852/B2AI_5_Paclitaxel_F12_R15_z01_yellow',
#  'ark:59852/B2AI_5_Paclitaxel_F12_R15_z01_green',
#  'ark:59852/B2AI_5_Paclitaxel_F12_R14_z01_blue',
#  'ark:59852/B2AI_5_Paclitaxel_F12_R14_z01_red',
#  'ark:59852/B2AI_5_Paclitaxel_F12_R14_z01_yellow',
#  'ark:59852/B2AI_5_Paclitaxel_F12_R14_z01_green',
#  'ark:59852/B2AI_5_Paclitaxel_F12_R13_z00_blue',
#  'ark:59852/B2AI_5_Paclitaxel_F12_R13_z00_red',
#  'ark:59852/B2AI_5_Paclitaxel_F12_R13_z00_yellow',
#  'ark:59852/B2AI_5_Paclitaxel_F12_R13_z00_green',
#  'ark:59852/B2AI_5_Paclitaxel_F12_R12_z01_blue',
#  'ark:59852/B2AI_5_Paclitaxel_F12_R12_z01_red',
#  'ark:59852/B2AI_5_Paclitaxel_F12_R12_z01_yellow',
#  'ark:59852/B2AI_5_Paclitaxel_F12_R12_z01_green',
#  'ark:59852/B2AI_5_Paclitaxel_F12_R11_z01_blue',
#  'ark:59852/B2AI_5_Paclitaxel_F12_R11_z01_red',
#  'ark:59852/B2AI_5_Paclitaxel_F12_R11_z01_yellow',
#  'ark:59852/B2AI_5_Paclitaxel_F12_R11_z01_green',
#  'ark:59852/B2AI_5_Paclitaxel_F12_R1_z01_blue',
#  'ark:59852/B2AI_5_Paclitaxel_F12_R1_z01_red',
#  'ark:59852/B2AI_5_Paclitaxel_F12_R1_z01_yellow',
#  'ark:59852/B2AI_5_Paclitaxel_F12_R1_z01_green',
#  'ark:59852/B2AI_3_Paclitaxel_B12_R8_z00_blue',
#  'ark:59852/B2AI_3_Paclitaxel_B12_R8_z00_red',
#  'ark:59852/B2AI_3_Paclitaxel_B12_R8_z00_yellow',
#  'ark:59852/B2AI_3_Paclitaxel_B12_R8_z00_green',
#  'ark:59852/B2AI_3_Paclitaxel_B12_R5_z02_blue',
#  'ark:59852/B2AI_3_Paclitaxel_B12_R5_z02_red',
#  'ark:59852/B2AI_3_Paclitaxel_B12_R5_z02_yellow',
#  'ark:59852/B2AI_3_Paclitaxel_B12_R5_z02_green',
#  'ark:59852/B2AI_3_Paclitaxel_B12_R3_z01_blue',
#  'ark:59852/B2AI_3_Paclitaxel_B12_R3_z01_red',
#  'ark:59852/B2AI_3_Paclitaxel_B12_R3_z01_yellow',
#  'ark:59852/B2AI_3_Paclitaxel_B12_R3_z01_green',
#  'ark:59852/B2AI_3_Paclitaxel_B12_R13_z00_blue',
#  'ark:59852/B2AI_3_Paclitaxel_B12_R13_z00_red',
#  'ark:59852/B2AI_3_Paclitaxel_B12_R13_z00_yellow',
#  'ark:59852/B2AI_3_Paclitaxel_B12_R13_z00_green',
#  'ark:59852/B2AI_3_Paclitaxel_B12_R11_z00_blue',
#  'ark:59852/B2AI_3_Paclitaxel_B12_R11_z00_red',
#  'ark:59852/B2AI_3_Paclitaxel_B12_R11_z00_yellow',
#  'ark:59852/B2AI_3_Paclitaxel_B12_R11_z00_green',
#  'ark:59852/B2AI_3_Paclitaxel_B12_R1_z01_blue',
#  'ark:59852/B2AI_3_Paclitaxel_B12_R1_z01_red',
#  'ark:59852/B2AI_3_Paclitaxel_B12_R1_z01_yellow',
#  'ark:59852/B2AI_3_Paclitaxel_B12_R1_z01_green',
#  'ark:59852/B2AI_4_Paclitaxel_D12_R8_z01_blue',
#  'ark:59852/B2AI_4_Paclitaxel_D12_R8_z01_red',
#  'ark:59852/B2AI_4_Paclitaxel_D12_R8_z01_yellow',
#  'ark:59852/B2AI_4_Paclitaxel_D12_R8_z01_green',
#  'ark:59852/B2AI_4_Paclitaxel_D12_R7_z01_blue',
#  'ark:59852/B2AI_4_Paclitaxel_D12_R7_z01_red',
#  'ark:59852/B2AI_4_Paclitaxel_D12_R7_z01_yellow',
#  'ark:59852/B2AI_4_Paclitaxel_D12_R7_z01_green',
#  'ark:59852/B2AI_4_Paclitaxel_D12_R6_z01_blue',
#  'ark:59852/B2AI_4_Paclitaxel_D12_R6_z01_red',
#  'ark:59852/B2AI_4_Paclitaxel_D12_R6_z01_yellow',
#  'ark:59852/B2AI_4_Paclitaxel_D12_R6_z01_green',
#  'ark:59852/B2AI_4_Paclitaxel_D12_R4_z01_blue',
#  'ark:59852/B2AI_4_Paclitaxel_D12_R4_z01_red',
#  'ark:59852/B2AI_4_Paclitaxel_D12_R4_z01_yellow',
#  'ark:59852/B2AI_4_Paclitaxel_D12_R4_z01_green',
#  'ark:59852/B2AI_4_Paclitaxel_D12_R3_z01_blue',
#  'ark:59852/B2AI_4_Paclitaxel_D12_R3_z01_red',
#  'ark:59852/B2AI_4_Paclitaxel_D12_R3_z01_yellow',
#  'ark:59852/B2AI_4_Paclitaxel_D12_R3_z01_green',
#  'ark:59852/B2AI_4_Paclitaxel_D12_R2_z01_blue',
#  'ark:59852/B2AI_4_Paclitaxel_D12_R2_z01_red',
#  'ark:59852/B2AI_4_Paclitaxel_D12_R2_z01_yellow',
#  'ark:59852/B2AI_4_Paclitaxel_D12_R2_z01_green',
#  'ark:59852/B2AI_4_Paclitaxel_D12_R14_z01_blue',
#  'ark:59852/B2AI_4_Paclitaxel_D12_R14_z01_red',
#  'ark:59852/B2AI_4_Paclitaxel_D12_R14_z01_yellow',
#  'ark:59852/B2AI_4_Paclitaxel_D12_R14_z01_green',
#  'ark:59852/B2AI_4_Paclitaxel_D12_R13_z01_blue',
#  'ark:59852/B2AI_4_Paclitaxel_D12_R13_z01_red',
#  'ark:59852/B2AI_4_Paclitaxel_D12_R13_z01_yellow',
#  'ark:59852/B2AI_4_Paclitaxel_D12_R13_z01_green',
#  'ark:59852/B2AI_4_Paclitaxel_D12_R11_z01_blue',
#  'ark:59852/B2AI_4_Paclitaxel_D12_R11_z01_red',
#  'ark:59852/B2AI_4_Paclitaxel_D12_R11_z01_yellow',
#  'ark:59852/B2AI_4_Paclitaxel_D12_R11_z01_green',
#  'ark:59852/B2AI_4_Paclitaxel_D12_R1_z00_blue',
#  'ark:59852/B2AI_4_Paclitaxel_D12_R1_z00_red',
#  'ark:59852/B2AI_4_Paclitaxel_D12_R1_z00_yellow',
#  'ark:59852/B2AI_4_Paclitaxel_D12_R1_z00_green',
#  'ark:59852/B2AI_5_Paclitaxel_E12_R8_z02_blue',
#  'ark:59852/B2AI_5_Paclitaxel_E12_R8_z02_red',
#  'ark:59852/B2AI_5_Paclitaxel_E12_R8_z02_yellow',
#  'ark:59852/B2AI_5_Paclitaxel_E12_R8_z02_green',
#  'ark:59852/B2AI_5_Paclitaxel_E12_R7_z01_blue',
#  'ark:59852/B2AI_5_Paclitaxel_E12_R7_z01_red',
#  'ark:59852/B2AI_5_Paclitaxel_E12_R7_z01_yellow',
#  'ark:59852/B2AI_5_Paclitaxel_E12_R7_z01_green',
#  'ark:59852/B2AI_5_Paclitaxel_E12_R6_z01_blue',
#  'ark:59852/B2AI_5_Paclitaxel_E12_R6_z01_red',
#  'ark:59852/B2AI_5_Paclitaxel_E12_R6_z01_yellow',
#  'ark:59852/B2AI_5_Paclitaxel_E12_R6_z01_green',
#  'ark:59852/B2AI_5_Paclitaxel_E12_R5_z00_blue',
#  'ark:59852/B2AI_5_Paclitaxel_E12_R5_z00_red',
#  'ark:59852/B2AI_5_Paclitaxel_E12_R5_z00_yellow',
#  'ark:59852/B2AI_5_Paclitaxel_E12_R5_z00_green',
#  'ark:59852/B2AI_5_Paclitaxel_E12_R4_z00_blue',
#  'ark:59852/B2AI_5_Paclitaxel_E12_R4_z00_red',
#  'ark:59852/B2AI_5_Paclitaxel_E12_R4_z00_yellow',
#  'ark:59852/B2AI_5_Paclitaxel_E12_R4_z00_green',
#  'ark:59852/B2AI_5_Paclitaxel_E12_R3_z00_blue',
#  'ark:59852/B2AI_5_Paclitaxel_E12_R3_z00_red',
#  'ark:59852/B2AI_5_Paclitaxel_E12_R3_z00_yellow',
#  'ark:59852/B2AI_5_Paclitaxel_E12_R3_z00_green',
#  'ark:59852/B2AI_5_Paclitaxel_E12_R2_z00_blue',
#  'ark:59852/B2AI_5_Paclitaxel_E12_R2_z00_red',
#  'ark:59852/B2AI_5_Paclitaxel_E12_R2_z00_yellow',
#  'ark:59852/B2AI_5_Paclitaxel_E12_R2_z00_green',
#  'ark:59852/B2AI_5_Paclitaxel_E12_R12_z00_blue',
#  'ark:59852/B2AI_5_Paclitaxel_E12_R12_z00_red',
#  'ark:59852/B2AI_5_Paclitaxel_E12_R12_z00_yellow',
#  'ark:59852/B2AI_5_Paclitaxel_E12_R12_z00_green',
#  'ark:59852/B2AI_5_Paclitaxel_E12_R1_z00_blue',
#  'ark:59852/B2AI_5_Paclitaxel_E12_R1_z00_red',
#  'ark:59852/B2AI_5_Paclitaxel_E12_R1_z00_yellow',
#  'ark:59852/B2AI_5_Paclitaxel_E12_R1_z00_green',
#  'ark:59852/B2AI_4_Paclitaxel_C12_R8_z00_blue',
#  'ark:59852/B2AI_4_Paclitaxel_C12_R8_z00_red',
#  'ark:59852/B2AI_4_Paclitaxel_C12_R8_z00_yellow',
#  'ark:59852/B2AI_4_Paclitaxel_C12_R8_z00_green',
#  'ark:59852/B2AI_4_Paclitaxel_C12_R7_z01_blue',
#  'ark:59852/B2AI_4_Paclitaxel_C12_R7_z01_red',
#  'ark:59852/B2AI_4_Paclitaxel_C12_R7_z01_yellow',
#  'ark:59852/B2AI_4_Paclitaxel_C12_R7_z01_green',
#  'ark:59852/B2AI_4_Paclitaxel_C12_R6_z01_blue',
#  'ark:59852/B2AI_4_Paclitaxel_C12_R6_z01_red',
#  'ark:59852/B2AI_4_Paclitaxel_C12_R6_z01_yellow',
#  'ark:59852/B2AI_4_Paclitaxel_C12_R6_z01_green',
#  'ark:59852/B2AI_4_Paclitaxel_C12_R5_z01_blue',
#  'ark:59852/B2AI_4_Paclitaxel_C12_R5_z01_red',
#  'ark:59852/B2AI_4_Paclitaxel_C12_R5_z01_yellow',
#  'ark:59852/B2AI_4_Paclitaxel_C12_R5_z01_green',
#  'ark:59852/B2AI_4_Paclitaxel_C12_R4_z01_blue',
#  'ark:59852/B2AI_4_Paclitaxel_C12_R4_z01_red',
#  'ark:59852/B2AI_4_Paclitaxel_C12_R4_z01_yellow',
#  'ark:59852/B2AI_4_Paclitaxel_C12_R4_z01_green',
#  'ark:59852/B2AI_4_Paclitaxel_C12_R2_z01_blue',
#  'ark:59852/B2AI_4_Paclitaxel_C12_R2_z01_red',
#  'ark:59852/B2AI_4_Paclitaxel_C12_R2_z01_yellow',
#  'ark:59852/B2AI_4_Paclitaxel_C12_R2_z01_green',
#  'ark:59852/B2AI_4_Paclitaxel_C12_R14_z01_blue',
#  'ark:59852/B2AI_4_Paclitaxel_C12_R14_z01_red',
#  'ark:59852/B2AI_4_Paclitaxel_C12_R14_z01_yellow',
#  'ark:59852/B2AI_4_Paclitaxel_C12_R14_z01_green',
#  'ark:59852/B2AI_4_Paclitaxel_C12_R12_z02_blue',
#  'ark:59852/B2AI_4_Paclitaxel_C12_R12_z02_red',
#  'ark:59852/B2AI_4_Paclitaxel_C12_R12_z02_yellow',
#  'ark:59852/B2AI_4_Paclitaxel_C12_R12_z02_green',
#  'ark:59852/B2AI_4_Paclitaxel_C12_R11_z01_blue',
#  'ark:59852/B2AI_4_Paclitaxel_C12_R11_z01_red',
#  'ark:59852/B2AI_4_Paclitaxel_C12_R11_z01_yellow',
#  'ark:59852/B2AI_4_Paclitaxel_C12_R11_z01_green',
#  'ark:59852/B2AI_4_Paclitaxel_C12_R1_z01_blue',
#  'ark:59852/B2AI_4_Paclitaxel_C12_R1_z01_red',
#  'ark:59852/B2AI_4_Paclitaxel_C12_R1_z01_yellow',
#  'ark:59852/B2AI_4_Paclitaxel_C12_R1_z01_green',
#  'ark:59852/B2AI_2_Paclitaxel_D12_R8_z01_blue',
#  'ark:59852/B2AI_2_Paclitaxel_D12_R8_z01_red',
#  'ark:59852/B2AI_2_Paclitaxel_D12_R8_z01_yellow',
#  'ark:59852/B2AI_2_Paclitaxel_D12_R8_z01_green',
#  'ark:59852/B2AI_2_Paclitaxel_D12_R7_z02_blue',
#  'ark:59852/B2AI_2_Paclitaxel_D12_R7_z02_red',
#  'ark:59852/B2AI_2_Paclitaxel_D12_R7_z02_yellow',
#  'ark:59852/B2AI_2_Paclitaxel_D12_R7_z02_green',
#  'ark:59852/B2AI_2_Paclitaxel_D12_R6_z01_blue',
#  'ark:59852/B2AI_2_Paclitaxel_D12_R6_z01_red',
#  'ark:59852/B2AI_2_Paclitaxel_D12_R6_z01_yellow',
#  'ark:59852/B2AI_2_Paclitaxel_D12_R6_z01_green',
#  'ark:59852/B2AI_2_Paclitaxel_D12_R5_z02_blue',
#  'ark:59852/B2AI_2_Paclitaxel_D12_R5_z02_red',
#  'ark:59852/B2AI_2_Paclitaxel_D12_R5_z02_yellow',
#  'ark:59852/B2AI_2_Paclitaxel_D12_R5_z02_green',
#  'ark:59852/B2AI_2_Paclitaxel_D12_R4_z00_blue',
#  'ark:59852/B2AI_2_Paclitaxel_D12_R4_z00_red',
#  'ark:59852/B2AI_2_Paclitaxel_D12_R4_z00_yellow',
#  'ark:59852/B2AI_2_Paclitaxel_D12_R4_z00_green',
#  'ark:59852/B2AI_2_Paclitaxel_D12_R3_z01_blue',
#  'ark:59852/B2AI_2_Paclitaxel_D12_R3_z01_red',
#  'ark:59852/B2AI_2_Paclitaxel_D12_R3_z01_yellow',
#  'ark:59852/B2AI_2_Paclitaxel_D12_R3_z01_green',
#  'ark:59852/B2AI_2_Paclitaxel_D12_R2_z01_blue',
#  'ark:59852/B2AI_2_Paclitaxel_D12_R2_z01_red',
#  'ark:59852/B2AI_2_Paclitaxel_D12_R2_z01_yellow',
#  'ark:59852/B2AI_2_Paclitaxel_D12_R2_z01_green',
#  'ark:59852/B2AI_2_Paclitaxel_D12_R14_z01_blue',
#  'ark:59852/B2AI_2_Paclitaxel_D12_R14_z01_red',
#  'ark:59852/B2AI_2_Paclitaxel_D12_R14_z01_yellow',
#  'ark:59852/B2AI_2_Paclitaxel_D12_R14_z01_green',
#  'ark:59852/B2AI_2_Paclitaxel_D12_R13_z01_blue',
#  'ark:59852/B2AI_2_Paclitaxel_D12_R13_z01_red',
#  'ark:59852/B2AI_2_Paclitaxel_D12_R13_z01_yellow',
#  'ark:59852/B2AI_2_Paclitaxel_D12_R13_z01_green',
#  'ark:59852/B2AI_2_Paclitaxel_D12_R11_z01_blue',
#  'ark:59852/B2AI_2_Paclitaxel_D12_R11_z01_red',
#  'ark:59852/B2AI_2_Paclitaxel_D12_R11_z01_yellow',
#  'ark:59852/B2AI_2_Paclitaxel_D12_R11_z01_green',
#  'ark:59852/B2AI_2_Paclitaxel_D12_R1_z00_blue',
#  'ark:59852/B2AI_2_Paclitaxel_D12_R1_z00_red',
#  'ark:59852/B2AI_2_Paclitaxel_D12_R1_z00_yellow',
#  'ark:59852/B2AI_2_Paclitaxel_D12_R1_z00_green',
#  'ark:59852/B2AI_1_Paclitaxel_C9_R8_z01_blue',
#  'ark:59852/B2AI_1_Paclitaxel_C9_R8_z01_red',
#  'ark:59852/B2AI_1_Paclitaxel_C9_R8_z01_yellow',
#  'ark:59852/B2AI_1_Paclitaxel_C9_R8_z01_green',
#  'ark:59852/B2AI_1_Paclitaxel_C9_R7_z01_blue',
#  'ark:59852/B2AI_1_Paclitaxel_C9_R7_z01_red',
#  'ark:59852/B2AI_1_Paclitaxel_C9_R7_z01_yellow',
#  'ark:59852/B2AI_1_Paclitaxel_C9_R7_z01_green',
#  'ark:59852/B2AI_1_Paclitaxel_C9_R6_z01_blue',
#  'ark:59852/B2AI_1_Paclitaxel_C9_R6_z01_red',
#  'ark:59852/B2AI_1_Paclitaxel_C9_R6_z01_yellow',
#  'ark:59852/B2AI_1_Paclitaxel_C9_R6_z01_green',
#  'ark:59852/B2AI_1_Paclitaxel_C9_R5_z01_blue',
#  'ark:59852/B2AI_1_Paclitaxel_C9_R5_z01_red',
#  'ark:59852/B2AI_1_Paclitaxel_C9_R5_z01_yellow',
#  'ark:59852/B2AI_1_Paclitaxel_C9_R5_z01_green',
#  'ark:59852/B2AI_1_Paclitaxel_C9_R4_z01_blue',
#  'ark:59852/B2AI_1_Paclitaxel_C9_R4_z01_red',
#  'ark:59852/B2AI_1_Paclitaxel_C9_R4_z01_yellow',
#  'ark:59852/B2AI_1_Paclitaxel_C9_R4_z01_green',
#  'ark:59852/B2AI_1_Paclitaxel_C9_R3_z00_blue',
#  'ark:59852/B2AI_1_Paclitaxel_C9_R3_z00_red',
#  'ark:59852/B2AI_1_Paclitaxel_C9_R3_z00_yellow',
#  'ark:59852/B2AI_1_Paclitaxel_C9_R3_z00_green',
#  'ark:59852/B2AI_1_Paclitaxel_C9_R2_z01_blue',
#  'ark:59852/B2AI_1_Paclitaxel_C9_R2_z01_red',
#  'ark:59852/B2AI_1_Paclitaxel_C9_R2_z01_yellow',
#  'ark:59852/B2AI_1_Paclitaxel_C9_R2_z01_green',
#  'ark:59852/B2AI_1_Paclitaxel_E8_R8_z01_blue',
#  'ark:59852/B2AI_1_Paclitaxel_E8_R8_z01_red',
#  'ark:59852/B2AI_1_Paclitaxel_E8_R8_z01_yellow',
#  'ark:59852/B2AI_1_Paclitaxel_E8_R8_z01_green',
#  'ark:59852/B2AI_1_Paclitaxel_E8_R7_z01_blue',
#  'ark:59852/B2AI_1_Paclitaxel_E8_R7_z01_red',
#  'ark:59852/B2AI_1_Paclitaxel_E8_R7_z01_yellow',
#  'ark:59852/B2AI_1_Paclitaxel_E8_R7_z01_green',
#  'ark:59852/B2AI_1_Paclitaxel_E8_R5_z01_blue',
#  'ark:59852/B2AI_1_Paclitaxel_E8_R5_z01_red',
#  'ark:59852/B2AI_1_Paclitaxel_E8_R5_z01_yellow',
#  'ark:59852/B2AI_1_Paclitaxel_E8_R5_z01_green',
#  'ark:59852/B2AI_1_Paclitaxel_E8_R4_z01_blue',
#  'ark:59852/B2AI_1_Paclitaxel_E8_R4_z01_red',
#  'ark:59852/B2AI_1_Paclitaxel_E8_R4_z01_yellow',
#  'ark:59852/B2AI_1_Paclitaxel_E8_R4_z01_green',
#  'ark:59852/B2AI_1_Paclitaxel_E8_R3_z01_blue',
#  'ark:59852/B2AI_1_Paclitaxel_E8_R3_z01_red',
#  'ark:59852/B2AI_1_Paclitaxel_E8_R3_z01_yellow',
#  'ark:59852/B2AI_1_Paclitaxel_E8_R3_z01_green',
#  'ark:59852/B2AI_1_Paclitaxel_E8_R2_z01_blue',
#  'ark:59852/B2AI_1_Paclitaxel_E8_R2_z01_red',
#  'ark:59852/B2AI_1_Paclitaxel_E8_R2_z01_yellow',
#  'ark:59852/B2AI_1_Paclitaxel_E8_R2_z01_green',
#  'ark:59852/B2AI_1_Paclitaxel_E8_R1_z01_blue',
#  'ark:59852/B2AI_1_Paclitaxel_E8_R1_z01_red',
#  'ark:59852/B2AI_1_Paclitaxel_E8_R1_z01_yellow',
#  'ark:59852/B2AI_1_Paclitaxel_E8_R1_z01_green',
#  'ark:59852/B2AI_5_Paclitaxel_D12_R8_z00_blue',
#  'ark:59852/B2AI_5_Paclitaxel_D12_R8_z00_red',
#  'ark:59852/B2AI_5_Paclitaxel_D12_R8_z00_yellow',
#  'ark:59852/B2AI_5_Paclitaxel_D12_R8_z00_green',
#  'ark:59852/B2AI_5_Paclitaxel_D12_R7_z00_blue',
#  'ark:59852/B2AI_5_Paclitaxel_D12_R7_z00_red',
#  'ark:59852/B2AI_5_Paclitaxel_D12_R7_z00_yellow',
#  ...]

# %%
identifierCollection.delete_many({})
# Out:
# DeleteResult({'n': 18155, 'ok': 1.0}, acknowledged=True)

# %%
# choose ro-crate upload
rocrateZip = pathlib.Path("paclitaxel/paclitaxel.zip")

upload = fairscapeCrateUpload.uploadROCrate(
    userInstance=foundUser,
    rocrate=rocrateZip
)

# %%
upload
# Out:
# ROCrateUploadRequest(guid='ad2d3ef1-dd1d-4d9c-9034-cb9c4de46491', permissions=Permissions(owner='mal8ch@virginia.edu', group=None), uploadPath='fairscape/mal8ch/rocrates/paclitaxel.zip', timeStarted=datetime.datetime(2025, 5, 1, 14, 25, 44, 144273), timeFinished=None, completed=False, error=None, identifiersMinted=[])

# %%
# get the metadata from the zipped rocrate

# %%
#roCrateJSON

# %%
crateGUID = crateMetadata.guid

# %%
# get all datasets
datasetList = roCrateModel.getDatasets()
datasetElem = datasetList[0]

# %%
# helper function to get all contents inside a zipped crate when there are more than 1k objects
def getROCrateContentsMinio(s3Client, bucketName, zipCratePath: str):
    # list entire subdirectory for rocrate upload
    listObjects = s3Client.list_objects_v2(
        Bucket= bucketName,
        Prefix= str(zipCratePath) + '/'
    )

    objectList = listObjects['Contents']

    isTruncated = listObjects.get('IsTruncated')
    nextContinueToken = listObjects.get('NextContinuationToken')

    while isTruncated:

        listObjects = s3Client.list_objects_v2(
            Bucket = bucketName,
            Prefix = str(zippedCratePath) + '/',
            ContinuationToken = nextContinueToken
        )
        nextContinueToken = listObjects.get('NextContinuationToken')
        isTruncated = listObjects.get('IsTruncated')
        objectList= objectList + listObjects['Contents']

    return objectList

# %%
# set remainder of metadata for storage
def writeDatasets(
    identifierCollection, 
    userInstance: UserWriteModel, 
    rocrateInstance, 
    objectList
):
    
    datasetWriteList = []

    # TODO: set to userInstance for method
    permissionsSet = userInstance.getPermissions()

    for datasetElem in rocrateInstance.getDatasets():

        # TODO: handle when remote content is included in ROCrate
        #if 'http' in datasetElem.contentUrl:
        #    continue
            
        # match the metadata path to content
        datasetCratePath = datasetElem.contentUrl.lstrip('file:///')
        
        # filter function to match content url to key
        matchedElementList = list(
            filter(
            lambda x: datasetCratePath in x.get('Key'),
            objectList
            )
        )

        if len(matchedElementList)>0:
            matchedElement = matchedElementList[0]
        else:
            print(f"ContentNotFound: {datasetElem.guid}\tPath: {datasetElem.contentUrl}")
            continue
    
         # create metadata record to insert 
        objectSize = matchedElement.get('Size')
        objectPath = matchedElement.get('Key').lstrip(minioDefaultBucket + '/')
        
        # create distribution for metadata
        distribution = DatasetDistribution.model_validate({
            "distributionType": 'minio',
            "location": {"path": objectPath}
            })
        
        outputDataset = DatasetWriteModel.model_validate({
            **datasetElem.model_dump(by_alias=True),
            "permissions": permissionsSet, 
            "distribution": distribution,
            "size": objectSize,
            "isPartOf": {
                "@id": crateGUID,
            },
            
        })

        # insert all identifiers for datasets
        insertResult = identifierCollection.insert_one(
            outputDataset.model_dump(by_alias=True, mode='json')
        )

        # TODO: check insertResult for success

        # append guid to dataset list
        datasetWriteList.append(outputDataset.guid)
    
    return datasetWriteList

# %%
def writeMetadataElements(
    identifierCollection,
    userInstance,
    rocrateInstance
):
    # mint software and computation and biochem entity
    rocrateMetadataElements = rocrateInstance.getSoftware() + rocrateInstance.getComputations() + rocrateInstance.getSchemas() + \
        rocrateInstance.getBioChemEntities() + rocrateInstance.getMedicalConditions()

    userPermissions = userInstance.getPermissions()
    crateGUID = rocrateInstance.getCrateMetadata().guid
    
    # written identifiers
    guidList = []

    # mint all metadata elements
    for metadataModel in rocrateMetadataElements:

        insertDocument = {
            **metadataModel.model_dump(by_alias=True, mode='json'),
            'permissions': userPermissions.model_dump(mode='json'),
            'isPartOf': {"@id": crateGUID}
        }
        
        insertResult = identifierCollection.insert_one(
           insertDocument
        )

        # TODO check insertResult
        
        guidList.append(metadataModel.guid)
        
        
    return guidList

# %%
len(roCrateJSON['@graph'])
# Out:
# 18157

# %%
objectList
# Out:
# [{'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_A10_R12_z02_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 117738,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_A10_R13_z02_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 125429,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_A10_R6_z01_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 97221,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_A10_R7_z01_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 119901,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_A10_R8_z01_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 78040,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_A11_R10_z02_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 145163,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_A11_R6_z01_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 84992,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_A11_R7_z01_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 108175,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_A11_R8_z01_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 97702,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_A12_R10_z02_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 132332,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_A12_R11_z01_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 162057,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_A12_R12_z01_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 157598,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_A12_R13_z01_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 95627,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_A12_R14_z02_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 161758,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_A12_R15_z02_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 107008,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_A12_R2_z01_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 126351,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_A12_R7_z00_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 77919,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_A12_R8_z00_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 137217,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_A1_R2_z01_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 256505,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_A1_R5_z01_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 118164,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_A1_R6_z01_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 144380,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_A2_R11_z01_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 83059,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_A2_R12_z01_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 75148,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_A2_R14_z01_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 70799,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_A2_R17_z01_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 68345,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_A2_R18_z01_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 85167,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_A2_R5_z01_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 111649,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_A2_R7_z01_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 90255,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_A3_R11_z01_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 79863,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_A3_R15_z01_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 82804,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_A3_R17_z01_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 78707,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_A3_R18_z01_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 73923,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_A3_R19_z02_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 91586,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_A3_R1_z01_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 80119,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_A3_R2_z01_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 106286,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_A3_R6_z01_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 80229,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_A3_R7_z02_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 82092,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_A3_R8_z01_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 96556,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_A4_R2_z01_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 122439,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_A4_R3_z01_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 110586,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_A4_R4_z01_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 93231,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_A4_R5_z01_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 112336,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_A4_R6_z01_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 114858,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_A4_R7_z01_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 202248,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_A4_R8_z01_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 92315,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_A5_R17_z01_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 90360,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_A5_R4_z02_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 92829,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_A5_R5_z01_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 104401,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_A5_R8_z01_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 153156,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_A6_R1_z01_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 78354,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_A6_R3_z02_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 82460,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_A6_R4_z01_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 110994,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_A7_R15_z01_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 91850,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_A7_R3_z01_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 86188,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_A7_R5_z01_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 87057,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_A7_R8_z01_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 82677,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_A8_R3_z01_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 82602,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_A8_R6_z01_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 94635,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_A8_R7_z01_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 146496,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_A9_R10_z02_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 114302,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_A9_R1_z01_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 84273,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_A9_R3_z02_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 88699,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_A9_R4_z01_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 107717,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_A9_R6_z01_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 111663,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_A9_R7_z01_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 94486,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_A9_R8_z01_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 82376,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_B10_R2_z02_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 116338,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_B10_R4_z02_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 158005,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_B10_R5_z01_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 217932,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_B10_R6_z01_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 108943,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_B10_R7_z01_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 156293,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_B10_R8_z01_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 134401,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_B11_R1_z02_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 156146,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_B11_R2_z01_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 134016,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_B11_R3_z02_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 118143,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_B11_R4_z00_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 204015,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_B11_R5_z01_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 220985,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_B11_R6_z01_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 134078,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_B11_R7_z01_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 155794,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_B11_R8_z01_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 114497,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_B12_R2_z02_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 106261,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_B12_R3_z01_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 104749,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_B12_R5_z01_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 133851,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_B12_R8_z02_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 105143,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_B12_R9_z01_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 106222,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_B1_R11_z01_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 97260,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_B1_R12_z01_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 92416,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_B1_R13_z01_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 95804,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_B1_R14_z01_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 123783,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_B1_R15_z02_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 108599,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_B1_R17_z01_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 114820,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_B1_R1_z01_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 124868,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_B1_R3_z01_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 204192,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_B1_R4_z01_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 143684,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_B2_R2_z01_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 190618,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_B2_R3_z01_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 109063,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_B2_R4_z01_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 275197,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_B2_R5_z01_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 274061,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_B2_R6_z01_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 99569,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_B2_R7_z02_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 85675,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_B2_R8_z01_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 130138,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_B3_R1_z00_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 177698,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_B3_R2_z01_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 215358,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_B3_R4_z01_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 332924,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_B3_R5_z01_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 194586,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_B3_R8_z01_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 140036,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_B4_R4_z00_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 235648,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_B4_R5_z01_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 263018,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_B4_R6_z01_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 136979,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_B4_R7_z01_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 137868,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_B4_R8_z01_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 131578,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_B5_R1_z02_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 102300,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_B5_R2_z01_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 127798,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_B5_R3_z01_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 115628,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_B5_R4_z01_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 167299,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_B5_R5_z01_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 145500,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_B5_R7_z01_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 107035,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_B5_R8_z01_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 89544,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_B6_R1_z01_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 107681,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_B6_R2_z01_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 93155,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_B6_R4_z01_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 202049,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_B6_R5_z01_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 170959,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_B6_R6_z01_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 99149,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_B6_R7_z01_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 111799,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_B6_R8_z01_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 89338,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_B7_R2_z01_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 117608,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_B7_R4_z01_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 165535,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_B7_R5_z01_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 129239,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_B7_R6_z01_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 104361,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_B7_R7_z01_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 118996,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_B8_R1_z01_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 92298,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_B8_R2_z01_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 131860,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_B8_R3_z01_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 119850,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_B8_R4_z01_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 149695,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_B8_R5_z01_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 142909,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_B8_R6_z01_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 119398,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_B8_R7_z01_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 106068,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_B8_R8_z01_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 98775,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_B9_R1_z01_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 131236,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_B9_R2_z02_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 176815,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_B9_R4_z01_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 212739,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_B9_R5_z00_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 195887,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_B9_R6_z01_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 102807,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_B9_R7_z01_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 153279,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_B9_R8_z01_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 116202,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_C10_R1_z01_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 91069,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_C10_R2_z01_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 128726,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_C10_R4_z01_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 217486,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_C10_R5_z01_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 154774,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_C10_R7_z01_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 126956,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_C11_R1_z01_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 119746,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_C11_R2_z00_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 133742,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_C11_R3_z01_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 126778,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_C11_R4_z01_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 163986,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_C11_R5_z01_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 211040,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_C11_R6_z02_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 86226,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_C11_R7_z01_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 116692,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_C11_R8_z01_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 94030,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_C12_R10_z02_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 92427,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_C12_R13_z02_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 76212,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_C12_R14_z01_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 86085,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_C12_R1_z01_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 100715,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_C12_R2_z01_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 94595,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_C12_R7_z00_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 86085,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_C1_R1_z01_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 89314,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_C1_R2_z01_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 144852,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_C1_R3_z01_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 99202,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_C1_R4_z01_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 142608,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_C1_R6_z01_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 93936,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_C1_R8_z01_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 93021,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_C2_R2_z01_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 116845,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_C2_R3_z01_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 152269,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_C2_R4_z01_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 271461,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_C2_R5_z01_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 232480,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_C2_R6_z01_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 109323,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_C2_R7_z01_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 154766,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_C3_R2_z01_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 122138,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_C3_R3_z01_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 126362,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_C3_R4_z01_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 266936,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_C3_R5_z01_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 250273,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_C3_R6_z01_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 85603,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_C4_R1_z01_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 151689,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_C4_R2_z01_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 195348,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_C4_R4_z01_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 292299,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_C4_R7_z01_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 144897,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_C5_R1_z01_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 106553,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_C5_R2_z01_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 117690,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_C5_R3_z01_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 109555,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_C5_R4_z01_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
# ...
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_2_Paclitaxel_C4_R12_z01_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 90972,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_2_Paclitaxel_C4_R13_z02_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 125796,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_2_Paclitaxel_C4_R14_z01_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 108496,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_2_Paclitaxel_C4_R1_z02_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 100915,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_2_Paclitaxel_C4_R2_z01_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 85244,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_2_Paclitaxel_C4_R3_z02_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 84737,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_2_Paclitaxel_C4_R4_z01_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 110280,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_2_Paclitaxel_C4_R5_z01_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 121928,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_2_Paclitaxel_C4_R6_z00_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 110223,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_2_Paclitaxel_C4_R7_z02_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 84157,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_2_Paclitaxel_C4_R8_z01_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 91791,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_2_Paclitaxel_C5_R11_z01_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 80081,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_2_Paclitaxel_C5_R12_z02_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 96039,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_2_Paclitaxel_C5_R13_z01_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 73848,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_2_Paclitaxel_C5_R14_z02_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 93904,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_2_Paclitaxel_C5_R1_z01_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 101818,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_2_Paclitaxel_C5_R2_z01_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 91139,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_2_Paclitaxel_C5_R3_z02_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 85618,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_2_Paclitaxel_C5_R4_z02_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 97302,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_2_Paclitaxel_C5_R5_z02_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 110215,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_2_Paclitaxel_C5_R6_z02_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 83807,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_2_Paclitaxel_C5_R7_z02_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 95080,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_2_Paclitaxel_C5_R8_z01_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 97261,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_2_Paclitaxel_C6_R11_z02_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 86218,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_2_Paclitaxel_C6_R12_z01_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 84352,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_2_Paclitaxel_C6_R13_z02_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 103174,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_2_Paclitaxel_C6_R14_z01_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 78598,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_2_Paclitaxel_C6_R15_z00_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 121045,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_2_Paclitaxel_C6_R1_z02_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 92559,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_2_Paclitaxel_C6_R2_z02_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 81925,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_2_Paclitaxel_C6_R3_z02_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 80781,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_2_Paclitaxel_C6_R5_z02_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 105422,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_2_Paclitaxel_C6_R6_z01_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 78758,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_2_Paclitaxel_C6_R7_z01_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 96853,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_2_Paclitaxel_C6_R8_z01_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 66467,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_2_Paclitaxel_C7_R12_z01_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 98760,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_2_Paclitaxel_C7_R13_z02_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 82869,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_2_Paclitaxel_C7_R14_z01_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 94564,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_2_Paclitaxel_C7_R1_z02_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 84815,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_2_Paclitaxel_C7_R2_z02_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 87846,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_2_Paclitaxel_C7_R3_z02_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 106102,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_2_Paclitaxel_C7_R4_z01_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 105083,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_2_Paclitaxel_C7_R5_z02_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 119800,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_2_Paclitaxel_C7_R6_z02_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 84932,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_2_Paclitaxel_C7_R7_z02_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 86039,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_2_Paclitaxel_C7_R8_z01_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 86543,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_2_Paclitaxel_C8_R11_z01_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 83739,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_2_Paclitaxel_C8_R12_z01_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 84582,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_2_Paclitaxel_C8_R13_z01_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 87408,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_2_Paclitaxel_C8_R14_z01_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 89717,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_2_Paclitaxel_C8_R15_z00_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 97425,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_2_Paclitaxel_C8_R2_z01_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 102074,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_2_Paclitaxel_C8_R3_z01_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 81096,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_2_Paclitaxel_C8_R4_z01_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 116888,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_2_Paclitaxel_C8_R5_z01_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 89108,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_2_Paclitaxel_C8_R6_z02_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 103237,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_2_Paclitaxel_C8_R7_z02_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 107951,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_2_Paclitaxel_C9_R11_z01_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 83188,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_2_Paclitaxel_C9_R12_z02_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 109104,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_2_Paclitaxel_C9_R13_z01_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 98369,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_2_Paclitaxel_C9_R14_z00_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 120348,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_2_Paclitaxel_C9_R15_z00_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 82064,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'fairscape/mal8ch/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_2_Paclitaxel_C9_R1_z02_blue.jpg',
#   'LastModified': datetime.datetime(2025, 4, 30, 16, 55, 1, 454000, tzinfo=tzutc()),
#   'ETag': '',
#   'Size': 100832,
#   'StorageClass': 'STANDARD'},
#  ...]

# %%
roCrateHasPart = [ {"@id": elem.guid, "@type": elem.metadataType} for elem in datasetWriteList] + [ {"@id": elem.guid, "@type": elem.metadataType} for elem in rocrateMetadataElements]

foundUser.getPermissions()

# %%
# mint rocrateMetadata identifier
roCrateIdentifier = {
    **roCrateModel.getCrateMetadata().model_dump(by_alias=True, mode='json'),
    "permissions": foundUser.getPermissions().model_dump(),
    "hasPart": roCrateHasPart,
}

# insert rocrate metadata identifier
insertCrateMetadata = rocrateCollection.insert_one(roCrateIdentifier)
insertCrateMetadata

insertCrateIdentifier = identifierCollection.insert_one(roCrateIdentifier)
insertCrateIdentifier

# %%
# add to list of metadata to mint

# %%
# testing with expanded metadata
with open('paclitaxel/paclitaxel/ro-crate-metadata.json', 'r') as jsonfile:
    rocrateMetadata = json.load(jsonfile)

rocrate = ROCrateV1_2.validate_metadata_graph(rocrateMetadata)

# %%
insertResult
# Out:
# InsertOneResult(ObjectId('680956ffff6c5ca2e9f2d4fa'), acknowledged=True)

# %%
class FairscapeROCrateUpload(FairscapeRequest):
    pass

# %%
class FairscapeROCrateProcessing(FairscapeRequest):
    pass

# %% [markdown]
# #### ROCrate Tests

# %%
# metadata only ROCrate

# %%
# content and metadata ROCrate

# %%
# - outputOfROCrate
# - prov Relations between ROCrate

# %% [markdown]
# ## Resolver

# %%
EVIDatasetType = "https://w3id.org/EVI#Dataset"
EVIComputationType = "https://w3id.org/EVI#Computation"
EVISoftwareType = "https://w3id.org/EVI#Software"

def getElemByID(identifierCollection: pymongo.collection.Collection, guid: str):

    foundMetadata = identifierCollection.find_one({"@id": guid})

    if foundMetadata is None:
        return None

    match foundMetadata['@type']:
        case "https://w3id.org/EVI#Dataset":
            return DatasetWriteModel.model_validate(foundMetadata)

        case "https://w3id.org/EVI#Computation":
            return SoftwareWriteModel.model_validate(foundMetadata)

        case "https://w3id.org/EVI#Software":
            return SoftwareWriteModel.model_validate(foundMetadata)

# %% [markdown]
# ## Evidence Graph

# %% [markdown]
# ## Reasoninng

# %% [markdown]
# ### Miscelaneous

# %%
# correct format for all image elements
with open('paclitaxel/paclitaxel/ro-crate-metadata.json', 'r') as rocrateMetadataFile:
    crateJSON = json.load(rocrateMetadataFile)

element_list = list(filter(lambda x: x.get('@type') == 'EVI:Dataset' and x.get('format') is None, crateJSON['@graph']))
for elem in element_list:
    elem['format'] = 'image/jpeg'

    
with open('paclitaxel/paclitaxel/ro-crate-metadata.json', 'w') as rocrateMetadataFile:
    json.dump(crateJSON, rocrateMetadataFile)
