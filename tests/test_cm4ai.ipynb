# %%
import sys
import os

# %%
sys.path.append("C:\\\\Users\\Max\\Documents\\GitHub\\mds_python\\mds\\src")

# %%
from fairscape_mds.crud.rocrate import FairscapeROCrateRequest
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 from fairscape_mds.crud.rocrate import FairscapeROCrateRequest
#
# File C:\\Users\Max\Documents\GitHub\mds_python\mds\src\fairscape_mds\crud\rocrate.py:4
#       2 from fairscape_mds.models.user import Permissions, UserWriteModel, checkPermissions
#       3 from fairscape_mds.models.dataset import DatasetWriteModel, DatasetDistribution, DistributionTypeEnum
# ----> 4 from fairscape_mds.crud.fairscape_request import FairscapeRequest
#       5 from fairscape_mds.crud.fairscape_response import FairscapeResponse
#       6 from fairscape_mds.crud.identifier import deleteIdentifier
#
# File C:\\Users\Max\Documents\GitHub\mds_python\mds\src\fairscape_mds\crud\fairscape_request.py:1
# ----> 1 from fairscape_mds.core.config import FairscapeConfig
#       4 class FairscapeRequest():
#       5 	def __init__(
# ...

# %%
download_link = "https://ell-vault.stanford.edu/dav/jnhansen/www/B2AI/MDA-MB-468/CAB005042_EIF5A/B2AI_3_Paclitaxel_C2_R11/z00/B2AI_3_Paclitaxel_C2_R11_z00_blue_red_green.jpg"

# %%
paclitaxel = "/mnt/e/Work/Data/Uploads/upload_06_29_2025/paclitaxel.zip"
