# %%
import os
import sys
import pathlib

# %%
testPaths = pathlib.Path(".").absolute()
str(testPaths.parent)
# Out:
# 'c:\\Users\\Max\\Documents\\GitHub\\mds_python\\mds\\src\\fairscape_mds'

# %%
sys.path.append(str(testPaths.parent.parent))

# %%
from fairscape_mds.core.config import appConfig
from fairscape_mds.models.rocrate import ROCrateUploadRequest
from fairscape_mds.models.user import UserWriteModel, checkPermissions
from fairscape_mds.crud.rocrate import userPath, setDatasetObjectKey, FairscapeROCrateRequest
from fairscape_mds.crud.fairscape_request import FairscapeRequest
from fairscape_mds.crud.fairscape_response import FairscapeResponse
import uuid

# %%
userQuery = {
	"email": "test@example.org"
}

# %%
# get test user from database to 
userMetadata = appConfig.userCollection.find_one(
	userQuery, 
	projection={"_id": False}
	)

currentUser = UserWriteModel.model_validate(userMetadata)

# %%
# create a fairscape upload request
from pydantic import BaseModel, Field
from fairscape_mds.models.user import Permissions
from typing import Optional, Any, Dict
import datetime

class FairscapeUploadJob(BaseModel):
	guid: str = Field(alias="@id")
	presigned: bool 
	uploadPath: str
	fileSize: Optional[int] = Field(default=None)
	presignedUploadLink: Optional[Dict[str, Any]] = Field(default=None)
	permissions: Permissions
	timeStarted: Optional[datetime.datetime] = Field(default_factory=datetime.datetime.now)
	timeFinished: Optional[datetime.datetime] = Field(default=None)
	status: Optional[str] = Field(default=None)
	complete: bool 
	success: bool
	rocrateGUID: Optional[str] = Field(default=None)
	identifiersMinted: Optional[int] = Field(default=None)

# %%
def createUploadPresignedLink(s3_client, bucket_name, object_name, expiration=7200):

	presignedUploadLink = s3_client.generate_presigned_post(
			bucket_name, 
			object_name,
			Fields=None,
			ExpiresIn=expiration,
	)

	return presignedUploadLink

# %%
# upload request modification that gives presigned minio put url

class FairscapePresignedROCrateRequest(FairscapeRequest):

	def __init_(self, config):
		super().__init__(config)
		self.config = config

	def get(
			self,
			currentUser: UserWriteModel,
			jobGUID: str
	):
		jobMetadata = self.config.asyncCollection.find_one(
			{"@id": jobGUID},
			projection={"_id": False}
		)

		if not jobMetadata:
			return FairscapeResponse(
				success=False,
				statusCode=404,
				error={
					"message": f"upload job {jobGUID} not found",
					"error": "job not found",
					"@id": jobGUID 
				}
			)

		try:
			jobInstance = FairscapeUploadJob.model_validate(jobMetadata)
		except Exception as exc:
			return FairscapeResponse(
				success=False,
				statusCode=500,
				error= {
					"message": "error unmarshaling job metadata",
					"error": str(exc),
					"@id": jobGUID
				}
			)

		# check permissions on metadata
		if checkPermissions(jobInstance.permissions, currentUser):
			return FairscapeResponse(
				success=True,
				statusCode=200,
				model=jobInstance,
			)
		else:
			return FairscapeResponse(
				success=False,
				statusCode=401,
				error={
					"message": "user unauthorized to view upload request"
				}
			)


	def execute(
		self, 
		currentUser, 
		jobGUID
	):

		# if no minio object is available then return 
		processROCrate.apply_async(args=(uploadJob.guid,), )

		return FairscapeResponse(
			success=200
		)
		

	def upload(
			self,
			currentUser: UserWriteModel, 
			filename: str, 
			filesize: int
			):

		userEmailPath = userPath(currentUser.email)
		uploadPath = f"{appConfig.minioDefaultPath}/{userEmailPath}/rocrates/{filename}"

		try:
			presignedUploadLink = createUploadPresignedLink(
				appConfig.minioClient,
				appConfig.minioBucket,
				uploadPath
			)
		except Exception as exc:
			return FairscapeResponse(
				success=False,
				statusCode=500,
				error={
					"message": "unable to grant presigned upload link",
					"error": str(exc)
					}
			)

		uploadJobInstance = FairscapeUploadJob.model_validate({
			"@id": str(uuid.uuid4()),
			"presigned": True,
			"uploadPath": uploadPath,
			"fileSize": filesize,
			"presignedUploadLink": presignedUploadLink,
			"timeStarted": None,
			"timeFinished": None,
			"permissions": currentUser.getPermissions(),
			"status": "generate presigned link for upload",
			"complete": False,
			"success": False,	
			"rocrateGUID": None,
			"identifiersMinted": 0
		})


		insertResult = appConfig.asyncCollection.insert_one(
			uploadJobInstance.model_dump(mode='json', by_alias=True)
		)

		assert insertResult.inserted_id

		return FairscapeResponse(
			success=True,
			statusCode=200,
			model=uploadJobInstance
		)

# %%
createUploadPresignedLink(appConfig.minioClient, appConfig.minioBucket, object_name="rocrate.zip")
# Out:
# {'url': 'http://localhost:9000/default',
#  'fields': {'key': 'rocrate.zip',
#   'x-amz-algorithm': 'AWS4-HMAC-SHA256',
#   'x-amz-credential': 'miniotestadmin/20250911/us-east-1/s3/aws4_request',
#   'x-amz-date': '20250911T162814Z',
#   'policy': '',
#   'x-amz-signature': '716c8b3bb8e4feb6f6ce24d26103da6dae27bac6fdf3759baa36c027765edd11'}}

# %%
appConfig.minioClient.list_buckets()
# Out:
# {'ResponseMetadata': {'RequestId': '18644740DEA76675',
#   'HostId': 'dd9025bab4ad464b049177c95eb6ebf374d3b3fd1af9251148b658df7ac2e3e8',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'accept-ranges': 'bytes',
#    'content-length': '457',
#    'content-type': 'application/xml',
#    'server': 'MinIO',
#    'strict-transport-security': 'max-age=31536000; includeSubDomains',
#    'vary': 'Origin, Accept-Encoding',
#    'x-amz-id-2': 'dd9025bab4ad464b049177c95eb6ebf374d3b3fd1af9251148b658df7ac2e3e8',
#    'x-amz-request-id': '18644740DEA76675',
#    'x-content-type-options': 'nosniff',
#    'x-ratelimit-limit': '4450',
#    'x-ratelimit-remaining': '4450',
#    'x-xss-protection': '1; mode=block',
#    'date': 'Thu, 11 Sep 2025 16:28:18 GMT'},
#   'RetryAttempts': 0},
#  'Buckets': [{'Name': 'default',
#    'CreationDate': datetime.datetime(2025, 7, 21, 7, 3, 40, 883000, tzinfo=tzutc())},
#   {'Name': 'fairscape',
#    'CreationDate': datetime.datetime(2025, 7, 21, 7, 4, 42, 612000, tzinfo=tzutc())}],
#  'Owner': {'DisplayName': 'minio',
#   'ID': '02d6176db174dc93cb1b899f7c6078f08654445fe8cf1b6ce98d8855f66bdbf4'}}

# %%
presignedROCrateRequestFactory = FairscapePresignedROCrateRequest(appConfig)

# %%
uploadPresignedResponse = presignedROCrateRequestFactory.upload(
	currentUser,
	"paclitaxel.zip",
	4497805667
)

# %%
uploadPresignedResponse.model.model_dump(by_alias=True)
# Out:
# {'@id': '4919243b-9da0-469c-ab8a-aa7ee61a4eef',
#  'presigned': True,
#  'uploadPath': 'default/test/rocrates/paclitaxel.zip',
#  'fileSize': 4497805667,
#  'presignedUploadLink': {'url': 'http://localhost:9000/default',
#   'fields': {'key': 'default/test/rocrates/paclitaxel.zip',
#    'x-amz-algorithm': 'AWS4-HMAC-SHA256',
#    'x-amz-credential': 'miniotestadmin/20250911/us-east-1/s3/aws4_request',
#    'x-amz-date': '20250911T162825Z',
#    'policy': '',
#    'x-amz-signature': 'ed7582cdc3a927f7e8eb8dac8aa20f4658b50e2f004c2aa9af60869aa45c2c6a'}},
#  'permissions': {'owner': 'test@example.org', 'group': None},
#  'timeStarted': None,
#  'timeFinished': None,
#  'status': 'generate presigned link for upload',
#  'complete': False,
#  'success': False,
#  'rocrateGUID': None,
#  'identifiersMinted': 0}

# %%
uploadInstance = uploadPresignedResponse.model
uploadLink = uploadInstance.presignedUploadLink.get("url")
uploadFields = uploadInstance.presignedUploadLink.get("fields")
jobGUID = uploadInstance.guid

# %%
import httpx
import json
import boto3
import sys

# %%
uploadLink
# Out:
# 'http://localhost:9000/default'

# %%
cratePath ="E:\\Work\\Data\\Uploads\\upload_06_29_2025\\paclitaxel.zip" 
with open(cratePath, "rb") as cratefile:
	rocrateFiles = {
		"file": ("paclitaxel.zip", cratefile, "application/zip")
	}


	# upload a test rocrate
	paclitaxelResponse = httpx.post(
		uploadLink,
		files=rocrateFiles,
		data=uploadFields,
		timeout=10000,
		verify=False
	)

# %%
paclitaxelResponse
# Out:
# <Response [204 No Content]>

# %%
dict(paclitaxelResponse.headers)
# Out:
# {'accept-ranges': 'bytes',
#  'etag': '"84850812a162a043114183728950c7c9"',
#  'location': 'http://localhost:9000/default/default/test/rocrates/paclitaxel.zip',
#  'server': 'MinIO',
#  'strict-transport-security': 'max-age=31536000; includeSubDomains',
#  'vary': 'Origin, Accept-Encoding',
#  'x-amz-id-2': 'dd9025bab4ad464b049177c95eb6ebf374d3b3fd1af9251148b658df7ac2e3e8',
#  'x-amz-request-id': '18644748FA70CAF1',
#  'x-content-type-options': 'nosniff',
#  'x-ratelimit-limit': '4450',
#  'x-ratelimit-remaining': '4450',
#  'x-xss-protection': '1; mode=block',
#  'date': 'Thu, 11 Sep 2025 16:29:04 GMT'}

# %%
jobGUID

# %%
def proccessROCrate(jobGUID):

	jobMetadata = appConfig.asyncCollection.find_one(
		{"@id": jobGUID},
		projection={"_id": False}
	)

	if jobMetadata is None:
		return FairscapeResponse(
			success=False,
			statusCode=404,
			error= {"message": "job not found"}
		)
	
	return FairscapeUploadJob.model_validate(jobMetadata)

# %%
# given the job id 
jobInstance = proccessROCrate(jobGUID)
# Out:
# 'default/test/rocrates/paclitaxel.zip'

# %%
# Out:
# 'paclitaxel'

# %%
jobUploadPath = pathlib.PurePosixPath(jobInstance.uploadPath)
baseDirectory = jobInstance.uploadPath 
metadataKey = baseDirectory + "/ro-crate-metadata.json"
metadataFound = False

try: 
	s3Response = appConfig.minioClient.get_object(
		Bucket = appConfig.minioBucket,
		Key = metadataKey
	)
	metadataFound = True
except appConfig.minioClient.exceptions.NoSuchKey as e:
	metadataFound = False

if not metadataFound:

	metadataKey = f"{baseDirectory}/{jobUploadPath.stem}/ro-crate-metadata.json"

	try: 
		s3Response = appConfig.minioClient.get_object(
			Bucket = appConfig.minioBucket,
			Key = metadataKey
		)
		metadataFound = True
	except appConfig.minioClient.exceptions.NoSuchKey as e:
		metadataFound = False

if metadataFound:
	try:
		content = s3Response['Body']
		roCrateJSON = json.loads(content.read())
	except json.JSONDecodeError:
		raise Exception("Failed to Decode Metadata JSON")

else:
	raise Exception("Metadata Not Found in RO-Crate")

# %%
roCrateJSON
# Out:
# {'@context': {'@vocab': 'https://schema.org/', 'EVI': 'https://w3id.org/EVI#'},
#  '@graph': [{'@id': 'ro-crate-metadata.json',
#    '@type': 'CreativeWork',
#    'conformsTo': {'@id': 'https://w3id.org/ro/crate/1.2-DRAFT'},
#    'about': {'@id': 'ark:59853/rocrate-paclitaxel-if-data-release'}},
#   {'@type': ['Dataset', 'https://w3id.org/EVI#ROCrate'],
#    'isPartOf': [],
#    'version': '0.1.0',
#    'datePublished': '02/28/2025',
#    'license': 'https://creativecommons.org/licenses/by-nc-sa/4.0/deed.en',
#    'associatedPublication': None,
#    'author': ['Hansen JN',
#     'Axelsson U',
#     'Johannesson A',
#     'Fall J',
#     'Ballllosera Navarro F',
#     'Lundberg E'],
#    'conditionsOfAccess': 'This dataset was created by investigators and staff of the Cell Maps for Artificial Intelligence project (CM4AI - https://cm4ai.org), a Data Generation Project of the NIH Bridge2AI program for cellular imaging data by The Board of Trustees of the Leland Stanford Junior University. It is licensed for reuse under the Creative Commons Attribution-NonCommercial-ShareAlike 4.0 International (CC-BY-NC-SA 4.0) license, whose terms are summarized here: https://creativecommons.org/licenses/by-nc-sa/4.0/deed.en.  Proper attribution credit as required by the license includes citation of the copyright holders and of the attribution parties, which includes citation of the following article: Clark T, Schaffer L, Obernier K, Al Manir S, Churas CP, Dailamy A, Doctor Y, Forget A, Hansen JN, Hu M, Lenkiewicz J, Levinson MA, Marquez C, Mohan J, Nourreddine S, Niestroy J, Pratt D, Qian G, Thaker S, Belisle-Pipon J-C, Brandt C, Chen J, Ding Y, Fodeh S, Krogan N, Lundberg E, Mali P, Payne-Foster P, Ratcliffe S, Ravitsky V, Sali A, Schulz W, Ideker T. Cell Maps for Artificial Intelligence: AI-Ready Maps of Human Cell Architecture from Disease-Relevant Cell Lines. BioRXiv 2024.”',
#    'copyrightNotice': 'Copyright (c) 2025 by The Board of Trustees of the Leland Stanford Junior University',
#    'hasPart': [],
#    '@id': 'ark:59853/rocrate-paclitaxel-if-data-release',
#    'name': 'Paclitaxel IF Images',
#    'description': 'This data set displays the spatial localization of 464 proteins of interest in cells of the breast cancer cell line MDA-MB-468 treated with paclitaxel as imaged by immunofluorescence-based staining (ICC-IF) and confocal microscopy in the Lundberg Lab at Stanford University, as part of the Cell Maps for Artificial Intelligence (CM4AI; CM4AI.org) project. Nuclei were stained with DAPI (blue channel); endoplasmic reticulum with a calreticulin antibody (yellow channel); microtubules with tubulin antibody (red channel); and antibody against protein of interest (green channel). \n\nThis data is Copyright (c) 2025 The Board of Trustees of the Leland Stanford Junior University. It is licensed for reuse under Creative Commons Attribution ShareAlike NonCommercial 4.0 International License (https://creativecommons.org/licenses/by-nc-sa/4.0/). Attribution is required to the copyright holders and the authors. Any publications referencing this data or derived products should cite the related article as well as directly citing this data collection.\n',
#    'keywords': ['AI',
#     'artificial intelligence',
#     'breast cancer',
#     'cell maps',
#     'CM4AI',
#     'machine learning',
#     'MDA-MB-468',
#     'paclitaxel',
#     'protein localization',
#     'protein localization']},
#   {'@id': 'ark:59853/dataset-paclitaxel-manifest',
#    '@type': 'Dataset',
#    'name': 'Paclitaxel Manifest',
#    'author': ['Hansen JN'],
#    'datePublished': '02/28/2025',
#    'keywords': ['if images', 'metadata'],
#    'format': 'csv',
#    'description': 'CSV file containing the metadata for downloads for all paclitaxel treated images',
#    'contentUrl': 'file:///manifest.csv'},
#   {'@id': 'ark:59853/cell-line-MDA-MB-468',
#    '@type': 'BioChemEntity',
#    'name': 'MDA-MB-468 Cell Line',
#    'identifier': [{'@type': 'PropertyValue',
#      'value': 'RRID:CVCL_0419',
#      'name': 'RRID'}],
#    'url': 'https://www.cellosaurus.org/CVCL_0419',
#    'description': 'A cell line of immortalized breast cancer cells taken from a 51 Year old Female.',
#    'alternateName': ['MDA-MB 468',
#     'MDA-MB468',
#     'MDAMB468',
#     'MDA-468',
#     'MDA468',
#     'MB468',
#     'MD Anderson-Metastatic Breast-468'],
#    'organism': {'@id': 'ark:59853/organism-homo-sapiens',
#     'name': 'Homo Sapiens',
#     'identifier': [{'@type': 'PropertyValue',
#       'name': 'NCBI Taxonomy Browser',
#       'value': 'NCBI:txid9606',
#       'url': 'https://www.ncbi.nlm.nih.gov/Taxonomy/Browser/wwwtax.cgi?mode=info&id=9606'}]},
#    'associatedDisease': {'@id': 'ark:59853/disease-breast-adenocarcinoma',
#     '@type': 'MedicalCondition',
#     'identifier': [{'@type': 'PropertyValue',
#       'value': 'NCIt:C5214',
#       'name': 'NCI Thesaurus',
#       'url': 'https://ncit.nci.nih.gov/ncitbrowser/ConceptReport.jsp?dictionary=NCI_Thesaurus&code=C5214'}],
#     'name': 'Breast adenocarcinoma',
#     'description': 'The most common histologic type of breast carcinoma. Representative examples include invasive ductal carcinoma not otherwise specified, ductal carcinoma in situ, inflammatory carcinoma, secretory carcinoma, signet ring cell carcinoma, tubular carcinoma, invasive lobular carcinoma, and lobular carcinoma in situ.'},
#    'EVI:usedBy': []},
#   {'@id': 'ark:59853/treatment-paclitaxel',
#    '@type': 'BioChemEntity',
#    'name': 'Paclitaxel',
#    'associatedDiesease': {'@id': 'ark:59853/medicalcondition-breast-adenocarcinoma'},
#    'identifier': [{'@type': 'PropertyValue',
#      'value': 'https://rxnav.nlm.nih.gov/id/rxnorm/56946',
#      'name': 'RxNORM'},
#     {'@type': 'PropertyValue',
#      'value': 'https://pubchem.ncbi.nlm.nih.gov/compound/Paclitaxel',
#      'name': 'PubChem'}],
#    'description': 'Paclitaxel is a taxoid chemotherapeutic agent used as first-line and subsequent therapy for the treatment of advanced carcinoma of the ovary, and other various cancers including breast and lung cancer.'},
#   {'@id': 'ark:59853/stain-dapi',
#    '@type': 'BioChemEntity',
#    'name': 'DAPI',
#    'identifier': [{'@type': 'PropertyValue',
#      'value': 'https://pubchem.ncbi.nlm.nih.gov/compound/2954',
#      'name': 'PubChem'}],
#    'isLocatedInSubcellularLocation': {'@id': 'GO:0005634', 'name': 'Nucleus'},
#    'description': 'DAPI is a lipid soluble fluorochrome dye that binds to adenine-thymine (A-T) rich regions in DNA and, to a lesser extent, RNA. During fluorescence microscopy and flow cytometry, this agent binds to and detects endogenous and exogenous DNA in cellular samples. DAPI is excited with ultraviolet (UV) light (maximum absorption at 358 nm) and upon binding, emits light in the blue portion of the spectrum (461 nm for DNA and ~500 nm for RNA).'},
#   {'@id': 'ark:59853/stain-calreticulin-antibody',
#    '@type': 'BioChemEntity',
#    'name': 'Calreticulin antibody',
#    'identifier': [],
#    'isLocatedInSubcellularLocation': {'@id': 'GO:0005783',
#     'name': 'Endoplasmic Reticulum'},
#    'description': None},
#   {'@id': 'ark:59853/stain-tubulin-antibody',
#    '@type': 'BioChemEntity',
#    'name': 'Tubulin antibody',
#    'identifier': [],
#    'isLocatedInSubcellularLocation': {'@id': 'GO:0005856',
#     'name': 'Cytoskeleton'},
#    'description': None},
#   {'@id': 'ark:59853/b2ai-antibody-CAB005042',
#    '@type': 'BioChemEntity',
#    'name': 'Stain CAB005042',
#    'identifier': [{'@type': 'PropertyValue',
#      'name': 'HPA Antibody ID',
#      'value': 'CAB005042'},
#     {'@type': 'PropertyValue', 'name': 'ENSEMBL', 'value': 'ENSG00000132507'},
#     {'@type': 'PropertyValue', 'name': 'ENSEMBL', 'value': 'ENSG00000132507'},
#     {'@type': 'PropertyValue', 'name': 'Uniprot', 'value': 'P63241'}],
#    'isLocatedInSubcellularLocation': [{'@type': 'PropertyValue',
#      'name': 'Chromosome Number',
#      'value': '17'}],
#    'description': None},
#   {'@id': 'ark:59853/b2ai-antibody-CAB017180',
#    '@type': 'BioChemEntity',
#    'name': 'Stain CAB017180',
#    'identifier': [{'@type': 'PropertyValue',
#      'name': 'HPA Antibody ID',
#      'value': 'CAB017180'},
#     {'@type': 'PropertyValue', 'name': 'ENSEMBL', 'value': 'ENSG00000133026'},
#     {'@type': 'PropertyValue', 'name': 'ENSEMBL', 'value': 'ENSG00000133026'},
#     {'@type': 'PropertyValue', 'name': 'Uniprot', 'value': 'P35580'}],
#    'isLocatedInSubcellularLocation': [{'@type': 'PropertyValue',
#      'name': 'Chromosome Number',
#      'value': '17'}],
#    'description': None},
#   {'@id': 'ark:59853/b2ai-antibody-CAB034320',
#    '@type': 'BioChemEntity',
#    'name': 'Stain CAB034320',
#    'identifier': [{'@type': 'PropertyValue',
#      'name': 'HPA Antibody ID',
#      'value': 'CAB034320'},
#     {'@type': 'PropertyValue', 'name': 'ENSEMBL', 'value': 'ENSG00000163191'},
#     {'@type': 'PropertyValue', 'name': 'ENSEMBL', 'value': 'ENSG00000163191'},
#     {'@type': 'PropertyValue', 'name': 'Uniprot', 'value': 'P31949'}],
#    'isLocatedInSubcellularLocation': [{'@type': 'PropertyValue',
#      'name': 'Chromosome Number',
#      'value': '1'}],
#    'description': None},
#   {'@id': 'ark:59853/b2ai-antibody-CAB079904',
#    '@type': 'BioChemEntity',
#    'name': 'Stain CAB079904',
#    'identifier': [{'@type': 'PropertyValue',
#      'name': 'HPA Antibody ID',
#      'value': 'CAB079904'},
#     {'@type': 'PropertyValue', 'name': 'ENSEMBL', 'value': 'ENSG00000187555'},
#     {'@type': 'PropertyValue', 'name': 'ENSEMBL', 'value': 'ENSG00000187555'},
#     {'@type': 'PropertyValue', 'name': 'Uniprot', 'value': 'Q93009'}],
#    'isLocatedInSubcellularLocation': [{'@type': 'PropertyValue',
#      'name': 'Chromosome Number',
#      'value': '16'}],
#    'description': None},
#   {'@id': 'ark:59853/b2ai-antibody-CAB079921',
#    '@type': 'BioChemEntity',
#    'name': 'Stain CAB079921',
#    'identifier': [{'@type': 'PropertyValue',
#      'name': 'HPA Antibody ID',
#      'value': 'CAB079921'},
#     {'@type': 'PropertyValue', 'name': 'ENSEMBL', 'value': 'ENSG00000186298'},
#     {'@type': 'PropertyValue', 'name': 'ENSEMBL', 'value': 'ENSG00000186298'},
#     {'@type': 'PropertyValue', 'name': 'Uniprot', 'value': 'P36873'}],
#    'isLocatedInSubcellularLocation': [{'@type': 'PropertyValue',
#      'name': 'Chromosome Number',
#      'value': '12'}],
#    'description': None},
#   {'@id': 'ark:59853/b2ai-antibody-CAB080425',
#    '@type': 'BioChemEntity',
#    'name': 'Stain CAB080425',
#    'identifier': [{'@type': 'PropertyValue',
#      'name': 'HPA Antibody ID',
#      'value': 'CAB080425'},
#     {'@type': 'PropertyValue', 'name': 'ENSEMBL', 'value': 'ENSG00000108773'},
#     {'@type': 'PropertyValue', 'name': 'ENSEMBL', 'value': 'ENSG00000108773'},
#     {'@type': 'PropertyValue', 'name': 'Uniprot', 'value': 'Q92830'}],
#    'isLocatedInSubcellularLocation': [{'@type': 'PropertyValue',
#      'name': 'Chromosome Number',
#      'value': '17'}],
#    'description': None},
#   {'@id': 'ark:59853/b2ai-antibody-CAB080426',
#    '@type': 'BioChemEntity',
#    'name': 'Stain CAB080426',
#    'identifier': [{'@type': 'PropertyValue',
#      'name': 'HPA Antibody ID',
#      'value': 'CAB080426'},
#     {'@type': 'PropertyValue', 'name': 'ENSEMBL', 'value': 'ENSG00000147099'},
#     {'@type': 'PropertyValue', 'name': 'ENSEMBL', 'value': 'ENSG00000147099'},
#     {'@type': 'PropertyValue', 'name': 'Uniprot', 'value': 'Q9BY41'}],
#    'isLocatedInSubcellularLocation': [{'@type': 'PropertyValue',
#      'name': 'Chromosome Number',
#      'value': 'X'}],
#    'description': None},
#   {'@id': 'ark:59853/b2ai-antibody-CAB080427',
#    '@type': 'BioChemEntity',
#    'name': 'Stain CAB080427',
#    'identifier': [{'@type': 'PropertyValue',
#      'name': 'HPA Antibody ID',
#      'value': 'CAB080427'},
#     {'@type': 'PropertyValue', 'name': 'ENSEMBL', 'value': 'ENSG00000163517'},
#     {'@type': 'PropertyValue', 'name': 'ENSEMBL', 'value': 'ENSG00000163517'},
#     {'@type': 'PropertyValue', 'name': 'Uniprot', 'value': 'Q96DB2'}],
#    'isLocatedInSubcellularLocation': [{'@type': 'PropertyValue',
#      'name': 'Chromosome Number',
#      'value': '3'}],
#    'description': None},
#   {'@id': 'ark:59853/b2ai-antibody-CAB080428',
#    '@type': 'BioChemEntity',
#    'name': 'Stain CAB080428',
#    'identifier': [{'@type': 'PropertyValue',
#      'name': 'HPA Antibody ID',
#      'value': 'CAB080428'},
#     {'@type': 'PropertyValue', 'name': 'ENSEMBL', 'value': 'ENSG00000116478'},
#     {'@type': 'PropertyValue', 'name': 'ENSEMBL', 'value': 'ENSG00000116478'},
#     {'@type': 'PropertyValue', 'name': 'Uniprot', 'value': 'Q13547'}],
#    'isLocatedInSubcellularLocation': [{'@type': 'PropertyValue',
#      'name': 'Chromosome Number',
#      'value': '1'}],
#    'description': None},
#   {'@id': 'ark:59853/b2ai-antibody-CAB080429',
#    '@type': 'BioChemEntity',
#    'name': 'Stain CAB080429',
#    'identifier': [{'@type': 'PropertyValue',
#      'name': 'HPA Antibody ID',
#      'value': 'CAB080429'},
#     {'@type': 'PropertyValue', 'name': 'ENSEMBL', 'value': 'ENSG00000156983'},
#     {'@type': 'PropertyValue', 'name': 'ENSEMBL', 'value': 'ENSG00000156983'},
#     {'@type': 'PropertyValue', 'name': 'Uniprot', 'value': 'P55201'}],
#    'isLocatedInSubcellularLocation': [{'@type': 'PropertyValue',
#      'name': 'Chromosome Number',
#      'value': '3'}],
#    'description': None},
#   {'@id': 'ark:59853/b2ai-antibody-CAB080430',
#    '@type': 'BioChemEntity',
#    'name': 'Stain CAB080430',
#    'identifier': [{'@type': 'PropertyValue',
#      'name': 'HPA Antibody ID',
#      'value': 'CAB080430'},
#     {'@type': 'PropertyValue', 'name': 'ENSEMBL', 'value': 'ENSG00000130816'},
#     {'@type': 'PropertyValue', 'name': 'ENSEMBL', 'value': 'ENSG00000130816'},
#     {'@type': 'PropertyValue', 'name': 'Uniprot', 'value': 'P26358'}],
#    'isLocatedInSubcellularLocation': [{'@type': 'PropertyValue',
#      'name': 'Chromosome Number',
#      'value': '19'}],
#    'description': None},
#   {'@id': 'ark:59853/b2ai-antibody-CAB080431',
#    '@type': 'BioChemEntity',
#    'name': 'Stain CAB080431',
#    'identifier': [{'@type': 'PropertyValue',
#      'name': 'HPA Antibody ID',
#      'value': 'CAB080431'},
#     {'@type': 'PropertyValue', 'name': 'ENSEMBL', 'value': 'ENSG00000061273'},
#     {'@type': 'PropertyValue', 'name': 'ENSEMBL', 'value': 'ENSG00000061273'},
#     {'@type': 'PropertyValue', 'name': 'Uniprot', 'value': 'Q8WUI4'}],
#    'isLocatedInSubcellularLocation': [{'@type': 'PropertyValue',
#      'name': 'Chromosome Number',
#      'value': '12'}],
#    'description': None},
#   {'@id': 'ark:59853/b2ai-antibody-HPA000427',
#    '@type': 'BioChemEntity',
#    'name': 'Stain HPA000427',
#    'identifier': [{'@type': 'PropertyValue',
#      'name': 'HPA Antibody ID',
#      'value': 'HPA000427'},
#     {'@type': 'PropertyValue', 'name': 'ENSEMBL', 'value': 'ENSG00000101811'},
#     {'@type': 'PropertyValue', 'name': 'ENSEMBL', 'value': 'ENSG00000101811'},
#     {'@type': 'PropertyValue', 'name': 'Uniprot', 'value': 'P33240'}],
#    'isLocatedInSubcellularLocation': [{'@type': 'PropertyValue',
#      'name': 'Chromosome Number',
#      'value': 'X'}],
#    'description': None},
#   {'@id': 'ark:59853/b2ai-antibody-HPA000511',
#    '@type': 'BioChemEntity',
#    'name': 'Stain HPA000511',
#    'identifier': [{'@type': 'PropertyValue',
#      'name': 'HPA Antibody ID',
#      'value': 'HPA000511'},
#     {'@type': 'PropertyValue', 'name': 'ENSEMBL', 'value': 'ENSG00000198157'},
#     {'@type': 'PropertyValue', 'name': 'ENSEMBL', 'value': 'ENSG00000198157'},
#     {'@type': 'PropertyValue', 'name': 'Uniprot', 'value': 'P82970'}],
#    'isLocatedInSubcellularLocation': [{'@type': 'PropertyValue',
#      'name': 'Chromosome Number',
#      'value': 'X'}],
#    'description': None},
#   {'@id': 'ark:59853/b2ai-antibody-HPA000525',
#    '@type': 'BioChemEntity',
#    'name': 'Stain HPA000525',
#    'identifier': [{'@type': 'PropertyValue',
#      'name': 'HPA Antibody ID',
#      'value': 'HPA000525'},
#     {'@type': 'PropertyValue', 'name': 'ENSEMBL', 'value': 'ENSG00000239900'},
#     {'@type': 'PropertyValue', 'name': 'ENSEMBL', 'value': 'ENSG00000239900'},
#     {'@type': 'PropertyValue', 'name': 'Uniprot', 'value': 'P30566'}],
#    'isLocatedInSubcellularLocation': [{'@type': 'PropertyValue',
#      'name': 'Chromosome Number',
#      'value': '22'}],
#    'description': None},
#   {'@id': 'ark:59853/b2ai-antibody-HPA000571',
#    '@type': 'BioChemEntity',
#    'name': 'Stain HPA000571',
#    'identifier': [{'@type': 'PropertyValue',
#      'name': 'HPA Antibody ID',
#      'value': 'HPA000571'},
#     {'@type': 'PropertyValue', 'name': 'ENSEMBL', 'value': 'ENSG00000147383'},
#     {'@type': 'PropertyValue', 'name': 'ENSEMBL', 'value': 'ENSG00000147383'},
#     {'@type': 'PropertyValue', 'name': 'Uniprot', 'value': 'Q15738'}],
#    'isLocatedInSubcellularLocation': [{'@type': 'PropertyValue',
#      'name': 'Chromosome Number',
#      'value': 'X'}],
#    'description': None},
#   {'@id': 'ark:59853/b2ai-antibody-HPA000704',
#    '@type': 'BioChemEntity',
#    'name': 'Stain HPA000704',
#    'identifier': [{'@type': 'PropertyValue',
#      'name': 'HPA Antibody ID',
#      'value': 'HPA000704'},
#     {'@type': 'PropertyValue', 'name': 'ENSEMBL', 'value': 'ENSG00000100714'},
#     {'@type': 'PropertyValue', 'name': 'ENSEMBL', 'value': 'ENSG00000100714'},
#     {'@type': 'PropertyValue', 'name': 'Uniprot', 'value': 'P11586'}],
#    'isLocatedInSubcellularLocation': [{'@type': 'PropertyValue',
#      'name': 'Chromosome Number',
#      'value': '14'}],
#    'description': None},
#   {'@id': 'ark:59853/b2ai-antibody-HPA000815',
#    '@type': 'BioChemEntity',
#    'name': 'Stain HPA000815',
#    'identifier': [{'@type': 'PropertyValue',
#      'name': 'HPA Antibody ID',
#      'value': 'HPA000815'},
#     {'@type': 'PropertyValue', 'name': 'ENSEMBL', 'value': 'ENSG00000100395'},
#     {'@type': 'PropertyValue', 'name': 'ENSEMBL', 'value': 'ENSG00000100395'},
#     {'@type': 'PropertyValue', 'name': 'Uniprot', 'value': 'Q969R5'}],
#    'isLocatedInSubcellularLocation': [{'@type': 'PropertyValue',
#      'name': 'Chromosome Number',
#      'value': '22'}],
#    'description': None},
#   {'@id': 'ark:59853/b2ai-antibody-HPA000834',
#    '@type': 'BioChemEntity',
#    'name': 'Stain HPA000834',
#    'identifier': [{'@type': 'PropertyValue',
#      'name': 'HPA Antibody ID',
#      'value': 'HPA000834'},
#     {'@type': 'PropertyValue', 'name': 'ENSEMBL', 'value': 'ENSG00000160211'},
#     {'@type': 'PropertyValue', 'name': 'ENSEMBL', 'value': 'ENSG00000160211'},
#     {'@type': 'PropertyValue', 'name': 'Uniprot', 'value': 'P11413'}],
#    'isLocatedInSubcellularLocation': [{'@type': 'PropertyValue',
#      'name': 'Chromosome Number',
#      'value': 'X'}],
#    'description': None},
#   {'@id': 'ark:59853/b2ai-antibody-HPA000895',
#    '@type': 'BioChemEntity',
#    'name': 'Stain HPA000895',
#    'identifier': [{'@type': 'PropertyValue',
#      'name': 'HPA Antibody ID',
#      'value': 'HPA000895'},
#     {'@type': 'PropertyValue', 'name': 'ENSEMBL', 'value': 'ENSG00000102024'},
#     {'@type': 'PropertyValue', 'name': 'ENSEMBL', 'value': 'ENSG00000120756'},
#     {'@type': 'PropertyValue', 'name': 'ENSEMBL', 'value': 'ENSG00000136167'},
#     {'@type': 'PropertyValue', 'name': 'ENSEMBL', 'value': 'ENSG00000102024'},
#     {'@type': 'PropertyValue', 'name': 'ENSEMBL', 'value': 'ENSG00000120756'},
#     {'@type': 'PropertyValue', 'name': 'ENSEMBL', 'value': 'ENSG00000136167'},
#     {'@type': 'PropertyValue', 'name': 'Uniprot', 'value': 'P13797'},
#     {'@type': 'PropertyValue', 'name': 'Uniprot', 'value': 'P13796'},
#     {'@type': 'PropertyValue', 'name': 'Uniprot', 'value': 'Q14651'}],
#    'isLocatedInSubcellularLocation': [{'@type': 'PropertyValue',
#      'name': 'Chromosome Number',
#      'value': 'X'},
#     {'@type': 'PropertyValue', 'name': 'Chromosome Number', 'value': '13'},
#     {'@type': 'PropertyValue', 'name': 'Chromosome Number', 'value': '3'}],
#    'description': None},
#   {'@id': 'ark:59853/b2ai-antibody-HPA001022',
#    '@type': 'BioChemEntity',
#    'name': 'Stain HPA001022',
#    'identifier': [{'@type': 'PropertyValue',
#      'name': 'HPA Antibody ID',
#      'value': 'HPA001022'},
#     {'@type': 'PropertyValue', 'name': 'ENSEMBL', 'value': 'ENSG00000130826'},
#     {'@type': 'PropertyValue', 'name': 'ENSEMBL', 'value': 'ENSG00000130826'},
#     {'@type': 'PropertyValue', 'name': 'Uniprot', 'value': 'O60832'}],
#    'isLocatedInSubcellularLocation': [{'@type': 'PropertyValue',
#      'name': 'Chromosome Number',
#      'value': 'X'}],
#    'description': None},
#   {'@id': 'ark:59853/b2ai-antibody-HPA001023',
#    '@type': 'BioChemEntity',
#    'name': 'Stain HPA001023',
#    'identifier': [{'@type': 'PropertyValue',
#      'name': 'HPA Antibody ID',
#      'value': 'HPA001023'},
#     {'@type': 'PropertyValue', 'name': 'ENSEMBL', 'value': 'ENSG00000156531'},
#     {'@type': 'PropertyValue', 'name': 'ENSEMBL', 'value': 'ENSG00000156531'},
#     {'@type': 'PropertyValue', 'name': 'Uniprot', 'value': 'Q8IWS0'}],
#    'isLocatedInSubcellularLocation': [{'@type': 'PropertyValue',
#      'name': 'Chromosome Number',
#      'value': 'X'}],
#    'description': None},
#   {'@id': 'ark:59853/b2ai-antibody-HPA001075',
#    '@type': 'BioChemEntity',
#    'name': 'Stain HPA001075',
#    'identifier': [{'@type': 'PropertyValue',
#      'name': 'HPA Antibody ID',
#      'value': 'HPA001075'},
#     {'@type': 'PropertyValue', 'name': 'ENSEMBL', 'value': 'ENSG00000147133'},
#     {'@type': 'PropertyValue', 'name': 'ENSEMBL', 'value': 'ENSG00000147133'},
#     {'@type': 'PropertyValue', 'name': 'Uniprot', 'value': 'P21675'}],
#    'isLocatedInSubcellularLocation': [{'@type': 'PropertyValue',
#      'name': 'Chromosome Number',
#      'value': 'X'}],
#    'description': None},
#   {'@id': 'ark:59853/b2ai-antibody-HPA001130',
#    '@type': 'BioChemEntity',
#    'name': 'Stain HPA001130',
#    'identifier': [{'@type': 'PropertyValue',
#      'name': 'HPA Antibody ID',
#      'value': 'HPA001130'},
#     {'@type': 'PropertyValue', 'name': 'ENSEMBL', 'value': 'ENSG00000100097'},
#     {'@type': 'PropertyValue', 'name': 'ENSEMBL', 'value': 'ENSG00000100097'},
#     {'@type': 'PropertyValue', 'name': 'Uniprot', 'value': 'P09382'}],
#    'isLocatedInSubcellularLocation': [{'@type': 'PropertyValue',
#      'name': 'Chromosome Number',
#      'value': '22'}],
#    'description': None},
#   {'@id': 'ark:59853/b2ai-antibody-HPA001401',
#    '@type': 'BioChemEntity',
#    'name': 'Stain HPA001401',
#    'identifier': [{'@type': 'PropertyValue',
#      'name': 'HPA Antibody ID',
#      'value': 'HPA001401'},
#     {'@type': 'PropertyValue', 'name': 'ENSEMBL', 'value': 'ENSG00000142168'},
#     {'@type': 'PropertyValue', 'name': 'ENSEMBL', 'value': 'ENSG00000142168'},
#     {'@type': 'PropertyValue', 'name': 'Uniprot', 'value': 'P00441'}],
#    'isLocatedInSubcellularLocation': [{'@type': 'PropertyValue',
#      'name': 'Chromosome Number',
#      'value': '21'}],
#    'description': None},
#   {'@id': 'ark:59853/b2ai-antibody-HPA001464',
#    '@type': 'BioChemEntity',
#    'name': 'Stain HPA001464',
#    'identifier': [{'@type': 'PropertyValue',
#      'name': 'HPA Antibody ID',
#      'value': 'HPA001464'},
#     {'@type': 'PropertyValue', 'name': 'ENSEMBL', 'value': 'ENSG00000168040'},
#     {'@type': 'PropertyValue', 'name': 'ENSEMBL', 'value': 'ENSG00000168040'},
#     {'@type': 'PropertyValue', 'name': 'Uniprot', 'value': 'Q13158'}],
#    'isLocatedInSubcellularLocation': [{'@type': 'PropertyValue',
#      'name': 'Chromosome Number',
#      'value': '11'}],
#    'description': None},
#   {'@id': 'ark:59853/b2ai-antibody-HPA001562',
#    '@type': 'BioChemEntity',
#    'name': 'Stain HPA001562',
#    'identifier': [{'@type': 'PropertyValue',
#      'name': 'HPA Antibody ID',
#      'value': 'HPA001562'},
#     {'@type': 'PropertyValue', 'name': 'ENSEMBL', 'value': 'ENSG00000162772'},
#     {'@type': 'PropertyValue', 'name': 'ENSEMBL', 'value': 'ENSG00000162772'},
#     {'@type': 'PropertyValue', 'name': 'Uniprot', 'value': 'P18847'}],
#    'isLocatedInSubcellularLocation': [{'@type': 'PropertyValue',
#      'name': 'Chromosome Number',
#      'value': '1'}],
#    'description': None},
#   {'@id': 'ark:59853/b2ai-antibody-HPA001749',
#    '@type': 'BioChemEntity',
#    'name': 'Stain HPA001749',
#    'identifier': [{'@type': 'PropertyValue',
#      'name': 'HPA Antibody ID',
#      'value': 'HPA001749'},
#     {'@type': 'PropertyValue', 'name': 'ENSEMBL', 'value': 'ENSG00000100284'},
#     {'@type': 'PropertyValue', 'name': 'ENSEMBL', 'value': 'ENSG00000100284'},
#     {'@type': 'PropertyValue', 'name': 'Uniprot', 'value': 'O60784'}],
#    'isLocatedInSubcellularLocation': [{'@type': 'PropertyValue',
#      'name': 'Chromosome Number',
#      'value': '22'}],
#    'description': None},
#   {'@id': 'ark:59853/b2ai-antibody-HPA001762',
#    '@type': 'BioChemEntity',
#    'name': 'Stain HPA001762',
#    'identifier': [{'@type': 'PropertyValue',
#      'name': 'HPA Antibody ID',
#      'value': 'HPA001762'},
#     {'@type': 'PropertyValue', 'name': 'ENSEMBL', 'value': 'ENSG00000026025'},
#     {'@type': 'PropertyValue', 'name': 'ENSEMBL', 'value': 'ENSG00000026025'},
#     {'@type': 'PropertyValue', 'name': 'Uniprot', 'value': 'P08670'}],
#    'isLocatedInSubcellularLocation': [{'@type': 'PropertyValue',
#      'name': 'Chromosome Number',
#      'value': '10'}],
#    'description': None},
#   {'@id': 'ark:59853/b2ai-antibody-HPA001768',
#    '@type': 'BioChemEntity',
#    'name': 'Stain HPA001768',
#    'identifier': [{'@type': 'PropertyValue',
#      'name': 'HPA Antibody ID',
#      'value': 'HPA001768'},
#     {'@type': 'PropertyValue', 'name': 'ENSEMBL', 'value': 'ENSG00000197879'},
#     {'@type': 'PropertyValue', 'name': 'ENSEMBL', 'value': 'ENSG00000197879'},
#     {'@type': 'PropertyValue', 'name': 'Uniprot', 'value': 'O00159'}],
#    'isLocatedInSubcellularLocation': [{'@type': 'PropertyValue',
#      'name': 'Chromosome Number',
#      'value': '17'}],
#    'description': None},
#   {'@id': 'ark:59853/b2ai-antibody-HPA001780',
#    '@type': 'BioChemEntity',
#    'name': 'Stain HPA001780',
#    'identifier': [{'@type': 'PropertyValue',
#      'name': 'HPA Antibody ID',
#      'value': 'HPA001780'},
#     {'@type': 'PropertyValue', 'name': 'ENSEMBL', 'value': 'ENSG00000100784'},
#     {'@type': 'PropertyValue', 'name': 'ENSEMBL', 'value': 'ENSG00000100784'},
#     {'@type': 'PropertyValue', 'name': 'Uniprot', 'value': 'O75582'}],
#    'isLocatedInSubcellularLocation': [{'@type': 'PropertyValue',
#      'name': 'Chromosome Number',
#      'value': '14'}],
#    'description': None},
#   {'@id': 'ark:59853/b2ai-antibody-HPA001803',
#    '@type': 'BioChemEntity',
#    'name': 'Stain HPA001803',
#    'identifier': [{'@type': 'PropertyValue',
#      'name': 'HPA Antibody ID',
#      'value': 'HPA001803'},
#     {'@type': 'PropertyValue', 'name': 'ENSEMBL', 'value': 'ENSG00000088305'},
#     {'@type': 'PropertyValue', 'name': 'ENSEMBL', 'value': 'ENSG00000088305'},
#     {'@type': 'PropertyValue', 'name': 'Uniprot', 'value': 'Q9UBC3'}],
#    'isLocatedInSubcellularLocation': [{'@type': 'PropertyValue',
#      'name': 'Chromosome Number',
#      'value': '20'}],
#    'description': None},
#   {'@id': 'ark:59853/b2ai-antibody-HPA001890',
#    '@type': 'BioChemEntity',
#    'name': 'Stain HPA001890',
#    'identifier': [{'@type': 'PropertyValue',
#      'name': 'HPA Antibody ID',
#      'value': 'HPA001890'},
#     {'@type': 'PropertyValue', 'name': 'ENSEMBL', 'value': 'ENSG00000163932'},
#     {'@type': 'PropertyValue', 'name': 'ENSEMBL', 'value': 'ENSG00000163932'},
#     {'@type': 'PropertyValue', 'name': 'Uniprot', 'value': 'Q05655'}],
#    'isLocatedInSubcellularLocation': [{'@type': 'PropertyValue',
#      'name': 'Chromosome Number',
#      'value': '3'}],
#    'description': None},
#   {'@id': 'ark:59853/b2ai-antibody-HPA001912',
#    '@type': 'BioChemEntity',
#    'name': 'Stain HPA001912',
#    'identifier': [{'@type': 'PropertyValue',
#      'name': 'HPA Antibody ID',
#      'value': 'HPA001912'},
#     {'@type': 'PropertyValue', 'name': 'ENSEMBL', 'value': 'ENSG00000090447'},
#     {'@type': 'PropertyValue', 'name': 'ENSEMBL', 'value': 'ENSG00000090447'},
#     {'@type': 'PropertyValue', 'name': 'Uniprot', 'value': 'Q01664'}],
#    'isLocatedInSubcellularLocation': [{'@type': 'PropertyValue',
#      'name': 'Chromosome Number',
#      'value': '16'}],
#    'description': None},
#   {'@id': 'ark:59853/b2ai-antibody-HPA001925',
#    '@type': 'BioChemEntity',
#    'name': 'Stain HPA001925',
#    'identifier': [{'@type': 'PropertyValue',
#      'name': 'HPA Antibody ID',
#      'value': 'HPA001925'},
#     {'@type': 'PropertyValue', 'name': 'ENSEMBL', 'value': 'ENSG00000158710'},
#     {'@type': 'PropertyValue', 'name': 'ENSEMBL', 'value': 'ENSG00000158710'},
#     {'@type': 'PropertyValue', 'name': 'Uniprot', 'value': 'P37802'}],
#    'isLocatedInSubcellularLocation': [{'@type': 'PropertyValue',
#      'name': 'Chromosome Number',
#      'value': '1'}],
#    'description': None},
#   {'@id': 'ark:59853/b2ai-antibody-HPA002123',
#    '@type': 'BioChemEntity',
#    'name': 'Stain HPA002123',
#    'identifier': [{'@type': 'PropertyValue',
#      'name': 'HPA Antibody ID',
#      'value': 'HPA002123'},
#     {'@type': 'PropertyValue', 'name': 'ENSEMBL', 'value': 'ENSG00000165092'},
#     {'@type': 'PropertyValue', 'name': 'ENSEMBL', 'value': 'ENSG00000165092'},
#     {'@type': 'PropertyValue', 'name': 'Uniprot', 'value': 'P00352'}],
#    'isLocatedInSubcellularLocation': [{'@type': 'PropertyValue',
#      'name': 'Chromosome Number',
#      'value': '9'}],
#    'description': None},
#   {'@id': 'ark:59853/b2ai-antibody-HPA002485',
#    '@type': 'BioChemEntity',
#    'name': 'Stain HPA002485',
#    'identifier': [{'@type': 'PropertyValue',
#      'name': 'HPA Antibody ID',
#      'value': 'HPA002485'},
#     {'@type': 'PropertyValue', 'name': 'ENSEMBL', 'value': 'ENSG00000131143'},
#     {'@type': 'PropertyValue', 'name': 'ENSEMBL', 'value': 'ENSG00000131143'},
#     {'@type': 'PropertyValue', 'name': 'Uniprot', 'value': 'P13073'}],
#    'isLocatedInSubcellularLocation': [{'@type': 'PropertyValue',
#      'name': 'Chromosome Number',
#      'value': '16'}],
#    'description': None},
#   {'@id': 'ark:59853/b2ai-antibody-HPA002636',
#    '@type': 'BioChemEntity',
#    'name': 'Stain HPA002636',
#    'identifier': [{'@type': 'PropertyValue',
#      'name': 'HPA Antibody ID',
#      'value': 'HPA002636'},
#     {'@type': 'PropertyValue', 'name': 'ENSEMBL', 'value': 'ENSG00000087586'},
#     {'@type': 'PropertyValue', 'name': 'ENSEMBL', 'value': 'ENSG00000087586'},
#     {'@type': 'PropertyValue', 'name': 'Uniprot', 'value': 'O14965'}],
#    'isLocatedInSubcellularLocation': [{'@type': 'PropertyValue',
#      'name': 'Chromosome Number',
#      'value': '20'}],
#    'description': None},
#   {'@id': 'ark:59853/b2ai-antibody-HPA002891',
#    '@type': 'BioChemEntity',
#    'name': 'Stain HPA002891',
#    'identifier': [{'@type': 'PropertyValue',
#      'name': 'HPA Antibody ID',
#      'value': 'HPA002891'},
#     {'@type': 'PropertyValue', 'name': 'ENSEMBL', 'value': 'ENSG00000142208'},
#     {'@type': 'PropertyValue', 'name': 'ENSEMBL', 'value': 'ENSG00000142208'},
#     {'@type': 'PropertyValue', 'name': 'Uniprot', 'value': 'P31749'}],
#    'isLocatedInSubcellularLocation': [{'@type': 'PropertyValue',
#      'name': 'Chromosome Number',
#      'value': '14'}],
#    'description': None},
#   {'@id': 'ark:59853/b2ai-antibody-HPA003054',
#    '@type': 'BioChemEntity',
#    'name': 'Stain HPA003054',
#    'identifier': [{'@type': 'PropertyValue',
#      'name': 'HPA Antibody ID',
#      'value': 'HPA003054'},
#     {'@type': 'PropertyValue', 'name': 'ENSEMBL', 'value': 'ENSG00000100304'},
#     {'@type': 'PropertyValue', 'name': 'ENSEMBL', 'value': 'ENSG00000100304'},
#     {'@type': 'PropertyValue', 'name': 'Uniprot', 'value': 'Q14166'}],
#    'isLocatedInSubcellularLocation': [{'@type': 'PropertyValue',
#      'name': 'Chromosome Number',
#      'value': '22'}],
#    'description': None},
#   {'@id': 'ark:59853/b2ai-antibody-HPA003128',
#    '@type': 'BioChemEntity',
#    'name': 'Stain HPA003128',
#    'identifier': [{'@type': 'PropertyValue',
#      'name': 'HPA Antibody ID',
#      'value': 'HPA003128'},
#     {'@type': 'PropertyValue', 'name': 'ENSEMBL', 'value': 'ENSG00000100393'},
#     {'@type': 'PropertyValue', 'name': 'ENSEMBL', 'value': 'ENSG00000100393'},
#     {'@type': 'PropertyValue', 'name': 'Uniprot', 'value': 'Q09472'}],
#    'isLocatedInSubcellularLocation': [{'@type': 'PropertyValue',
#      'name': 'Chromosome Number',
#      'value': '22'}],
#    'description': None},
#   {'@id': 'ark:59853/b2ai-antibody-HPA003324',
#    '@type': 'BioChemEntity',
#    'name': 'Stain HPA003324',
#    'identifier': [{'@type': 'PropertyValue',
#      'name': 'HPA Antibody ID',
#      'value': 'HPA003324'},
#     {'@type': 'PropertyValue', 'name': 'ENSEMBL', 'value': 'ENSG00000155380'},
#     {'@type': 'PropertyValue', 'name': 'ENSEMBL', 'value': 'ENSG00000155380'},
#     {'@type': 'PropertyValue', 'name': 'Uniprot', 'value': 'P53985'}],
#    'isLocatedInSubcellularLocation': [{'@type': 'PropertyValue',
#      'name': 'Chromosome Number',
#      'value': '1'}],
#    'description': None},
#   {'@id': 'ark:59853/b2ai-antibody-HPA003373',
#    '@type': 'BioChemEntity',
#    'name': 'Stain HPA003373',
#    'identifier': [{'@type': 'PropertyValue',
#      'name': 'HPA Antibody ID',
#      'value': 'HPA003373'},
#     {'@type': 'PropertyValue', 'name': 'ENSEMBL', 'value': 'ENSG00000125691'},
#     {'@type': 'PropertyValue', 'name': 'ENSEMBL', 'value': 'ENSG00000125691'},
#     {'@type': 'PropertyValue', 'name': 'Uniprot', 'value': 'P62829'}],
#    'isLocatedInSubcellularLocation': [{'@type': 'PropertyValue',
#      'name': 'Chromosome Number',
#      'value': '17'}],
#    'description': None},
#   {'@id': 'ark:59853/b2ai-antibody-HPA003394',
#    '@type': 'BioChemEntity',
#    'name': 'Stain HPA003394',
#    'identifier': [{'@type': 'PropertyValue',
#      'name': 'HPA Antibody ID',
#      'value': 'HPA003394'},
#     {'@type': 'PropertyValue', 'name': 'ENSEMBL', 'value': 'ENSG00000070182'},
#     {'@type': 'PropertyValue', 'name': 'ENSEMBL', 'value': 'ENSG00000070182'},
#     {'@type': 'PropertyValue', 'name': 'Uniprot', 'value': 'P11277'}],
#    'isLocatedInSubcellularLocation': [{'@type': 'PropertyValue',
#      'name': 'Chromosome Number',
#      'value': '14'}],
#    'description': None},
#   {'@id': 'ark:59853/b2ai-antibody-HPA003474',
#    '@type': 'BioChemEntity',
#    'name': 'Stain HPA003474',
#    'identifier': [{'@type': 'PropertyValue',
#      'name': 'HPA Antibody ID',
#      'value': 'HPA003474'},
#     {'@type': 'PropertyValue', 'name': 'ENSEMBL', 'value': 'ENSG00000125952'},
#     {'@type': 'PropertyValue', 'name': 'ENSEMBL', 'value': 'ENSG00000125952'},
#     {'@type': 'PropertyValue', 'name': 'Uniprot', 'value': 'P61244'}],
#    'isLocatedInSubcellularLocation': [{'@type': 'PropertyValue',
#      'name': 'Chromosome Number',
#      'value': '14'}],
#    'description': None},
#   {'@id': 'ark:59853/b2ai-antibody-HPA003714',
#    '@type': 'BioChemEntity',
#    'name': 'Stain HPA003714',
#    'identifier': [{'@type': 'PropertyValue',
#      'name': 'HPA Antibody ID',
#      'value': 'HPA003714'},
#     {'@type': 'PropertyValue', 'name': 'ENSEMBL', 'value': 'ENSG00000094631'},
#     {'@type': 'PropertyValue', 'name': 'ENSEMBL', 'value': 'ENSG00000094631'},
#     {'@type': 'PropertyValue', 'name': 'Uniprot', 'value': 'Q9UBN7'}],
#    'isLocatedInSubcellularLocation': [{'@type': 'PropertyValue',
#      'name': 'Chromosome Number',
#      'value': 'X'}],
#    'description': None},
#   {'@id': 'ark:59853/b2ai-antibody-HPA004052',
#    '@type': 'BioChemEntity',
#    'name': 'Stain HPA004052',
#    'identifier': [{'@type': 'PropertyValue',
#      'name': 'HPA Antibody ID',
#      'value': 'HPA004052'},
#     {'@type': 'PropertyValue', 'name': 'ENSEMBL', 'value': 'ENSG00000145907'},
#     {'@type': 'PropertyValue', 'name': 'ENSEMBL', 'value': 'ENSG00000145907'},
#     {'@type': 'PropertyValue', 'name': 'Uniprot', 'value': 'Q13283'}],
#    'isLocatedInSubcellularLocation': [{'@type': 'PropertyValue',
#      'name': 'Chromosome Number',
#      'value': '5'}],
#    'description': None},
#   {'@id': 'ark:59853/b2ai-antibody-HPA004125',
#    '@type': 'BioChemEntity',
#    'name': 'Stain HPA004125',
#    'identifier': [{'@type': 'PropertyValue',
#      'name': 'HPA Antibody ID',
#      'value': 'HPA004125'},
#     {'@type': 'PropertyValue', 'name': 'ENSEMBL', 'value': 'ENSG00000166986'},
#     {'@type': 'PropertyValue', 'name': 'ENSEMBL', 'value': 'ENSG00000166986'},
#     {'@type': 'PropertyValue', 'name': 'Uniprot', 'value': 'P56192'}],
#    'isLocatedInSubcellularLocation': [{'@type': 'PropertyValue',
#      'name': 'Chromosome Number',
#      'value': '12'}],
#    'description': None},
#   {'@id': 'ark:59853/b2ai-antibody-HPA004246',
#    '@type': 'BioChemEntity',
#    'name': 'Stain HPA004246',
#    'identifier': [{'@type': 'PropertyValue',
#      'name': 'HPA Antibody ID',
#      'value': 'HPA004246'},
#     {'@type': 'PropertyValue', 'name': 'ENSEMBL', 'value': 'ENSG00000106617'},
#     {'@type': 'PropertyValue', 'name': 'ENSEMBL', 'value': 'ENSG00000106617'},
#     {'@type': 'PropertyValue', 'name': 'Uniprot', 'value': 'Q9UGJ0'}],
#    'isLocatedInSubcellularLocation': [{'@type': 'PropertyValue',
#      'name': 'Chromosome Number',
#      'value': '7'}],
#    'description': None},
#   {'@id': 'ark:59853/b2ai-antibody-HPA004247',
#    '@type': 'BioChemEntity',
#    'name': 'Stain HPA004247',
#    'identifier': [{'@type': 'PropertyValue',
#      'name': 'HPA Antibody ID',
#      'value': 'HPA004247'},
#     {'@type': 'PropertyValue', 'name': 'ENSEMBL', 'value': 'ENSG00000111725'},
#     {'@type': 'PropertyValue', 'name': 'ENSEMBL', 'value': 'ENSG00000111725'},
#     {'@type': 'PropertyValue', 'name': 'Uniprot', 'value': 'Q9Y478'}],
#    'isLocatedInSubcellularLocation': [{'@type': 'PropertyValue',
#      'name': 'Chromosome Number',
#      'value': '12'}],
#    'description': None},
#   {'@id': 'ark:59853/b2ai-antibody-HPA004426',
#    '@type': 'BioChemEntity',
#    'name': 'Stain HPA004426',
#    'identifier': [{'@type': 'PropertyValue',
#      'name': 'HPA Antibody ID',
#      'value': 'HPA004426'},
#     {'@type': 'PropertyValue', 'name': 'ENSEMBL', 'value': 'ENSG00000197746'},
#     {'@type': 'PropertyValue', 'name': 'ENSEMBL', 'value': 'ENSG00000197746'},
#     {'@type': 'PropertyValue', 'name': 'Uniprot', 'value': 'P07602'}],
#    'isLocatedInSubcellularLocation': [{'@type': 'PropertyValue',
#      'name': 'Chromosome Number',
#      'value': '10'}],
#    'description': None},
#   {'@id': 'ark:59853/b2ai-antibody-HPA004428',
#    '@type': 'BioChemEntity',
#    'name': 'Stain HPA004428',
#    'identifier': [{'@type': 'PropertyValue',
#      'name': 'HPA Antibody ID',
#      'value': 'HPA004428'},
#     {'@type': 'PropertyValue', 'name': 'ENSEMBL', 'value': 'ENSG00000075239'},
#     {'@type': 'PropertyValue', 'name': 'ENSEMBL', 'value': 'ENSG00000075239'},
#     {'@type': 'PropertyValue', 'name': 'Uniprot', 'value': 'P24752'}],
#    'isLocatedInSubcellularLocation': [{'@type': 'PropertyValue',
#      'name': 'Chromosome Number',
#      'value': '11'}],
#    'description': None},
#   {'@id': 'ark:59853/b2ai-antibody-HPA004747',
#    '@type': 'BioChemEntity',
#    'name': 'Stain HPA004747',
#    'identifier': [{'@type': 'PropertyValue',
#      'name': 'HPA Antibody ID',
#      'value': 'HPA004747'},
#     {'@type': 'PropertyValue', 'name': 'ENSEMBL', 'value': 'ENSG00000136068'},
#     {'@type': 'PropertyValue', 'name': 'ENSEMBL', 'value': 'ENSG00000136068'},
#     {'@type': 'PropertyValue', 'name': 'Uniprot', 'value': 'O75369'}],
#    'isLocatedInSubcellularLocation': [{'@type': 'PropertyValue',
#      'name': 'Chromosome Number',
#      'value': '3'}],
#    'description': None},
#   {'@id': 'ark:59853/b2ai-antibody-HPA004748',
#    '@type': 'BioChemEntity',
#    'name': 'Stain HPA004748',
#    'identifier': [{'@type': 'PropertyValue',
#      'name': 'HPA Antibody ID',
#      'value': 'HPA004748'},
#     {'@type': 'PropertyValue', 'name': 'ENSEMBL', 'value': 'ENSG00000137076'},
#     {'@type': 'PropertyValue', 'name': 'ENSEMBL', 'value': 'ENSG00000137076'},
#     {'@type': 'PropertyValue', 'name': 'Uniprot', 'value': 'Q9Y490'}],
#    'isLocatedInSubcellularLocation': [{'@type': 'PropertyValue',
#      'name': 'Chromosome Number',
#      'value': '9'}],
#    'description': None},
#   {'@id': 'ark:59853/b2ai-antibody-HPA004835',
#    '@type': 'BioChemEntity',
#    'name': 'Stain HPA004835',
#    'identifier': [{'@type': 'PropertyValue',
#      'name': 'HPA Antibody ID',
#      'value': 'HPA004835'},
#     {'@type': 'PropertyValue', 'name': 'ENSEMBL', 'value': 'ENSG00000159840'},
#     {'@type': 'PropertyValue', 'name': 'ENSEMBL', 'value': 'ENSG00000159840'},
#     {'@type': 'PropertyValue', 'name': 'Uniprot', 'value': 'Q15942'}],
#    'isLocatedInSubcellularLocation': [{'@type': 'PropertyValue',
#      'name': 'Chromosome Number',
#      'value': '7'}],
#    'description': None},
#   {'@id': 'ark:59853/b2ai-antibody-HPA004840',
#    '@type': 'BioChemEntity',
#    'name': 'Stain HPA004840',
#    'identifier': [{'@type': 'PropertyValue',
#      'name': 'HPA Antibody ID',
#      'value': 'HPA004840'},
#     {'@type': 'PropertyValue', 'name': 'ENSEMBL', 'value': 'ENSG00000012048'},
#     {'@type': 'PropertyValue', 'name': 'ENSEMBL', 'value': 'ENSG00000012048'},
#     {'@type': 'PropertyValue', 'name': 'Uniprot', 'value': 'P38398'}],
#    'isLocatedInSubcellularLocation': [{'@type': 'PropertyValue',
#      'name': 'Chromosome Number',
#      'value': '17'}],
#    'description': None},
#   {'@id': 'ark:59853/b2ai-antibody-HPA004902',
#    '@type': 'BioChemEntity',
#    'name': 'Stain HPA004902',
#    'identifier': [{'@type': 'PropertyValue',
#      'name': 'HPA Antibody ID',
#      'value': 'HPA004902'},
#     {'@type': 'PropertyValue', 'name': 'ENSEMBL', 'value': 'ENSG00000122565'},
#     {'@type': 'PropertyValue', 'name': 'ENSEMBL', 'value': 'ENSG00000122565'},
#     {'@type': 'PropertyValue', 'name': 'Uniprot', 'value': 'Q13185'}],
#    'isLocatedInSubcellularLocation': [{'@type': 'PropertyValue',
#      'name': 'Chromosome Number',
#      'value': '7'}],
#    'description': None},
#   {'@id': 'ark:59853/b2ai-antibody-HPA004911',
#    '@type': 'BioChemEntity',
#    'name': 'Stain HPA004911',
#    'identifier': [{'@type': 'PropertyValue',
#      'name': 'HPA Antibody ID',
#      'value': 'HPA004911'},
#     {'@type': 'PropertyValue', 'name': 'ENSEMBL', 'value': 'ENSG00000138668'},
#     {'@type': 'PropertyValue', 'name': 'ENSEMBL', 'value': 'ENSG00000138668'},
#     {'@type': 'PropertyValue', 'name': 'Uniprot', 'value': 'Q14103'}],
#    'isLocatedInSubcellularLocation': [{'@type': 'PropertyValue',
#      'name': 'Chromosome Number',
#      'value': '4'}],
#    'description': None},
#   {'@id': 'ark:59853/b2ai-antibody-HPA005665',
#    '@type': 'BioChemEntity',
#    'name': 'Stain HPA005665',
#    'identifier': [{'@type': 'PropertyValue',
#      'name': 'HPA Antibody ID',
#      'value': 'HPA005665'},
#     {'@type': 'PropertyValue', 'name': 'ENSEMBL', 'value': 'ENSG00000125354'},
#     {'@type': 'PropertyValue', 'name': 'ENSEMBL', 'value': 'ENSG00000138758'},
#     {'@type': 'PropertyValue', 'name': 'ENSEMBL', 'value': 'ENSG00000164402'},
#     {'@type': 'PropertyValue', 'name': 'ENSEMBL', 'value': 'ENSG00000125354'},
#     {'@type': 'PropertyValue', 'name': 'ENSEMBL', 'value': 'ENSG00000138758'},
#     {'@type': 'PropertyValue', 'name': 'ENSEMBL', 'value': 'ENSG00000164402'},
#     {'@type': 'PropertyValue', 'name': 'Uniprot', 'value': 'Q14141'},
#     {'@type': 'PropertyValue', 'name': 'Uniprot', 'value': 'Q9NVA2'},
#     {'@type': 'PropertyValue', 'name': 'Uniprot', 'value': 'Q92599'}],
#    'isLocatedInSubcellularLocation': [{'@type': 'PropertyValue',
#      'name': 'Chromosome Number',
#      'value': 'X'},
#     {'@type': 'PropertyValue', 'name': 'Chromosome Number', 'value': '4'},
#     {'@type': 'PropertyValue', 'name': 'Chromosome Number', 'value': '5'}],
#    'description': None},
#   {'@id': 'ark:59853/b2ai-antibody-HPA005700',
#    '@type': 'BioChemEntity',
#    'name': 'Stain HPA005700',
#    'identifier': [{'@type': 'PropertyValue',
#      'name': 'HPA Antibody ID',
#      'value': 'HPA005700'},
#     {'@type': 'PropertyValue', 'name': 'ENSEMBL', 'value': 'ENSG00000100030'},
#     {'@type': 'PropertyValue', 'name': 'ENSEMBL', 'value': 'ENSG00000102882'},
#     {'@type': 'PropertyValue', 'name': 'ENSEMBL', 'value': 'ENSG00000100030'},
#     {'@type': 'PropertyValue', 'name': 'ENSEMBL', 'value': 'ENSG00000102882'},
#     {'@type': 'PropertyValue', 'name': 'Uniprot', 'value': 'P28482'},
#     {'@type': 'PropertyValue', 'name': 'Uniprot', 'value': 'P27361'}],
#    'isLocatedInSubcellularLocation': [{'@type': 'PropertyValue',
#      'name': 'Chromosome Number',
#      'value': '22'},
#     {'@type': 'PropertyValue', 'name': 'Chromosome Number', 'value': '16'}],
#    'description': None},
#   {'@id': 'ark:59853/b2ai-antibody-HPA005734',
#    '@type': 'BioChemEntity',
#    'name': 'Stain HPA005734',
#    'identifier': [{'@type': 'PropertyValue',
#      'name': 'HPA Antibody ID',
#      'value': 'HPA005734'},
#     {'@type': 'PropertyValue', 'name': 'ENSEMBL', 'value': 'ENSG00000066739'},
#     {'@type': 'PropertyValue', 'name': 'ENSEMBL', 'value': 'ENSG00000066739'},
#     {'@type': 'PropertyValue', 'name': 'Uniprot', 'value': 'Q96BY7'}],
#    'isLocatedInSubcellularLocation': [{'@type': 'PropertyValue',
#      'name': 'Chromosome Number',
#      'value': '14'}],
#    'description': None},
#   {'@id': 'ark:59853/b2ai-antibody-HPA005835',
#    '@type': 'BioChemEntity',
#    'name': 'Stain HPA005835',
#    'identifier': [{'@type': 'PropertyValue',
#      'name': 'HPA Antibody ID',
#      'value': 'HPA005835'},
#     {'@type': 'PropertyValue', 'name': 'ENSEMBL', 'value': 'ENSG00000104823'},
#     {'@type': 'PropertyValue', 'name': 'ENSEMBL', 'value': 'ENSG00000104823'},
#     {'@type': 'PropertyValue', 'name': 'Uniprot', 'value': 'Q13011'}],
#    'isLocatedInSubcellularLocation': [{'@type': 'PropertyValue',
#      'name': 'Chromosome Number',
#      'value': '19'}],
#    'description': None},
#   {'@id': 'ark:59853/b2ai-antibody-HPA005992',
#    '@type': 'BioChemEntity',
#    'name': 'Stain HPA005992',
#    'identifier': [{'@type': 'PropertyValue',
#      'name': 'HPA Antibody ID',
#      'value': 'HPA005992'},
#     {'@type': 'PropertyValue', 'name': 'ENSEMBL', 'value': 'ENSG00000014216'},
#     {'@type': 'PropertyValue', 'name': 'ENSEMBL', 'value': 'ENSG00000014216'},
#     {'@type': 'PropertyValue', 'name': 'Uniprot', 'value': 'P07384'}],
#    'isLocatedInSubcellularLocation': [{'@type': 'PropertyValue',
#      'name': 'Chromosome Number',
#      'value': '11'}],
#    'description': None},
#   {'@id': 'ark:59853/b2ai-antibody-HPA005993',
#    '@type': 'BioChemEntity',
#    'name': 'Stain HPA005993',
#    'identifier': [{'@type': 'PropertyValue',
#      'name': 'HPA Antibody ID',
#      'value': 'HPA005993'},
#     {'@type': 'PropertyValue', 'name': 'ENSEMBL', 'value': 'ENSG00000154277'},
#     {'@type': 'PropertyValue', 'name': 'ENSEMBL', 'value': 'ENSG00000154277'},
#     {'@type': 'PropertyValue', 'name': 'Uniprot', 'value': 'P09936'}],
#    'isLocatedInSubcellularLocation': [{'@type': 'PropertyValue',
#      'name': 'Chromosome Number',
#      'value': '4'}],
#    'description': None},
#   {'@id': 'ark:59853/b2ai-antibody-HPA006035',
#    '@type': 'BioChemEntity',
#    'name': 'Stain HPA006035',
#    'identifier': [{'@type': 'PropertyValue',
#      'name': 'HPA Antibody ID',
#      'value': 'HPA006035'},
#     {'@type': 'PropertyValue', 'name': 'ENSEMBL', 'value': 'ENSG00000072110'},
#     {'@type': 'PropertyValue', 'name': 'ENSEMBL', 'value': 'ENSG00000077522'},
#     {'@type': 'PropertyValue', 'name': 'ENSEMBL', 'value': 'ENSG00000130402'},
#     {'@type': 'PropertyValue', 'name': 'ENSEMBL', 'value': 'ENSG00000248746'},
#     {'@type': 'PropertyValue', 'name': 'ENSEMBL', 'value': 'ENSG00000072110'},
#     {'@type': 'PropertyValue', 'name': 'ENSEMBL', 'value': 'ENSG00000077522'},
#     {'@type': 'PropertyValue', 'name': 'ENSEMBL', 'value': 'ENSG00000130402'},
#     {'@type': 'PropertyValue', 'name': 'ENSEMBL', 'value': 'ENSG00000248746'},
#     {'@type': 'PropertyValue', 'name': 'Uniprot', 'value': 'O43707'},
#     {'@type': 'PropertyValue', 'name': 'Uniprot', 'value': 'P12814'},
#     {'@type': 'PropertyValue', 'name': 'Uniprot', 'value': 'Q08043'},
#     {'@type': 'PropertyValue', 'name': 'Uniprot', 'value': 'P35609'}],
#    'isLocatedInSubcellularLocation': [{'@type': 'PropertyValue',
#      'name': 'Chromosome Number',
#      'value': '19'},
#     {'@type': 'PropertyValue', 'name': 'Chromosome Number', 'value': '14'},
#     {'@type': 'PropertyValue', 'name': 'Chromosome Number', 'value': '11'},
#     {'@type': 'PropertyValue', 'name': 'Chromosome Number', 'value': '1'}],
#    'description': None},
#   {'@id': 'ark:59853/b2ai-antibody-HPA006104',
#    '@type': 'BioChemEntity',
#    'name': 'Stain HPA006104',
#    'identifier': [{'@type': 'PropertyValue',
#      'name': 'HPA Antibody ID',
#      'value': 'HPA006104'},
#     {'@type': 'PropertyValue', 'name': 'ENSEMBL', 'value': 'ENSG00000156650'},
# ...
#    'usedTreatment': {'@id': 'ark:59853/treatment-paclitaxel'},
#    'description': 'This immunoflouresence image was taken of a well containing cells from the MDA-MB-468 cell line. The drug Paclitaxel was applied to these cells. This sample was stained with the compound DAPI to label the cell nucleus.',
#    'keywords': ['Machine learning',
#     'Artificial intelligence',
#     'Breast cancer',
#     'Paclitaxel',
#     'Vorinostat',
#     'IF',
#     'Microscopy',
#     'Immunofluorescence',
#     'Nucleus',
#     'DAPI'],
#    'associatedPublication': None,
#    'contentUrl': 'file:///blue/B2AI_3_Paclitaxel_D12_R4_z01_blue.jpg',
#    'datePublished': '02/28/2025',
#    'format': 'image/jpeg'},
#   {'@id': 'ark:59853/B2AI_3_Paclitaxel_D12_R4_z01_red',
#    '@type': 'EVI:Dataset',
#    'name': 'B2AI IF Image B2AI_3_Paclitaxel_D12_R4_z01_red.jpg',
#    'author': ['Hansen JN',
#     'Axelsson U',
#     'Johannesson A',
#     'Fall J',
#     'Ballllosera Navarro F',
#     'Lundberg E'],
#    'usedStain': {'@id': 'ark:59853/stain-tubulin-antibody'},
#    'usedCellLine': {'@id': 'ark:59853/cell-line-MDA-MB-468'},
#    'usedTreatment': {'@id': 'ark:59853/treatment-paclitaxel'},
#    'description': 'This immunoflouresence image was taken of a well containing cells from the MDA-MB-468 cell line. The drug Paclitaxel was applied to these cells. This sample was stained with a tubulin antibody to label the microtubili of the cytoskeleton.',
#    'keywords': ['Machine learning',
#     'Artificial intelligence',
#     'Breast cancer',
#     'Paclitaxel',
#     'Vorinostat',
#     'IF',
#     'Microscopy',
#     'Immunofluorescence',
#     'Cytoskeleton',
#     'Tubulin'],
#    'associatedPublication': None,
#    'contentUrl': 'file:///red/B2AI_3_Paclitaxel_D12_R4_z01_red.jpg',
#    'datePublished': '02/28/2025',
#    'format': 'image/jpeg'},
#   {'@id': 'ark:59853/B2AI_3_Paclitaxel_D12_R4_z01_yellow',
#    '@type': 'EVI:Dataset',
#    'name': 'CM4AI IF Image B2AI_3_Paclitaxel_D12_R4_z01_yellow.jpg',
#    'author': ['Hansen JN',
#     'Axelsson U',
#     'Johannesson A',
#     'Fall J',
#     'Ballllosera Navarro F',
#     'Lundberg E'],
#    'usedStain': {'@id': 'ark:59853/stain-calreticulin-antibody'},
#    'usedCellLine': {'@id': 'ark:59853/cell-line-MDA-MB-468'},
#    'usedTreatment': {'@id': 'ark:59853/treatment-paclitaxel'},
#    'description': 'This immunoflouresence image was taken of a well containing cells from the MDA-MB-468 cell line. The drug Paclitaxel was applied to these cells. This sample was stained with a calreticulin antibody to label the endoplasmic reticulum.',
#    'keywords': ['Machine learning',
#     'Artificial intelligence',
#     'Breast cancer',
#     'Paclitaxel',
#     'Vorinostat',
#     'IF',
#     'Microscopy',
#     'Immunofluorescence',
#     'Endoplasmic Reticulum',
#     'ER',
#     'Calreticulin'],
#    'associatedPublication': None,
#    'contentUrl': 'file:///yellow/B2AI_3_Paclitaxel_D12_R4_z01_yellow.jpg',
#    'datePublished': '02/28/2025',
#    'format': 'image/jpeg'},
#   {'@id': 'ark:59853/B2AI_3_Paclitaxel_D12_R4_z01_green',
#    '@type': 'EVI:Dataset',
#    'name': 'CM4AI IF Image B2AI_3_Paclitaxel_D12_R4_z01_green.jpg',
#    'author': ['Hansen JN',
#     'Axelsson U',
#     'Johannesson A',
#     'Fall J',
#     'Ballllosera Navarro F',
#     'Lundberg E'],
#    'usedStain': {'@id': 'ark:59853/b2ai-antibody-HPA075204'},
#    'usedCellLine': {'@id': 'ark:59853/cell-line-MDA-MB-468'},
#    'usedTreatment': {'@id': 'ark:59853/treatment-paclitaxel'},
#    'description': 'This immunoflouresence image was taken of a well containing cells from the MDA-MB-468 cell line. The drug Paclitaxel was applied to these cells. This sample was stained with a variable antibody.',
#    'keywords': ['Machine learning',
#     'Artificial intelligence',
#     'Breast cancer',
#     'Paclitaxel',
#     'Vorinostat',
#     'IF',
#     'Microscopy',
#     'Immunofluorescence'],
#    'associatedPublication': None,
#    'contentUrl': 'file:///green/B2AI_3_Paclitaxel_D12_R4_z01_green.jpg',
#    'datePublished': '02/28/2025',
#    'format': 'image/jpeg'},
#   {'@id': 'ark:59853/B2AI_3_Paclitaxel_D12_R3_z02_blue',
#    '@type': 'EVI:Dataset',
#    'name': 'B2AI IF Image B2AI_3_Paclitaxel_D12_R3_z02_blue.jpg',
#    'author': ['Hansen JN',
#     'Axelsson U',
#     'Johannesson A',
#     'Fall J',
#     'Ballllosera Navarro F',
#     'Lundberg E'],
#    'usedStain': {'@id': 'ark:59853/stain-dapi'},
#    'usedCellLine': {'@id': 'ark:59853/cell-line-MDA-MB-468'},
#    'usedTreatment': {'@id': 'ark:59853/treatment-paclitaxel'},
#    'description': 'This immunoflouresence image was taken of a well containing cells from the MDA-MB-468 cell line. The drug Paclitaxel was applied to these cells. This sample was stained with the compound DAPI to label the cell nucleus.',
#    'keywords': ['Machine learning',
#     'Artificial intelligence',
#     'Breast cancer',
#     'Paclitaxel',
#     'Vorinostat',
#     'IF',
#     'Microscopy',
#     'Immunofluorescence',
#     'Nucleus',
#     'DAPI'],
#    'associatedPublication': None,
#    'contentUrl': 'file:///blue/B2AI_3_Paclitaxel_D12_R3_z02_blue.jpg',
#    'datePublished': '02/28/2025',
#    'format': 'image/jpeg'},
#   {'@id': 'ark:59853/B2AI_3_Paclitaxel_D12_R3_z02_red',
#    '@type': 'EVI:Dataset',
#    'name': 'B2AI IF Image B2AI_3_Paclitaxel_D12_R3_z02_red.jpg',
#    'author': ['Hansen JN',
#     'Axelsson U',
#     'Johannesson A',
#     'Fall J',
#     'Ballllosera Navarro F',
#     'Lundberg E'],
#    'usedStain': {'@id': 'ark:59853/stain-tubulin-antibody'},
#    'usedCellLine': {'@id': 'ark:59853/cell-line-MDA-MB-468'},
#    'usedTreatment': {'@id': 'ark:59853/treatment-paclitaxel'},
#    'description': 'This immunoflouresence image was taken of a well containing cells from the MDA-MB-468 cell line. The drug Paclitaxel was applied to these cells. This sample was stained with a tubulin antibody to label the microtubili of the cytoskeleton.',
#    'keywords': ['Machine learning',
#     'Artificial intelligence',
#     'Breast cancer',
#     'Paclitaxel',
#     'Vorinostat',
#     'IF',
#     'Microscopy',
#     'Immunofluorescence',
#     'Cytoskeleton',
#     'Tubulin'],
#    'associatedPublication': None,
#    'contentUrl': 'file:///red/B2AI_3_Paclitaxel_D12_R3_z02_red.jpg',
#    'datePublished': '02/28/2025',
#    'format': 'image/jpeg'},
#   {'@id': 'ark:59853/B2AI_3_Paclitaxel_D12_R3_z02_yellow',
#    '@type': 'EVI:Dataset',
#    'name': 'CM4AI IF Image B2AI_3_Paclitaxel_D12_R3_z02_yellow.jpg',
#    'author': ['Hansen JN',
#     'Axelsson U',
#     'Johannesson A',
#     'Fall J',
#     'Ballllosera Navarro F',
#     'Lundberg E'],
#    'usedStain': {'@id': 'ark:59853/stain-calreticulin-antibody'},
#    'usedCellLine': {'@id': 'ark:59853/cell-line-MDA-MB-468'},
#    'usedTreatment': {'@id': 'ark:59853/treatment-paclitaxel'},
#    'description': 'This immunoflouresence image was taken of a well containing cells from the MDA-MB-468 cell line. The drug Paclitaxel was applied to these cells. This sample was stained with a calreticulin antibody to label the endoplasmic reticulum.',
#    'keywords': ['Machine learning',
#     'Artificial intelligence',
#     'Breast cancer',
#     'Paclitaxel',
#     'Vorinostat',
#     'IF',
#     'Microscopy',
#     'Immunofluorescence',
#     'Endoplasmic Reticulum',
#     'ER',
#     'Calreticulin'],
#    'associatedPublication': None,
#    'contentUrl': 'file:///yellow/B2AI_3_Paclitaxel_D12_R3_z02_yellow.jpg',
#    'datePublished': '02/28/2025',
#    'format': 'image/jpeg'},
#   {'@id': 'ark:59853/B2AI_3_Paclitaxel_D12_R3_z02_green',
#    '@type': 'EVI:Dataset',
#    'name': 'CM4AI IF Image B2AI_3_Paclitaxel_D12_R3_z02_green.jpg',
#    'author': ['Hansen JN',
#     'Axelsson U',
#     'Johannesson A',
#     'Fall J',
#     'Ballllosera Navarro F',
#     'Lundberg E'],
#    'usedStain': {'@id': 'ark:59853/b2ai-antibody-HPA075204'},
#    'usedCellLine': {'@id': 'ark:59853/cell-line-MDA-MB-468'},
#    'usedTreatment': {'@id': 'ark:59853/treatment-paclitaxel'},
#    'description': 'This immunoflouresence image was taken of a well containing cells from the MDA-MB-468 cell line. The drug Paclitaxel was applied to these cells. This sample was stained with a variable antibody.',
#    'keywords': ['Machine learning',
#     'Artificial intelligence',
#     'Breast cancer',
#     'Paclitaxel',
#     'Vorinostat',
#     'IF',
#     'Microscopy',
#     'Immunofluorescence'],
#    'associatedPublication': None,
#    'contentUrl': 'file:///green/B2AI_3_Paclitaxel_D12_R3_z02_green.jpg',
#    'datePublished': '02/28/2025',
#    'format': 'image/jpeg'},
#   {'@id': 'ark:59853/B2AI_3_Paclitaxel_D12_R14_z00_blue',
#    '@type': 'EVI:Dataset',
#    'name': 'B2AI IF Image B2AI_3_Paclitaxel_D12_R14_z00_blue.jpg',
#    'author': ['Hansen JN',
#     'Axelsson U',
#     'Johannesson A',
#     'Fall J',
#     'Ballllosera Navarro F',
#     'Lundberg E'],
#    'usedStain': {'@id': 'ark:59853/stain-dapi'},
#    'usedCellLine': {'@id': 'ark:59853/cell-line-MDA-MB-468'},
#    'usedTreatment': {'@id': 'ark:59853/treatment-paclitaxel'},
#    'description': 'This immunoflouresence image was taken of a well containing cells from the MDA-MB-468 cell line. The drug Paclitaxel was applied to these cells. This sample was stained with the compound DAPI to label the cell nucleus.',
#    'keywords': ['Machine learning',
#     'Artificial intelligence',
#     'Breast cancer',
#     'Paclitaxel',
#     'Vorinostat',
#     'IF',
#     'Microscopy',
#     'Immunofluorescence',
#     'Nucleus',
#     'DAPI'],
#    'associatedPublication': None,
#    'contentUrl': 'file:///blue/B2AI_3_Paclitaxel_D12_R14_z00_blue.jpg',
#    'datePublished': '02/28/2025',
#    'format': 'image/jpeg'},
#   {'@id': 'ark:59853/B2AI_3_Paclitaxel_D12_R14_z00_red',
#    '@type': 'EVI:Dataset',
#    'name': 'B2AI IF Image B2AI_3_Paclitaxel_D12_R14_z00_red.jpg',
#    'author': ['Hansen JN',
#     'Axelsson U',
#     'Johannesson A',
#     'Fall J',
#     'Ballllosera Navarro F',
#     'Lundberg E'],
#    'usedStain': {'@id': 'ark:59853/stain-tubulin-antibody'},
#    'usedCellLine': {'@id': 'ark:59853/cell-line-MDA-MB-468'},
#    'usedTreatment': {'@id': 'ark:59853/treatment-paclitaxel'},
#    'description': 'This immunoflouresence image was taken of a well containing cells from the MDA-MB-468 cell line. The drug Paclitaxel was applied to these cells. This sample was stained with a tubulin antibody to label the microtubili of the cytoskeleton.',
#    'keywords': ['Machine learning',
#     'Artificial intelligence',
#     'Breast cancer',
#     'Paclitaxel',
#     'Vorinostat',
#     'IF',
#     'Microscopy',
#     'Immunofluorescence',
#     'Cytoskeleton',
#     'Tubulin'],
#    'associatedPublication': None,
#    'contentUrl': 'file:///red/B2AI_3_Paclitaxel_D12_R14_z00_red.jpg',
#    'datePublished': '02/28/2025',
#    'format': 'image/jpeg'},
#   {'@id': 'ark:59853/B2AI_3_Paclitaxel_D12_R14_z00_yellow',
#    '@type': 'EVI:Dataset',
#    'name': 'CM4AI IF Image B2AI_3_Paclitaxel_D12_R14_z00_yellow.jpg',
#    'author': ['Hansen JN',
#     'Axelsson U',
#     'Johannesson A',
#     'Fall J',
#     'Ballllosera Navarro F',
#     'Lundberg E'],
#    'usedStain': {'@id': 'ark:59853/stain-calreticulin-antibody'},
#    'usedCellLine': {'@id': 'ark:59853/cell-line-MDA-MB-468'},
#    'usedTreatment': {'@id': 'ark:59853/treatment-paclitaxel'},
#    'description': 'This immunoflouresence image was taken of a well containing cells from the MDA-MB-468 cell line. The drug Paclitaxel was applied to these cells. This sample was stained with a calreticulin antibody to label the endoplasmic reticulum.',
#    'keywords': ['Machine learning',
#     'Artificial intelligence',
#     'Breast cancer',
#     'Paclitaxel',
#     'Vorinostat',
#     'IF',
#     'Microscopy',
#     'Immunofluorescence',
#     'Endoplasmic Reticulum',
#     'ER',
#     'Calreticulin'],
#    'associatedPublication': None,
#    'contentUrl': 'file:///yellow/B2AI_3_Paclitaxel_D12_R14_z00_yellow.jpg',
#    'datePublished': '02/28/2025',
#    'format': 'image/jpeg'},
#   {'@id': 'ark:59853/B2AI_3_Paclitaxel_D12_R14_z00_green',
#    '@type': 'EVI:Dataset',
#    'name': 'CM4AI IF Image B2AI_3_Paclitaxel_D12_R14_z00_green.jpg',
#    'author': ['Hansen JN',
#     'Axelsson U',
#     'Johannesson A',
#     'Fall J',
#     'Ballllosera Navarro F',
#     'Lundberg E'],
#    'usedStain': {'@id': 'ark:59853/b2ai-antibody-HPA075204'},
#    'usedCellLine': {'@id': 'ark:59853/cell-line-MDA-MB-468'},
#    'usedTreatment': {'@id': 'ark:59853/treatment-paclitaxel'},
#    'description': 'This immunoflouresence image was taken of a well containing cells from the MDA-MB-468 cell line. The drug Paclitaxel was applied to these cells. This sample was stained with a variable antibody.',
#    'keywords': ['Machine learning',
#     'Artificial intelligence',
#     'Breast cancer',
#     'Paclitaxel',
#     'Vorinostat',
#     'IF',
#     'Microscopy',
#     'Immunofluorescence'],
#    'associatedPublication': None,
#    'contentUrl': 'file:///green/B2AI_3_Paclitaxel_D12_R14_z00_green.jpg',
#    'datePublished': '02/28/2025',
#    'format': 'image/jpeg'},
#   {'@id': 'ark:59853/B2AI_3_Paclitaxel_D12_R13_z01_blue',
#    '@type': 'EVI:Dataset',
#    'name': 'B2AI IF Image B2AI_3_Paclitaxel_D12_R13_z01_blue.jpg',
#    'author': ['Hansen JN',
#     'Axelsson U',
#     'Johannesson A',
#     'Fall J',
#     'Ballllosera Navarro F',
#     'Lundberg E'],
#    'usedStain': {'@id': 'ark:59853/stain-dapi'},
#    'usedCellLine': {'@id': 'ark:59853/cell-line-MDA-MB-468'},
#    'usedTreatment': {'@id': 'ark:59853/treatment-paclitaxel'},
#    'description': 'This immunoflouresence image was taken of a well containing cells from the MDA-MB-468 cell line. The drug Paclitaxel was applied to these cells. This sample was stained with the compound DAPI to label the cell nucleus.',
#    'keywords': ['Machine learning',
#     'Artificial intelligence',
#     'Breast cancer',
#     'Paclitaxel',
#     'Vorinostat',
#     'IF',
#     'Microscopy',
#     'Immunofluorescence',
#     'Nucleus',
#     'DAPI'],
#    'associatedPublication': None,
#    'contentUrl': 'file:///blue/B2AI_3_Paclitaxel_D12_R13_z01_blue.jpg',
#    'datePublished': '02/28/2025',
#    'format': 'image/jpeg'},
#   {'@id': 'ark:59853/B2AI_3_Paclitaxel_D12_R13_z01_red',
#    '@type': 'EVI:Dataset',
#    'name': 'B2AI IF Image B2AI_3_Paclitaxel_D12_R13_z01_red.jpg',
#    'author': ['Hansen JN',
#     'Axelsson U',
#     'Johannesson A',
#     'Fall J',
#     'Ballllosera Navarro F',
#     'Lundberg E'],
#    'usedStain': {'@id': 'ark:59853/stain-tubulin-antibody'},
#    'usedCellLine': {'@id': 'ark:59853/cell-line-MDA-MB-468'},
#    'usedTreatment': {'@id': 'ark:59853/treatment-paclitaxel'},
#    'description': 'This immunoflouresence image was taken of a well containing cells from the MDA-MB-468 cell line. The drug Paclitaxel was applied to these cells. This sample was stained with a tubulin antibody to label the microtubili of the cytoskeleton.',
#    'keywords': ['Machine learning',
#     'Artificial intelligence',
#     'Breast cancer',
#     'Paclitaxel',
#     'Vorinostat',
#     'IF',
#     'Microscopy',
#     'Immunofluorescence',
#     'Cytoskeleton',
#     'Tubulin'],
#    'associatedPublication': None,
#    'contentUrl': 'file:///red/B2AI_3_Paclitaxel_D12_R13_z01_red.jpg',
#    'datePublished': '02/28/2025',
#    'format': 'image/jpeg'},
#   {'@id': 'ark:59853/B2AI_3_Paclitaxel_D12_R13_z01_yellow',
#    '@type': 'EVI:Dataset',
#    'name': 'CM4AI IF Image B2AI_3_Paclitaxel_D12_R13_z01_yellow.jpg',
#    'author': ['Hansen JN',
#     'Axelsson U',
#     'Johannesson A',
#     'Fall J',
#     'Ballllosera Navarro F',
#     'Lundberg E'],
#    'usedStain': {'@id': 'ark:59853/stain-calreticulin-antibody'},
#    'usedCellLine': {'@id': 'ark:59853/cell-line-MDA-MB-468'},
#    'usedTreatment': {'@id': 'ark:59853/treatment-paclitaxel'},
#    'description': 'This immunoflouresence image was taken of a well containing cells from the MDA-MB-468 cell line. The drug Paclitaxel was applied to these cells. This sample was stained with a calreticulin antibody to label the endoplasmic reticulum.',
#    'keywords': ['Machine learning',
#     'Artificial intelligence',
#     'Breast cancer',
#     'Paclitaxel',
#     'Vorinostat',
#     'IF',
#     'Microscopy',
#     'Immunofluorescence',
#     'Endoplasmic Reticulum',
#     'ER',
#     'Calreticulin'],
#    'associatedPublication': None,
#    'contentUrl': 'file:///yellow/B2AI_3_Paclitaxel_D12_R13_z01_yellow.jpg',
#    'datePublished': '02/28/2025',
#    'format': 'image/jpeg'},
#   ...]}

# %%
import sys
def sizeof(obj):
	size = sys.getsizeof(obj)
	if isinstance(obj, dict): 
		return size + sum(map(sizeof, obj.keys())) + sum(map(sizeof, obj.values()))
	if isinstance(obj, (list, tuple, set, frozenset)): 
		return size + sum(map(sizeof, obj))
	return size

# %%
sizeof(roCrateJSON) / 10**6
# Out:
# 98.071248

# %%
# find metadata object
try: 
	s3Response = appConfig.minioClient.get_object(
		Bucket = appConfig.minioBucket,
		Key = metadataKey
	)
except json.JSONDecodeError:
	raise Exception("Failed to Decode Metadata JSON")

# %%
def recursiveMinioSearch(s3Client, bucket: str, prefix: str, key: str):	

	listResponse = s3Client.list_objects_v2(
		Bucket= bucket,
		Prefix= prefix
	)

	nextToken = listResponse['NextContinuationToken']
	matchedMetadataKeys = []
	isTruncated = listResponse['IsTruncated']

	while isTruncated:

		matchedMetadataKeys = list(
			filter(
				lambda x: key in x['Key'],
				listResponse['Contents']
				)
			)

		listResponse = s3Client.list_objects_v2(
			Bucket=bucket,
			Prefix=prefix,
			ContinuationToken= nextToken
		)

		nextToken = listResponse.get('ContinuationToken')
		isTruncated = listResponse['IsTruncated']

	return matchedMetadataKeys

# %%
listResponse = recursiveMinioSearch(
	s3Client=appConfig.minioClient,
	bucket= appConfig.minioBucket,
	prefix= jobInstance.uploadPath + "/",
	key = "ro-crate-metadata.json"
)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[75], line 1
# ----> 1 listResponse = recursiveMinioSearch(
#       2 	s3Client=appConfig.minioClient,
#       3 	bucket= appConfig.minioBucket,
#       4 	prefix= jobInstance.uploadPath + "/",
#       5 	key = "ro-crate-metadata.json"
#       6 )
#
# Cell In[74], line 21, in recursiveMinioSearch(s3Client, bucket, prefix, key)
#      12 while isTruncated:
#      14 	matchedMetadataKeys = list(
#      15 		filter(
#      16 			lambda x: key in x['Key'],
#      17 			listResponse['Contents']
#      18 			)
#      19 		)
# ---> 21 	listResponse = s3Client.list_objects_v2(
#      22 		Bucket=bucket,
#      23 		Prefix=prefix,
#      24 		ContinuationToken= nextToken
#      25 	)
#      27 	nextToken = listResponse.get('ContinuationToken')
#      28 	isTruncated = listResponse['IsTruncated']
#
# File c:\Users\Max\anaconda3\Lib\site-packages\botocore\client.py:602, in ClientCreator._create_api_method.<locals>._api_call(self, *args, **kwargs)
#     598     raise TypeError(
#     599         f"{py_operation_name}() only accepts keyword arguments."
#     600     )
#     601 # The "self" in this scope is referring to the BaseClient.
# --> 602 return self._make_api_call(operation_name, kwargs)
#
# File c:\Users\Max\anaconda3\Lib\site-packages\botocore\context.py:123, in with_current_context.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     121 if hook:
#     122     hook()
# --> 123 return func(*args, **kwargs)
#
# File c:\Users\Max\anaconda3\Lib\site-packages\botocore\client.py:1060, in BaseClient._make_api_call(self, operation_name, api_params)
#    1056     maybe_compress_request(
#    1057         self.meta.config, request_dict, operation_model
#    1058     )
#    1059     apply_request_checksum(request_dict)
# -> 1060     http, parsed_response = self._make_request(
#    1061         operation_model, request_dict, request_context
#    1062     )
#    1064 self.meta.events.emit(
#    1065     f'after-call.{service_id}.{operation_name}',
#    1066     http_response=http,
#    (...)
#    1069     context=request_context,
#    1070 )
#    1072 if http.status_code >= 300:
#
# File c:\Users\Max\anaconda3\Lib\site-packages\botocore\client.py:1084, in BaseClient._make_request(self, operation_model, request_dict, request_context)
#    1082 def _make_request(self, operation_model, request_dict, request_context):
#    1083     try:
# -> 1084         return self._endpoint.make_request(operation_model, request_dict)
#    1085     except Exception as e:
#    1086         self.meta.events.emit(
#    1087             f'after-call-error.{self._service_model.service_id.hyphenize()}.{operation_model.name}',
#    1088             exception=e,
#    1089             context=request_context,
#    1090         )
#
# File c:\Users\Max\anaconda3\Lib\site-packages\botocore\endpoint.py:119, in Endpoint.make_request(self, operation_model, request_dict)
#     113 def make_request(self, operation_model, request_dict):
#     114     logger.debug(
#     115         "Making request for %s with params: %s",
#     116         operation_model,
#     117         request_dict,
#     118     )
# --> 119     return self._send_request(request_dict, operation_model)
#
# File c:\Users\Max\anaconda3\Lib\site-packages\botocore\endpoint.py:197, in Endpoint._send_request(self, request_dict, operation_model)
#     195 self._update_retries_context(context, attempts)
#     196 request = self.create_request(request_dict, operation_model)
# --> 197 success_response, exception = self._get_response(
#     198     request, operation_model, context
#     199 )
#     200 while self._needs_retry(
#     201     attempts,
#     202     operation_model,
#    (...)
#     205     exception,
#     206 ):
#     207     attempts += 1
#
# File c:\Users\Max\anaconda3\Lib\site-packages\botocore\endpoint.py:239, in Endpoint._get_response(self, request, operation_model, context)
#     233 def _get_response(self, request, operation_model, context):
#     234     # This will return a tuple of (success_response, exception)
#     235     # and success_response is itself a tuple of
#     236     # (http_response, parsed_dict).
#     237     # If an exception occurs then the success_response is None.
#     238     # If no exception occurs then exception is None.
# --> 239     success_response, exception = self._do_get_response(
#     240         request, operation_model, context
#     241     )
#     242     kwargs_to_emit = {
#     243         'response_dict': None,
#     244         'parsed_response': None,
#     245         'context': context,
#     246         'exception': exception,
#     247     }
#     248     if success_response is not None:
#
# File c:\Users\Max\anaconda3\Lib\site-packages\botocore\endpoint.py:313, in Endpoint._do_get_response(self, request, operation_model, context)
#     306 self._event_emitter.emit(
#     307     f"before-parse.{service_id}.{operation_model.name}",
#     308     operation_model=operation_model,
#     309     response_dict=response_dict,
#     310     customized_response_dict=customized_response_dict,
#     311 )
#     312 parser = self._response_parser_factory.create_parser(protocol)
# --> 313 parsed_response = parser.parse(
#     314     response_dict, operation_model.output_shape
#     315 )
#     316 parsed_response.update(customized_response_dict)
#     317 # Do a second parsing pass to pick up on any modeled error fields
#     318 # NOTE: Ideally, we would push this down into the parser classes but
#     319 # they currently have no reference to the operation or service model
#     320 # The parsers should probably take the operation model instead of
#     321 # output shape but we can't change that now
#
# File c:\Users\Max\anaconda3\Lib\site-packages\botocore\parsers.py:267, in ResponseParser.parse(self, response, shape)
#     265         parsed = self._do_error_parse(response, shape)
#     266 else:
# --> 267     parsed = self._do_parse(response, shape)
#     269 # We don't want to decorate event stream responses with metadata
#     270 if shape and shape.serialization.get('eventstream'):
#
# File c:\Users\Max\anaconda3\Lib\site-packages\botocore\parsers.py:1119, in BaseRestParser._do_parse(self, response, shape)
#    1115 final_parsed = {}
#    1116 final_parsed['ResponseMetadata'] = self._populate_response_metadata(
#    1117     response
#    1118 )
# -> 1119 self._add_modeled_parse(response, shape, final_parsed)
#    1120 return final_parsed
#
# File c:\Users\Max\anaconda3\Lib\site-packages\botocore\parsers.py:1129, in BaseRestParser._add_modeled_parse(self, response, shape, final_parsed)
#    1125 member_shapes = shape.members
#    1126 self._parse_non_payload_attrs(
#    1127     response, shape, member_shapes, final_parsed
#    1128 )
# -> 1129 self._parse_payload(response, shape, member_shapes, final_parsed)
#
# File c:\Users\Max\anaconda3\Lib\site-packages\botocore\parsers.py:1171, in BaseRestParser._parse_payload(self, response, shape, member_shapes, final_parsed)
#    1169 else:
#    1170     original_parsed = self._initial_body_parse(response['body'])
# -> 1171     body_parsed = self._parse_shape(shape, original_parsed)
#    1172     final_parsed.update(body_parsed)
#
# File c:\Users\Max\anaconda3\Lib\site-packages\botocore\parsers.py:347, in ResponseParser._parse_shape(self, shape, node)
#     343 def _parse_shape(self, shape, node):
#     344     handler = getattr(
#     345         self, f'_handle_{shape.type_name}', self._default_handle
#     346     )
# --> 347     return handler(shape, node)
#
# File c:\Users\Max\anaconda3\Lib\site-packages\botocore\parsers.py:476, in BaseXMLResponseParser._handle_structure(self, shape, node)
#     474 member_node = xml_dict.get(xml_name)
#     475 if member_node is not None:
# --> 476     parsed[member_name] = self._parse_shape(
#     477         member_shape, member_node
#     478     )
#     479 elif member_shape.serialization.get('xmlAttribute'):
#     480     attribs = {}
#
# File c:\Users\Max\anaconda3\Lib\site-packages\botocore\parsers.py:347, in ResponseParser._parse_shape(self, shape, node)
#     343 def _parse_shape(self, shape, node):
#     344     handler = getattr(
#     345         self, f'_handle_{shape.type_name}', self._default_handle
#     346     )
# --> 347     return handler(shape, node)
#
# File c:\Users\Max\anaconda3\Lib\site-packages\botocore\parsers.py:1230, in BaseRestParser._handle_list(self, shape, node)
#    1227 if location == 'header' and not isinstance(node, list):
#    1228     # List in headers may be a comma separated string as per RFC7230
#    1229     node = [e.strip() for e in node.split(',')]
# -> 1230 return super()._handle_list(shape, node)
#
# File c:\Users\Max\anaconda3\Lib\site-packages\botocore\parsers.py:452, in BaseXMLResponseParser._handle_list(self, shape, node)
#     450 if shape.serialization.get('flattened') and not isinstance(node, list):
#     451     node = [node]
# --> 452 return super()._handle_list(shape, node)
#
# File c:\Users\Max\anaconda3\Lib\site-packages\botocore\parsers.py:355, in ResponseParser._handle_list(self, shape, node)
#     353 member_shape = shape.member
#     354 for item in node:
# --> 355     parsed.append(self._parse_shape(member_shape, item))
#     356 return parsed
#
# File c:\Users\Max\anaconda3\Lib\site-packages\botocore\parsers.py:347, in ResponseParser._parse_shape(self, shape, node)
#     343 def _parse_shape(self, shape, node):
#     344     handler = getattr(
#     345         self, f'_handle_{shape.type_name}', self._default_handle
#     346     )
# --> 347     return handler(shape, node)
#
# File c:\Users\Max\anaconda3\Lib\site-packages\botocore\parsers.py:476, in BaseXMLResponseParser._handle_structure(self, shape, node)
#     474 member_node = xml_dict.get(xml_name)
#     475 if member_node is not None:
# --> 476     parsed[member_name] = self._parse_shape(
#     477         member_shape, member_node
#     478     )
#     479 elif member_shape.serialization.get('xmlAttribute'):
#     480     attribs = {}
#
# File c:\Users\Max\anaconda3\Lib\site-packages\botocore\parsers.py:347, in ResponseParser._parse_shape(self, shape, node)
#     343 def _parse_shape(self, shape, node):
#     344     handler = getattr(
#     345         self, f'_handle_{shape.type_name}', self._default_handle
#     346     )
# --> 347     return handler(shape, node)
#
# File c:\Users\Max\anaconda3\Lib\site-packages\botocore\parsers.py:188, in _text_content.<locals>._get_text_content(self, shape, node_or_string)
#     186 else:
#     187     text = node_or_string
# --> 188 return func(self, shape, text)
#
# File c:\Users\Max\anaconda3\Lib\site-packages\botocore\parsers.py:573, in BaseXMLResponseParser._handle_timestamp(self, shape, text)
#     571 @_text_content
#     572 def _handle_timestamp(self, shape, text):
# --> 573     return self._timestamp_parser(text)
#
# File c:\Users\Max\anaconda3\Lib\site-packages\botocore\utils.py:993, in parse_timestamp(value)
#     991 for tzinfo in tzinfo_options:
#     992     try:
# --> 993         return _parse_timestamp_with_tzinfo(value, tzinfo)
#     994     except (OSError, OverflowError) as e:
#     995         logger.debug(
#     996             'Unable to parse timestamp with "%s" timezone info.',
#     997             tzinfo.__name__,
#     998             exc_info=e,
#     999         )
#
# File c:\Users\Max\anaconda3\Lib\site-packages\botocore\utils.py:973, in _parse_timestamp_with_tzinfo(value, tzinfo)
#     968         pass
#     969 try:
#     970     # In certain cases, a timestamp marked with GMT can be parsed into a
#     971     # different time zone, so here we provide a context which will
#     972     # enforce that GMT == UTC.
# --> 973     return dateutil.parser.parse(value, tzinfos={'GMT': tzutc()})
#     974 except (TypeError, ValueError) as e:
#     975     raise ValueError(f'Invalid timestamp "{value}": {e}')
#
# File c:\Users\Max\anaconda3\Lib\site-packages\dateutil\parser\_parser.py:1368, in parse(timestr, parserinfo, **kwargs)
#    1366     return parser(parserinfo).parse(timestr, **kwargs)
#    1367 else:
# -> 1368     return DEFAULTPARSER.parse(timestr, **kwargs)
#
# File c:\Users\Max\anaconda3\Lib\site-packages\dateutil\parser\_parser.py:640, in parser.parse(self, timestr, default, ignoretz, tzinfos, **kwargs)
#     636 if default is None:
#     637     default = datetime.datetime.now().replace(hour=0, minute=0,
#     638                                               second=0, microsecond=0)
# --> 640 res, skipped_tokens = self._parse(timestr, **kwargs)
#     642 if res is None:
#     643     raise ParserError("Unknown string format: %s", timestr)
#
# File c:\Users\Max\anaconda3\Lib\site-packages\dateutil\parser\_parser.py:719, in parser._parse(self, timestr, dayfirst, yearfirst, fuzzy, fuzzy_with_tokens)
#     716     yearfirst = info.yearfirst
#     718 res = self._result()
# --> 719 l = _timelex.split(timestr)         # Splits the timestr into tokens
#     721 skipped_idxs = []
#     723 # year/month/day list
#
# File c:\Users\Max\anaconda3\Lib\site-packages\dateutil\parser\_parser.py:201, in _timelex.split(cls, s)
#     199 @classmethod
#     200 def split(cls, s):
# --> 201     return list(cls(s))
#
# File c:\Users\Max\anaconda3\Lib\site-packages\dateutil\parser\_parser.py:190, in _timelex.__next__(self)
#     189 def __next__(self):
# --> 190     token = self.get_token()
#     191     if token is None:
#     192         raise StopIteration
#
# File c:\Users\Max\anaconda3\Lib\site-packages\dateutil\parser\_parser.py:106, in _timelex.get_token(self)
#     104     nextchar = self.charstack.pop(0)
#     105 else:
# --> 106     nextchar = self.instream.read(1)
#     107     while nextchar == '\x00':
#     108         nextchar = self.instream.read(1)
#
# KeyboardInterrupt:

# %%
listResponse
# Out:
# []

# %%
listResponse['ContinuationToken']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[63], line 1
# ----> 1 listResponse['ContinuationToken']
#
# KeyError: 'ContinuationToken'

# %%
listResponse
# Out:
# {'ResponseMetadata': {'RequestId': '18644D0B8935C0A5',
#   'HostId': 'dd9025bab4ad464b049177c95eb6ebf374d3b3fd1af9251148b658df7ac2e3e8',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'accept-ranges': 'bytes',
#    'content-length': '243527',
#    'content-type': 'application/xml',
#    'server': 'MinIO',
#    'strict-transport-security': 'max-age=31536000; includeSubDomains',
#    'vary': 'Origin, Accept-Encoding',
#    'x-amz-id-2': 'dd9025bab4ad464b049177c95eb6ebf374d3b3fd1af9251148b658df7ac2e3e8',
#    'x-amz-request-id': '18644D0B8935C0A5',
#    'x-content-type-options': 'nosniff',
#    'x-ratelimit-limit': '4450',
#    'x-ratelimit-remaining': '4450',
#    'x-xss-protection': '1; mode=block',
#    'date': 'Thu, 11 Sep 2025 18:14:26 GMT'},
#   'RetryAttempts': 0},
#  'IsTruncated': True,
#  'Contents': [{'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_A10_R12_z02_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 117738,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_A10_R13_z02_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 125429,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_A10_R6_z01_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 97221,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_A10_R7_z01_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 119901,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_A10_R8_z01_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 78040,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_A11_R10_z02_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 145163,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_A11_R6_z01_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 84992,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_A11_R7_z01_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 108175,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_A11_R8_z01_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 97702,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_A12_R10_z02_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 132332,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_A12_R11_z01_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 162057,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_A12_R12_z01_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 157598,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_A12_R13_z01_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 95627,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_A12_R14_z02_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 161758,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_A12_R15_z02_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 107008,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_A12_R2_z01_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 126351,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_A12_R7_z00_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 77919,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_A12_R8_z00_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 137217,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_A1_R2_z01_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 256505,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_A1_R5_z01_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 118164,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_A1_R6_z01_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 144380,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_A2_R11_z01_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 83059,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_A2_R12_z01_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 75148,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_A2_R14_z01_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 70799,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_A2_R17_z01_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 68345,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_A2_R18_z01_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 85167,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_A2_R5_z01_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 111649,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_A2_R7_z01_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 90255,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_A3_R11_z01_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 79863,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_A3_R15_z01_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 82804,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_A3_R17_z01_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 78707,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_A3_R18_z01_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 73923,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_A3_R19_z02_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 91586,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_A3_R1_z01_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 80119,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_A3_R2_z01_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 106286,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_A3_R6_z01_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 80229,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_A3_R7_z02_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 82092,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_A3_R8_z01_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 96556,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_A4_R2_z01_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 122439,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_A4_R3_z01_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 110586,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_A4_R4_z01_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 93231,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_A4_R5_z01_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 112336,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_A4_R6_z01_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 114858,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_A4_R7_z01_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 202248,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_A4_R8_z01_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 92315,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_A5_R17_z01_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 90360,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_A5_R4_z02_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 92829,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_A5_R5_z01_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 104401,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_A5_R8_z01_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 153156,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_A6_R1_z01_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 78354,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_A6_R3_z02_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 82460,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_A6_R4_z01_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 110994,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_A7_R15_z01_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 91850,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_A7_R3_z01_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 86188,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_A7_R5_z01_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 87057,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_A7_R8_z01_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 82677,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_A8_R3_z01_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 82602,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_A8_R6_z01_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 94635,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_A8_R7_z01_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 146496,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_A9_R10_z02_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 114302,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_A9_R1_z01_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 84273,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_A9_R3_z02_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 88699,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_A9_R4_z01_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 107717,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_A9_R6_z01_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 111663,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_A9_R7_z01_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 94486,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_A9_R8_z01_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 82376,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_B10_R2_z02_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 116338,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_B10_R4_z02_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 158005,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_B10_R5_z01_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 217932,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_B10_R6_z01_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 108943,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_B10_R7_z01_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 156293,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_B10_R8_z01_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 134401,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_B11_R1_z02_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 156146,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_B11_R2_z01_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 134016,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_B11_R3_z02_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 118143,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_B11_R4_z00_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 204015,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_B11_R5_z01_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 220985,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_B11_R6_z01_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 134078,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_B11_R7_z01_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 155794,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_B11_R8_z01_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 114497,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_B12_R2_z02_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 106261,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_B12_R3_z01_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 104749,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_B12_R5_z01_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 133851,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_B12_R8_z02_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 105143,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_B12_R9_z01_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 106222,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_B1_R11_z01_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 97260,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_B1_R12_z01_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 92416,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_B1_R13_z01_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 95804,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_B1_R14_z01_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 123783,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_B1_R15_z02_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 108599,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_B1_R17_z01_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 114820,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_B1_R1_z01_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 124868,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_B1_R3_z01_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 204192,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_B1_R4_z01_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 143684,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_B2_R2_z01_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 190618,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_B2_R3_z01_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 109063,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_B2_R4_z01_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 275197,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_B2_R5_z01_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 274061,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_B2_R6_z01_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 99569,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_B2_R7_z02_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 85675,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_B2_R8_z01_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 130138,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_B3_R1_z00_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 177698,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_B3_R2_z01_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 215358,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_B3_R4_z01_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 332924,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_B3_R5_z01_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 194586,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_B3_R8_z01_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 140036,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_B4_R4_z00_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 235648,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_B4_R5_z01_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 263018,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_B4_R6_z01_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 136979,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_B4_R7_z01_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 137868,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_B4_R8_z01_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 131578,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_B5_R1_z02_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 102300,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_B5_R2_z01_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 127798,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_B5_R3_z01_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 115628,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_B5_R4_z01_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 167299,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_B5_R5_z01_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 145500,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_B5_R7_z01_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 107035,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_B5_R8_z01_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 89544,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_B6_R1_z01_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 107681,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_B6_R2_z01_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 93155,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_B6_R4_z01_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 202049,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_B6_R5_z01_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 170959,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_B6_R6_z01_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 99149,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_B6_R7_z01_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 111799,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_B6_R8_z01_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 89338,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_B7_R2_z01_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 117608,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_B7_R4_z01_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 165535,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_B7_R5_z01_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 129239,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_B7_R6_z01_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 104361,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_B7_R7_z01_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 118996,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_B8_R1_z01_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 92298,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_B8_R2_z01_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 131860,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_B8_R3_z01_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 119850,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_B8_R4_z01_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 149695,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_B8_R5_z01_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 142909,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_B8_R6_z01_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 119398,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_B8_R7_z01_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 106068,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_B8_R8_z01_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 98775,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_B9_R1_z01_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 131236,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_B9_R2_z02_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 176815,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_B9_R4_z01_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 212739,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_B9_R5_z00_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 195887,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_B9_R6_z01_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 102807,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_B9_R7_z01_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 153279,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_B9_R8_z01_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 116202,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_C10_R1_z01_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 91069,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_C10_R2_z01_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 128726,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_C10_R4_z01_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 217486,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_C10_R5_z01_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 154774,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_C10_R7_z01_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 126956,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_C11_R1_z01_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 119746,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_C11_R2_z00_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 133742,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_C11_R3_z01_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 126778,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_C11_R4_z01_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 163986,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_C11_R5_z01_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 211040,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_C11_R6_z02_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 86226,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_C11_R7_z01_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 116692,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_C11_R8_z01_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 94030,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_C12_R10_z02_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 92427,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_C12_R13_z02_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 76212,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_C12_R14_z01_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 86085,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_C12_R1_z01_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 100715,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_C12_R2_z01_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 94595,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_C12_R7_z00_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 86085,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_C1_R1_z01_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 89314,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_C1_R2_z01_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 144852,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_C1_R3_z01_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 99202,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_C1_R4_z01_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 142608,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_C1_R6_z01_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 93936,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_C1_R8_z01_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 93021,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_C2_R2_z01_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 116845,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_C2_R3_z01_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 152269,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_C2_R4_z01_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 271461,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_C2_R5_z01_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 232480,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_C2_R6_z01_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 109323,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_C2_R7_z01_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 154766,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_C3_R2_z01_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 122138,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_C3_R3_z01_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 126362,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_C3_R4_z01_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 266936,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_C3_R5_z01_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 250273,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_C3_R6_z01_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 85603,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_C4_R1_z01_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 151689,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_C4_R2_z01_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 195348,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_C4_R4_z01_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 292299,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_1_Paclitaxel_C4_R7_z01_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 144897,
#    'StorageClass': 'STANDARD'},
# ...
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 125796,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_2_Paclitaxel_C4_R14_z01_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 108496,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_2_Paclitaxel_C4_R1_z02_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 100915,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_2_Paclitaxel_C4_R2_z01_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 85244,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_2_Paclitaxel_C4_R3_z02_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 84737,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_2_Paclitaxel_C4_R4_z01_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 110280,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_2_Paclitaxel_C4_R5_z01_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 121928,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_2_Paclitaxel_C4_R6_z00_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 110223,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_2_Paclitaxel_C4_R7_z02_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 84157,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_2_Paclitaxel_C4_R8_z01_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 91791,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_2_Paclitaxel_C5_R11_z01_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 80081,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_2_Paclitaxel_C5_R12_z02_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 96039,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_2_Paclitaxel_C5_R13_z01_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 73848,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_2_Paclitaxel_C5_R14_z02_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 93904,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_2_Paclitaxel_C5_R1_z01_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 101818,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_2_Paclitaxel_C5_R2_z01_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 91139,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_2_Paclitaxel_C5_R3_z02_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 85618,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_2_Paclitaxel_C5_R4_z02_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 97302,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_2_Paclitaxel_C5_R5_z02_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 110215,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_2_Paclitaxel_C5_R6_z02_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 83807,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_2_Paclitaxel_C5_R7_z02_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 95080,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_2_Paclitaxel_C5_R8_z01_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 97261,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_2_Paclitaxel_C6_R11_z02_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 86218,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_2_Paclitaxel_C6_R12_z01_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 84352,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_2_Paclitaxel_C6_R13_z02_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 103174,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_2_Paclitaxel_C6_R14_z01_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 78598,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_2_Paclitaxel_C6_R15_z00_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 121045,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_2_Paclitaxel_C6_R1_z02_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 92559,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_2_Paclitaxel_C6_R2_z02_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 81925,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_2_Paclitaxel_C6_R3_z02_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 80781,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_2_Paclitaxel_C6_R5_z02_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 105422,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_2_Paclitaxel_C6_R6_z01_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 78758,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_2_Paclitaxel_C6_R7_z01_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 96853,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_2_Paclitaxel_C6_R8_z01_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 66467,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_2_Paclitaxel_C7_R12_z01_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 98760,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_2_Paclitaxel_C7_R13_z02_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 82869,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_2_Paclitaxel_C7_R14_z01_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 94564,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_2_Paclitaxel_C7_R1_z02_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 84815,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_2_Paclitaxel_C7_R2_z02_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 87846,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_2_Paclitaxel_C7_R3_z02_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 106102,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_2_Paclitaxel_C7_R4_z01_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 105083,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_2_Paclitaxel_C7_R5_z02_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 119800,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_2_Paclitaxel_C7_R6_z02_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 84932,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_2_Paclitaxel_C7_R7_z02_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 86039,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_2_Paclitaxel_C7_R8_z01_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 86543,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_2_Paclitaxel_C8_R11_z01_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 83739,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_2_Paclitaxel_C8_R12_z01_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 84582,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_2_Paclitaxel_C8_R13_z01_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 87408,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_2_Paclitaxel_C8_R14_z01_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 89717,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_2_Paclitaxel_C8_R15_z00_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 97425,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_2_Paclitaxel_C8_R2_z01_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 102074,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_2_Paclitaxel_C8_R3_z01_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 81096,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_2_Paclitaxel_C8_R4_z01_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 116888,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_2_Paclitaxel_C8_R5_z01_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 89108,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_2_Paclitaxel_C8_R6_z02_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 103237,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_2_Paclitaxel_C8_R7_z02_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 107951,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_2_Paclitaxel_C9_R11_z01_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 83188,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_2_Paclitaxel_C9_R12_z02_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 109104,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_2_Paclitaxel_C9_R13_z01_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 98369,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_2_Paclitaxel_C9_R14_z00_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 120348,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_2_Paclitaxel_C9_R15_z00_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 82064,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'default/test/rocrates/paclitaxel.zip/paclitaxel/blue/B2AI_2_Paclitaxel_C9_R1_z02_blue.jpg',
#    'LastModified': datetime.datetime(2025, 9, 11, 16, 29, 4, 967000, tzinfo=tzutc()),
#    'ETag': '',
#    'Size': 100832,
#    'StorageClass': 'STANDARD'}],
#  'Name': 'default',
#  'Prefix': 'default/test/rocrates/paclitaxel.zip/',
#  'MaxKeys': 1000,
#  'EncodingType': 'url',
#  'KeyCount': 1000,
#  'NextContinuationToken': 'ZGVmYXVsdC90ZXN0L3JvY3JhdGVzL3BhY2xpdGF4ZWwuemlwL3BhY2xpdGF4ZWwvYmx1ZS9CMkFJXzJfUGFjbGl0YXhlbF9DOV9SMV96MDJfYmx1ZS5qcGc='}

# %%
rocrateMetadata

# %%
# start job

# %%
def presignedUploadRequest():
	pass

def executeJob():
	pass
