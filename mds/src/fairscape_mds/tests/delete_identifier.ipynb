# %%
import os
import sys
import pathlib

testPaths = pathlib.Path(".").absolute()
sys.path.append(str(testPaths.parent.parent))

# %%
from fairscape_mds.core.config import appConfig
# Out:
# /workspace/mds/src/.env
# mongodb://mongotestaccess:mongotestsecret@localhost:27017/

# %%
pathlib.Path(".").absolute().parent.parent / ".env"
# Out:
# PosixPath('/workspace/mds/src/.env')
